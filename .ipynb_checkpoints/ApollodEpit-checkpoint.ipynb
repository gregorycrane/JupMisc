# %%
import re
innotes = 0
roman_to_arabic = {
    'I': 1, 'II': 2, 'III': 3, 'IV': 4, 'V': 5,
    'VI': 6, 'VII': 7, 'VIII': 8, 'IX': 9, 'X': 10,
    'XI': 11, 'XII': 12, 'XIII': 13, 'XIV': 14, 'XV': 15,
    'XVI': 16, 'XVII': 17, 'XVIII': 18, 'XIX': 19, 'XX': 20,
    'XXI': 21, 'XXII': 22, 'XXIII': 23, 'XXIV': 24, 'XXV': 25,
    'XXVI': 26, 'XXVII': 27, 'XXVIII': 28, 'XXIX': 29, 'XXX': 30,
    'XXXI': 31, 'XXXII': 32, 'XXXIII': 33, 'XXXIV': 34, 'XXXV': 35,
    'XXXVI': 36, 'XXXVII': 37, 'XXXVIII': 38, 'XXXIX': 39, 'XL': 40,
    'XLI': 41, 'XLII': 42, 'XLIII': 43, 'XLIV': 44, 'XLV': 45,
    'XLVI': 46, 'XLVII': 47, 'XLVIII': 48, 'XLIX': 49, 'L': 50
}


fname = '/Users/gcrane/github/GRC_misc/tlg0548.tlg002.wagner1894-grc0.xml'
fname = '/Users/gcrane/github/GRC_misc/tlg0548.tlg001.wagner1894-grc0.xml'
f = open(fname)



outfname = '/Users/gcrane/github/GRC_misc/tlg0548.tlg002.wagner1894-grc1.xml'
outfname = '/Users/gcrane/github/GRC_misc/tlg0548.tlg001.wagner1894-grc1.xml'
tmpfname = '/tmp/tmp.xml'
outf = open(tmpfname,'w')

curpage = ''
innotes = 1
cursectn = 0
cursubsectn = 0
sentend = 0
prevaltsect = 0
curaltsect = 0
newsection = '</p></div></div>\n\n<div type="textpart" subtype="section" n="ZZZ">\n<div type="textpart" subtype="subsection" n="1"><p>'
newsubsection = '</p></div>\n\n<div type="textpart" subtype="subsection" n="ZZZ"><p>'
for l in f:
    if(re.search('"book"',l)):
        prevaltsect = 1
        curaltsect = 1
        
    m = re.search('"section" n="([0-9]+)"', l)
    if(m):
        cursectn = int(m[1])

    m = re.search('"subsection" n="([0-9]+)"', l)
    if(m):
        cursubsectn = int(m[1])
    l = re.sub('\s+$','',l)
    l = re.sub('^\s+','',l)
    if(re.search('<text',l)):
        innotes = 0
    m = re.search('<pb n="([0-9]+)',l)
    if(m):
        if(not innotes):
            print('nonotes',m[1])
        innotes = 0
        curpage = m[1]
        curline =0
        print('\n'+l,file=outf)
        continue

    if(re.search('(<div|<head|^<mile|<text|<body|div>|text>|body>)',l)):
        print(l,file=outf)
        continue


    if(re.search('<note>',l)):
        innotes = 1

    if(innotes):
        l = re.sub('([0-9])\s+(ss\.)','\g<1>\g<2>',l)
        l = re.sub('(\s+|^)([1-9]|1[0-9]|2[0-8])([s]*)\.\s+','</note>\n\n<note n="'+curpage+'.\g<2>\g<3>">',l)
        print(l,file=outf,end=' ')
        continue

        
    #if(re.search('[02468]$',curpage)):
    if(re.search('[13579]$',curpage)):
        if(not innotes):
            if(l and not re.search('<pb',l)):
                
                curline = curline + 1
                l = '<lb n="'+curpage+'.'+str(curline)+'"/>' + l
                if(curline in [5,10,15,20,25]):
                    m = re.search('([0-9]+$)',l)
                    if(not m):
                        if(curline > 19 and 0):
                            print('nolnum',curpage,curline,l)
                    else:
                        lnum = int(m[1])
                        if(not lnum == curline):
                            if(curline > 19 and 0):
                                print('mism',curpage,curline,l)
                        else:
                            l = re.sub('\s*([0-9]+$)','',l)
            m = re.search('^([0-9]+)',l)
            if(m):
                if(re.search('[^A-Zz-z]\.\s',l) and 0):
                    l = re.sub('([^A-Zz-z]\.)\s(.+)\s+([0-9]+)','\g<1></p></div>\n\n<div type="textpart" subtype="section" n="\g<3>">\n<p>\g<2>',l)
                    print(l)
            m = re.search('(<lb[^>]+>)([0-9]+)',l)
            if(m):
                workn = int(m[2])
                #print('a','workn',workn,'sub',cursubsectn)
                if(not workn == cursubsectn + 1 and not workn == cursectn + 1):
                    print(curpage,'jump',workn,cursectn,cursubsectn)
                if(not workn == cursubsectn + 1):
                    cursectn = workn
                    cursubsectn = 1
                    #print('nowa',cursectn,cursubsectn)
                    substr = re.sub('ZZZ',str(workn),newsection)
                else:
                    cursubsectn = workn
                    substr = re.sub('ZZZ',str(workn),newsubsection)
                if(sentend):
                    l = substr + l
                elif(re.search('\.\s+',l)):
                    l = re.sub('(\.)\s+','\g<1>'+substr,l)
                elif(re.search('·\s+',l)):
                    l = re.sub('(·)\s+','\g<1>'+substr,l)
                elif(re.search('·\s+',l)):
                    l = re.sub('(·)\s+','\g<1>'+substr,l)
                elif(re.search('@',l)):
                    l = re.sub('\s*@\s*',substr,l)
                else:
                    l = substr +'NOB'+l
                l = re.sub('(<lb[^>]+>)\s*([0-9]+)\s*','\g<1>',l)
                    
                #print(curpage,workn,'sect',cursectn,'sub',cursubsectn,l)
    else:
        if(not innotes and 1):
            if(l and not re.search('<pb',l)):
                
                curline = curline + 1
                if(curline in [5,10,15,20,25]):
                    m = re.search('^([0-9]*)(5|[123][05])\s+',l)
                    if(not m):
                        if(curline > 19 and 0):
                            print('nolnum',curpage,curline,l)
                    else:
                        #print('m1',m[1]+m[2],l)
                        lnum = int(m[1]+m[2])
                        if(not lnum == curline):
                            if(curline > 19 and 0):
                                print('mism',curpage,curline,l)
                        else:
                            
                           l = re.sub('^([0-9]*)(5|[123][05])\s+','',l) 
                l = '<lb n="'+curpage+'.'+str(curline)+'"/>' + l
            m = re.search('([0-9]+)$',l)
            if(m and 0):
                if(re.search('[^A-Zz-z]\.\s',l) and 0):
                    l = re.sub('([^A-Zz-z]\.)\s(.+)\s+([0-9]+)','\g<1></p></div>\n\n<div type="textpart" subtype="section" n="\g<3>">\n<p>\g<2>',l)
                    print(l)
            m = re.search('([0-9]+)$',l)
            if(m):
                workn = int(m[1])
                #print('b','workn',workn,'sub',cursubsectn)
                if(not workn == cursubsectn + 1):
                    cursectn = workn
                    cursubsectn = 1
                    #print('nowb',cursectn,cursubsectn)
                    substr = re.sub('ZZZ',str(workn),newsection)
                else:
                    cursubsectn = workn
                    substr = re.sub('ZZZ',str(workn),newsubsection)
                if(sentend):
                    l = substr + l
                elif(re.search('\.\s+',l)):
                    l = re.sub('(\.)\s+','\g<1>'+substr,l)
                elif(re.search('·\s+',l)):
                    l = re.sub('(·)\s+','\g<1>'+substr,l)
                elif(re.search('·\s+',l)):
                    l = re.sub('(·)\s+','\g<1>'+substr,l)
                elif(re.search('@',l)):
                    l = re.sub('\s*@\s*',substr,l)
                else:
                    l = substr +'NOB'+l
                #print(curpage,workn,'sect',cursectn,'sub',cursubsectn,l)
                l = re.sub('\s*([0-9]+)$','',l)

    if(l):
        if(re.search('[\.;][\s0-9]*$',l) or re.search('·$',l)):
            sentend = 1
        else:
            sentend = 0
    print(l,file=outf)
f.close()
outf.close()


f = open(tmpfname)
outfname = '/Users/gcrane/github/GRC_misc/tlg0548.tlg001.wagner1894-grc1.xml'
outf = open(outfname,'w')
innotes = 0
curbook = ''
for l in f:
    l = re.sub('\s+$','',l)
    l = re.sub('^\s+','',l)
    m = re.search('"book" n="([0-9]+)"', l)
    if(m):
        curbook = m[1]

    m = re.search('<pb n="([^"]+)',l)
    if(m):
        curpage = m[1]
        innotes = 0

    if(re.search('<note',l)):
        innotes = 1
    if(innotes):
        print(l,file=outf)
        continue

    if(re.search('[13579]$',curpage)):
        m = re.search('\s+([0-9]+)$',l)
        if(m):
            curaltcit = '<milestone unit="altsect" n="'+curbook+'.'+m[1]+'"/>'
            l = re.sub('\s+([0-9]+)$','',l)
            if(re.search('</p></div></div>',l)):
                l = re.sub('</p></div></div>','</p></div></div>'+curaltcit,l)
            elif(re.search('</p></div>',l)):
                l = re.sub('</p></div>','</p></div>'+curaltcit,l)
            elif(re.search('<p>',l)):
                l = re.sub('(<p>)','\g<1>'+curaltcit,l)
            elif(re.search('\.\s+',l)):
                l = re.sub('(\.)\s+','\g<1>'+curaltcit+' ',l)
            elif(re.search('(<lb[^>]+>)',l)):
                l = re.sub('(<lb[^>]+>)\s*','\g<1>'+curaltcit+' ',l)
            else:
                print('noalt',l)

    else:
        m = re.search('(<lb[^>]+>|<p>)([0-9]+)',l)
        if(m):
            l = re.sub('(<lb[^>]+>|<p>)([0-9]+)','\g<1>',l)
            curaltcit = '<milestone unit="altsect" n="'+curbook+'.'+m[2]+'"/>'
            if(re.search('</p></div></div>',l)):
                l = re.sub('</p></div></div>','</p></div></div>'+curaltcit,l)
            elif(re.search('</p></div>',l)):
                l = re.sub('</p></div>','</p></div>'+curaltcit,l)
            elif(re.search('<p>',l)):
                l = re.sub('(<p>)','\g<1>'+curaltcit,l)
            elif(re.search('\.\s+',l)):
                l = re.sub('(\.)\s+','\g<1>'+curaltcit+' ',l)
            elif(re.search('(<lb[^>]+>)',l)):
                l = re.sub('(<lb[^>]+>)\s*','\g<1>'+curaltcit+' ',l)
            else:
                print('noalt',l)
        
        
    if(l):
        if(re.search('[\.;][\s0-9]*$',l) or re.search('·$',l)):
            sentend = 1
        else:
            sentend = 0


    print(l,file=outf)

outf.close()
f.close()

f = open(outfname)

prevsect = 0
cursect = 0
for l in f:
    m = re.search('<milestone unit="altsect" n="[0-9]\.([^"]+)',l)
    if(m):
        cursect = int(m[1])
        if(cursect == 1):
            prevsect = 1
            continue
        if(not cursect == prevsect + 1):
            print('altjump',prevsect,cursect,l)
        prevsect = cursect

f.close()
# Out:
# nonotes 5
# altjump 1 3 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.3"/><lb n="5.16"/>ἀγανακτοῦσα δὲ Γῆ ἐπὶ τῇ ἀπωλείᾳ τῶν εἰς Τάρταρον
#
# altjump 1 4 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="1.4"/><lb n="6.9"/> ὁ δὲ τούτους μὲν ἐν τῷ Ταρτάρῳ πάλιν δήσας
#
# altjump 1 5 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.5"/><lb n="6.15"/> ὀργισθεῖσα δὲ ἐπὶ τούτοις Ρέα παραγίνεται
#
# altjump 1 6 <lb n="6.26"/><milestone unit="altsect" n="1.6"/> ἐπειδὴ δὲ Ζεὺς ἐγενήθη τέλειος, λαμβάνει Μῆτιν
#
# altjump 1 7 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.7"/>καὶ Κύκλωπες τότε Διὶ μὲν διδόασι
#
# altjump 1 8 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.8"/><lb n="7.16"/>ἐγένοντο δὲ Τιτάνων ἔκγονοι Ὠκεανοῦ μὲν καὶ
#
# altjump 1 9 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.9"/>ἐγένετο δὲ καὶ Κρόνου καὶ
#
# altjump 1 10 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.10"/><lb n="8.7"/> Πόντου δὲ καὶ Γῆς Φόρκος Θαύμας Νηρεύς Εὐρυβία
#
# altjump 1 11 <lb n="8.11"/> ὅταν τὰ κατὰ Περσέα λέγωμεν,</p></div></div><milestone unit="altsect" n="1.11"/>
#
# altjump 1 12 <lb n="8.16"/><milestone unit="altsect" n="1.12"/> Κυμὼ Ηιόνη Ἀλιμήδη Πληξαύρη Εὐκράντη,
#
# altjump 1 13 <lb n="9.3"/><milestone unit="altsect" n="1.13"/> Ζεὺς δὲ γαμεῖ μὲν Ἥραν, καὶ τεκνοῖ Ἥβην Εἰλείθυιαν
#
# altjump 1 14 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.14"/><lb n="9.13"/>Καλλιόπης μὲν οὖν καὶ Οἰάγρου, κατ᾽ ἐπίκλησιν δὲ
#
# altjump 1 15 <lb n="9.18"/>ἀνάγειν αὐτήν, καὶ Πλούτωνα ἔπεισεν ἀναπέμψαι.<milestone unit="altsect" n="1.15"/> ὁ
#
# altjump 1 16 <lb n="10.1"/> τῶν μαινάδων.</p></div></div><milestone unit="altsect" n="1.16"/>
#
# altjump 1 17 <lb n="10.6"/> ἀρρένων.</p></div><milestone unit="altsect" n="1.17"/>
#
# altjump 1 18 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.18"/><lb n="10.13"/> Εὐτέρπης δὲ καὶ ποταμοῦ Στρυμόνος Ρῆσος, ὃν ἐν
#
# altjump 1 19 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.19"/><lb n="10.18"/> Ἥρα δὲ χωρὶς εὐνῆς ἐγέννησεν Ἡφαιστον· ὡς δὲ
#
# altjump 1 20 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.20"/><lb n="10.25"/> μίγνυται δὲ Ζεὺς Μήτιδι, μεταβαλλούσῃ εἰς πολλὰς
#
# altjump 1 21 <lb n="11.9"/><milestone unit="altsect" n="1.21"/> τῶν δὲ Κοίου θυγατέρων Ἀστερία μὲν ὁμοιωθεῖσα
#
# altjump 1 22 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.22"/><lb n="11.16"/>Ἄρτεμις μὲν οὖν τὰ περὶ θήραν ἀσκήσασα παρθένος
#
# altjump 1 23 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.23"/>κτείνει
#
# altjump 1 24 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.24"/><lb n="12.7"/> ἀπέκτεινε δὲ Ἀπόλλων καὶ τὸν Ὀλύμπου παῖδα
#
# altjump 1 25 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.25"/><lb n="12.17"/> Ὠρίωνα δὲ Ἄρτεμις ἀπέκτεινεν ἐν Δήλῳ. τοῦτον
#
# altjump 1 26 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.26"/><lb n="12.25"/> ὁ δὲ ἐπὶ τὸ <add>Ηφαίστου</add> χαλκεῖον ἐλθὼν καὶ ἁρπάσας
#
# altjump 1 27 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.27"/>ἀλλὰ τῷ μὲν Ποσειδῶν ἡφαιστότευκτον
#
# altjump 1 28 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.28"/><lb n="13.11"/>Ποσειδῶν δὲ Ἀμφιτρίτην [τὴν Ὠκεανοῦ] γαμεῖ, καὶ
#
# altjump 1 29 <lb n="13.13"/><milestone unit="altsect" n="1.29"/> Πλούτων δὲ Περσεφόνης ἐρασθεὶς Διὸς συνεργοῦντος
#
# altjump 1 30 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.30"/>καὶ
#
# altjump 1 31 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.31"/><lb n="14.1"/> ὄντος δὲ τῇ τοῦ Κελεοῦ γυναικὶ Μετανείρᾳ παιδίου,
#
# altjump 1 32 <lb n="14.9"/> αὑτὴν ἐξέφηνε.</p></div></div><milestone unit="altsect" n="1.32"/>
#
# altjump 1 33 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.33"/><lb n="14.16"/> Διὸς δὲ Πλούτωνι τὴν Κόρην ἀναπέμψαι κελεύσαντος,
#
# altjump 1 34 <lb n="15.1"/><milestone unit="altsect" n="1.34"/> περὶ μὲν οὖν Δήμητρος ταῦτα λέγεται· Γῆ δὲ περὶ
#
# altjump 1 35 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.35"/>διέφερον δὲ πάντων Πορφυρίων τε
#
# altjump 1 36 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.36"/><lb n="15.19"/>κἀκεῖνος πρῶτον μὲν ἐτόξευσεν Ἀλκυονέα· πίπτων δὲ ἐπὶ
#
# altjump 1 37 <lb n="16.1"/> τος αὐτὸν Ἡρακλῆς τοξεύσας ἀπέκτεινε.</p></div><milestone unit="altsect" n="1.37"/>
#
# altjump 1 35 <lb n="16.8"/> σῶμα.</p></div><milestone unit="altsect" n="1.35"/>
#
# altjump 1 39 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.39"/><lb n="16.16"/> ὡς δ᾽ ἐκράτησαν οἱ θεοὶ τῶν Γιγάντων, Γῆ μᾶλλον
#
# altjump 1 40 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.40"/>τὰ δὲ ἀπὸ μηρῶν σπείρας εἶχεν
#
# altjump 1 41 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.41"/>θεοὶ δ᾽ ὡς εἶδον αὐτὸν ἐπ᾽ οὐρανὸν ὁρμώμενον,
#
# altjump 1 42 <div type="textpart" subtype="subsection" n="8"><p><milestone unit="altsect" n="1.42"/>Τυφὼν δὲ ταῖς σπείραις περιπλεχθεὶς κατέσχεν
#
# altjump 1 43 <lb n="18.6"/> τες τὰ νεῦρα ἥρμοσαν τῷ Διὶ λαθόντες.</p></div><milestone unit="altsect" n="1.43"/>
#
# altjump 1 44 <lb n="18.13"/> περὶ τὸν Αἷμον ὅλα ἔβαλλεν ὄρη.<milestone unit="altsect" n="1.44"/> τούτων δὲ
#
# altjump 1 45 <lb n="19.1"/><milestone unit="altsect" n="1.45"/> Ἀλλὰ περὶ μὲν τούτων μέχρι τοῦ δεῦρο ἡμῖν λελέχθω·
#
# altjump 1 46 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.46"/><lb n="19.10"/>καὶ Προμηθεὺς μὲν πυρὸς κλαπέντος δίκην ἔτινε
#
# altjump 1 47 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.47"/>ἐπεὶ δὲ
#
# altjump 1 48 <lb n="20.1"/> συνεχύθη πάντα.</p></div><milestone unit="altsect" n="1.48"/>
#
# altjump 1 49 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.49"/><lb n="20.11"/> γίνονται δὲ ἐκ Πύρρας Δευκαλίωνι παῖδες Ἕλλην
#
# altjump 1 50 <lb n="20.16"/> Ξούθος Αίολος.<milestone unit="altsect" n="1.50"/> αὐτὸς μὲν οὖν ἀφ᾽ αὑτοῦ τοὺς καλουμένους
#
# altjump 1 52 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.52"/><lb n="21.7"/>Περιμήδης μὲν οὖν καὶ Ἀχελώου Ιπποδάμας καὶ
#
# altjump 1 53 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.53"/><lb n="21.14"/>Κανάκη δὲ ἐγέννησεν ἐκ Ποσειδῶνος Ὁπλέα καὶ
#
# altjump 1 54 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.54"/>οὗτοι κατ'
#
# altjump 1 55 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.55"/><lb n="22.4"/> ἐμνῶντο δὲ Ἐφιάλτης μὲν Ἥραν Ὦτος δὲ Ἄρτεμιν. ἔδησαν
#
# altjump 1 56 <lb n="22.10"/><milestone unit="altsect" n="1.56"/> Καλύκης δὲ καὶ Αεθλίου παῖς Ἐνδυμίων γίνεται,
#
# altjump 1 57 <lb n="22.16"/><milestone unit="altsect" n="1.57"/> Ἐνδυμίωνος δὲ καὶ νηίδος νύμφης, ἢ ὥς τινες Ιφιανάσσης,
#
# altjump 1 58 <lb n="22.22"/><milestone unit="altsect" n="1.58"/> Αἰτωλοῦ δὲ καὶ Προνόης τῆς Φόρβου Πλευρών
#
# altjump 1 59 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.59"/>Καλυδῶνος
#
# altjump 1 60 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.60"/><lb n="23.7"/>Εὔηνος μὲν οὖν ἐγέννησε Μάρπησσαν, ἣν Ἀπόλλωνος
#
# altjump 1 61 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.61"/>Ἴδας δὲ εἰς Μεσσήνην παραγίνεται,
#
# altjump 1 62 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.62"/><lb n="23.20"/>Θεστίῳ δὲ ἐξ Εὐρυθέμιδος τῆς Κλεοβοίας ἐγένοντο
#
# altjump 1 63 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.63"/><lb n="23.23"/>Πορθάονος δὲ καὶ Εὐρύτης τῆς Ἱπποδάμαντος
#
# altjump 1 64 <lb n="24.1"/><milestone unit="altsect" n="1.64"/> Οἰνεὺς δὲ βασιλεύων Καλυδῶνος παρὰ Διονύσου
#
# altjump 1 65 <lb n="24.9"/> ἐπάλαισεν.</p></div><milestone unit="altsect" n="1.65"/>
#
# altjump 1 66 <lb n="24.16"/> γενόμενος τόνδε τον τρόπον ἐτελεύτησεν.<milestone unit="altsect" n="1.66"/> ἐτησίων
#
# altjump 1 67 <lb n="24.24"/> ἐπηγγείλατο.<milestone unit="altsect" n="1.67"/> οἱ δὲ συνελθόντες ἐπὶ τὴν τοῦ κάπρου
#
# altjump 1 68 <lb n="25.6"/><milestone unit="altsect" n="1.68"/> Ἄρκαδίας, Ιάσων Αἴσονος ἐξ Ιωλκοῦ, Ιφικλῆς Ἀμφιτρύωνος
#
# altjump 1 69 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.69"/>συνελθόντας δὲ
#
# altjump 1 70 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.70"/>περιστάντων δὲ αὐτῶν τὸν κάπρον, Ὑλεὺς
#
# altjump 1 71 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.71"/>οἱ δὲ Θεστίου παῖδες, ἀδοξοῦντες
#
# altjump 1 72 <lb n="26.1"/><milestone unit="altsect" n="1.72"/> δέρας αὐτῆς ἀφείλοντο, κατὰ γένος αὑτοῖς προσήκειν
#
# altjump 1 73 <lb n="26.12"/> κατ' αὐτοῦ· τὸν δὲ ὀργιζόμενον οἴκοι μένειν.</p></div><milestone unit="altsect" n="1.73"/>
#
# altjump 1 74 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.74"/><lb n="26.20"/> Ἀλθαίας δὲ ἀποθανούσης ἔγημεν Οἰνεὺς Περίβοιαν
#
# altjump 1 75 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.75"/>εἰσὶ δὲ οἱ λέγοντες Ιππόνουν ἐπιγνόντα
#
# altjump 1 76 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.76"/><lb n="27.7"/>Τυδεὺς δὲ ἀνὴρ γενόμενος γενναῖος ἐφυγαδεύθη,
#
# altjump 1 77 <lb n="27.16"/><milestone unit="altsect" n="1.77"/> Τυδεὺς μὲν οὖν ἐπὶ Θήβας μετ' Ἀδράστου στρατευσάμενος
#
# altjump 1 78 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.78"/>ὕστερον δὲ Διομήδης ἐξ
#
# altjump 1 79 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.79"/><lb n="28.5"/> οἱ δὲ διαφυγόντες Ἀγρίου παῖδες ἐνεδρεύσαντες περὶ
#
# altjump 1 80 <lb n="28.11"/><milestone unit="altsect" n="1.80"/> τῶν δὲ Αἰόλου παίδων Ἀθάμας, Βοιωτίας δυναστεύων,
#
# altjump 1 81 <lb n="28.19"/> εἰς Δελφοὺς ἀπαλλαγὴν ἐπυνθάνετο τῆς ἀφορίας.<milestone unit="altsect" n="1.81"/> Ἰνώ
#
# altjump 1 82 <lb n="28.24"/><milestone unit="altsect" n="1.82"/> Νεφέλη δὲ μετὰ τῆς θυγατρὸς αὐτὸν ἀνήρπασε, καὶ
#
# altjump 1 83 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.83"/>Φρίξος δὲ ἦλθεν
#
# altjump 1 84 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.84"/><lb n="29.14"/>Ἀθάμας δὲ ὕστερον διὰ μῆνιν Ἥρας καὶ τῶν ἐξ
#
# altjump 1 85 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.85"/><lb n="30.1"/> Σίσυφος δὲ ὁ Αἰόλου κτίσας Ἐφύραν τὴν νῦν
#
# altjump 1 86 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.86"/><lb n="30.11"/> Δηιὼν δὲ βασιλεύων τῆς Φωκίδος Διομήδην τὴν
#
# altjump 1 87 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.87"/><lb n="30.16"/> Περιήρης δὲ Μεσσήνην κατασχων Γοργοφόνην τὴν
#
# altjump 1 88 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.88"/><lb n="30.22"/> Μάγνης δὲ γαμεῖ νύμφην νηίδα, καὶ γίνονται
#
# altjump 1 89 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.89"/><lb n="31.3"/>Σαλμωνεὺς δὲ τὸ μὲν πρῶτον περὶ Θεσσαλίαν
#
# altjump 1 90 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.90"/><lb n="31.13"/>Τυρὼ δὲ ἡ Σαλμωνέως θυγάτηρ καὶ Ἀλκιδίκης
#
# altjump 1 91 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.91"/>ἐκκειμένων δὲ τῶν
#
# altjump 1 92 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.92"/>τελειωθέντες
#
# altjump 1 93 <lb n="32.3"/> Ἥραν ἀτιμάζων.</p></div></div><milestone unit="altsect" n="1.93"/>
#
# altjump 1 94 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.94"/><lb n="32.13"/> ἐσώθη δὲ Νέστωρ μόνος, ἐπειδὴ παρὰ Γερηνίοις ἐτρέφετο·
#
# altjump 1 95 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.95"/><lb n="32.18"/> Πελίας δὲ περὶ Θεσσαλίαν κατῴκει, καὶ γήμας
#
# altjump 1 96 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.96"/><lb n="32.22"/> Κρηθεὺς δὲ κτίσας Ιωλκόν γαμεί Τυρὼ τὴν Σαλμωνέως,
#
# altjump 1 97 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.97"/>οἱ δὲ γενόμενοι τέλειοι
#
# altjump 1 98 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.98"/><lb n="33.14"/>Βίας δὲ ἐμνηστεύετο Πηρὼ τὴν Νηλέως· ὁ δὲ
#
# altjump 1 99 <lb n="33.20"/>ἀδελφὸν συλλαβέσθαι.<milestone unit="altsect" n="1.99"/> Μελάμπους δὲ ὑπέσχετο, καὶ
#
# altjump 1 100 <lb n="34.4"/> δὲ ἀποκρινομένων λοιπὸν ἐλάχιστον εἶναι.<milestone unit="altsect" n="1.100"/> καὶ ταχέως
#
# altjump 1 101 <lb n="34.10"/> τὰς βόας λήψεται.<milestone unit="altsect" n="1.101"/> καὶ καταθύσας ταύρους δύο καὶ
#
# altjump 1 102 <lb n="34.19"/><milestone unit="altsect" n="1.102"/> ταῦτα μαθών παρ' αἰγυπιοῦ Μελάμπους τὴν
#
# altjump 1 103 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.103"/><lb n="35.3"/>Βίαντος δὲ καὶ Πηροῦς Ταλαός, οὗ καὶ Λυσιμάχης
#
# altjump 1 104 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.104"/><lb n="35.12"/>Φέρης δὲ ὁ Κρηθέως Φερὰς ἐν Θεσσαλίᾳ κτίσας
#
# altjump 1 105 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.105"/>Ἀδμήτου δὲ βασιλεύοντος
#
# altjump 1 106 <lb n="35.24"/><milestone unit="altsect" n="1.106"/> Ἀπόλλων δὲ εἰπὼν ἐξιλάσκεσθαι τὴν
#
# altjump 1 107 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.107"/><lb n="36.8"/> Αἴσονος δὲ τοῦ Κρηθέως καὶ Πολυμήδης τῆς Αὐτολύκου
#
# altjump 1 108 <lb n="36.13"/> δὲ ὕστερον αὐτὸν ἔγνω.<milestone unit="altsect" n="1.108"/> τελῶν γὰρ ἐπὶ τῇ θαλάσσῃ
#
# altjump 1 109 <lb n="36.21"/> αὐτῷ πρός τινος φονευθήσεσθαι τῶν πολιτῶν.<milestone unit="altsect" n="1.109"/> ὁ δέ,
#
# altjump 1 110 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.110"/><lb n="37.6"/>ἐπὶ τοῦτο πεμπόμενος Ιάσων Ἄργον παρεκάλεσε
#
# altjump 1 111 <lb n="37.13"/><milestone unit="altsect" n="1.111"/> οἱ δὲ συναθροισθέντες εἰσὶν οἵδε· Τΐφυς ῾Ἀγνίου, ὃς
#
# altjump 1 112 <lb n="37.18"/><milestone unit="altsect" n="1.112"/> † Καινεὺς Κορώνου, Παλαίμων Ἡφαίστου ἢ Αἰτωλοῦ,
#
# altjump 1 113 <lb n="38.4"/><milestone unit="altsect" n="1.113"/> Φᾶνος καὶ Στάφυλος Διονύσου, Ἐργίνος Που
#
# altjump 1 114 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.114"/><lb n="38.10"/> οὗτοι ναυαρχοῦντος Ἰάσονος ἀναχθέντες προσίσχουσι
#
# altjump 1 115 <lb n="38.16"/> αἰχμαλωτίδας συνευνάζοντο αὐταῖς.</p></div><milestone unit="altsect" n="1.115"/>
#
# altjump 1 116 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.116"/><lb n="39.3"/>ἀπὸ Λήμνου δὲ προσίσχουσι Δολίοσιν, ὧν ἐβασίλευε
#
# altjump 1 118 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.118"/>Ἡρόδωρος δὲ αὐτὸν
#
# altjump 1 119 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.119"/><lb n="40.6"/> ἀπὸ δὲ Μυσίας ἀπῆλθον εἰς τὴν Βεβρύκων γῆν,
#
# altjump 1 120 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.120"/><lb n="40.16"/> ἐντεῦθεν ἀναχθέντες καταντῶσιν εἰς τὴν τῆς Θράτης
#
# altjump 1 121 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="1.121"/>ἔπεμψαν δὲ
#
# altjump 1 122 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="1.122"/>θεασάμενοι
#
# altjump 1 123 <div type="textpart" subtype="subsection" n="7"><p><milestone unit="altsect" n="1.123"/>ἡ δὲ ἑτέρα καλουμένη
#
# altjump 1 124 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.124"/><lb n="42.4"/> ἀπαλλαγεὶς δὲ τῶν ἁρπυιῶν Φινεὺς ἐμήνυσε τὸν
#
# altjump 1 125 <lb n="42.11"/> δι' αὐτῶν διελθεῖν.</p></div><milestone unit="altsect" n="1.125"/>
#
# altjump 1 126 <lb n="42.20"/><milestone unit="altsect" n="1.126"/> αἱ μὲν οὖν συμπληγάδες ἔκτοτε ἔστησαν· χρεών
#
# altjump 1 127 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.127"/><lb n="43.3"/>παραπλεύσαντες δὲ Θερμώδοντα καὶ Καύκασον ἐπὶ
#
# altjump 1 128 <lb n="43.8"/>ταύρους μόνος καταζεύξῃ.<milestone unit="altsect" n="1.128"/> ἦσαν δὲ ἄγριοι παρ'
#
# altjump 1 129 <lb n="43.13"/>τοὺς ἡμίσεις ὧν Κάδμος ἔσπειρεν ἐν Θήβαις.<milestone unit="altsect" n="1.129"/> ἀποροῦντος
#
# altjump 1 130 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.130"/><lb n="43.21"/>ὀμόσαντος δὲ Ἰάσονος φάρμακον δίδωσιν, ᾧ καταζευγνύναι
#
# altjump 1 131 <lb n="44.7"/> αὐτούς.</p></div><milestone unit="altsect" n="1.131"/>
#
# altjump 1 132 <lb n="44.13"/> μένους πρὸς ἀλλήλους προσιὼν ἀνῄρει.</p></div></div><milestone unit="altsect" n="1.132"/>
#
# altjump 1 133 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.133"/><lb n="44.22"/> Αἰήτης δὲ ἐπιγνοὺς τὰ τῇ Μηδείᾳ τετολμημένα
#
# altjump 1 134 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.134"/><lb n="45.7"/>τοῖς δὲ Ἄργοναύταις τὸν Ἠριδανὸν ποταμὸν ἤδη
#
# altjump 1 135 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.135"/><lb n="45.17"/>παραπλεόντων δὲ Σειρῆνας αὐτῶν, Ὀρφεὺς τὴν
#
# altjump 1 136 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="1.136"/><lb n="45.21"/>μετὰ δὲ τὰς Σειρῆνας τὴν ναῦν Χάρυβδις ἐξεδέχετο
#
# altjump 1 137 <lb n="46.1"/><milestone unit="altsect" n="1.137"/> διεκόμισε τὴν ναῦν σὺν Νηρηίσι Θέτις παρακληθεῖσα
#
# altjump 1 138 <lb n="46.10"/><milestone unit="altsect" n="1.138"/> ὁ δὲ εἶπεν, εἰ μὲν ἤδη συνελήλυθεν Ἰάσονι, δώσειν
#
# altjump 1 139 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.139"/><lb n="46.16"/> πλέοντες δὲ νυκτὸς σφοδρῷ περιπίπτουσι χειμῶνι.
#
# altjump 1 140 <lb n="47.3"/><milestone unit="altsect" n="1.140"/> ἐντεῦθεν ἀναχθέντες κωλύονται Κρήτῃ προσίσχειν
#
# altjump 1 141 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.141"/><lb n="47.9"/>οὗτος ὁ Τάλως τρὶς ἑκάστης ἡμέρας τὴν νῆσον περιτροχάζων
#
# altjump 1 142 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="1.142"/><lb n="47.18"/>μίαν δὲ ἐνταῦθα νύκτα μείναντες Αἰγίνῃ προσίσχουσιν
#
# altjump 1 143 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.143"/><lb n="47.23"/>Πελίας δὲ ἀπογνοὺς τὴν ὑποστροφὴν τῶν Ἄργοναυτῶν
#
# altjump 1 144 <lb n="48.7"/> ἐθέλων καιρὸν ἐξεδέχετο.<milestone unit="altsect" n="1.144"/> καὶ τότε μὲν εἰς Ἰσθμὸν
#
# altjump 1 145 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="1.145"/><lb n="48.19"/> οἱ δὲ ἧκον εἰς Κόρινθον, καὶ δέκα μὲν ἔτη διετέλουν
#
# altjump 1 146 <lb n="49.4"/><milestone unit="altsect" n="1.146"/> τοὺς δὲ παῖδας οὓς εἶχεν ἐξ Ἰάσονος, Μέρμερον
#
# altjump 1 147 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="1.147"/><lb n="49.11"/>Μήδεια δὲ ἧκεν εἰς Ἀθήνας, κἀκεῖ γαμηθεῖσα Αἰγεῖ
#
# altjump 1 3 <lb n="50.18"/> δὲ τὸν Πελασγὸν αὐτόχθονα φησιν εἶναι.</p></div></div><milestone unit="altsect" n="2.3"/>
#
# altjump 1 4 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.4"/><lb n="51.6"/>Ἕκβάσου δὲ Ἀγήνωρ γίνεται, τούτου δὲ Ἄργος ὁ
#
# altjump 1 5 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.5"/><lb n="51.16"/>Ἄργου δὲ καὶ Ἰσμήνης τῆς Ἀσωποῦ παῖς Ἴασος,
#
# altjump 1 6 <lb n="52.2"/> ὅρκους ὑπὲρ ἔρωτος.</p></div><milestone unit="altsect" n="2.6"/>
#
# altjump 1 7 <lb n="52.8"/> ὑπῆρχεν ἄλσει.<milestone unit="altsect" n="2.7"/> Διὸς δὲ ἐπιτάξαντος Ἑρμῇ
#
# altjump 1 8 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="2.8"/><lb n="52.16"/> ἀπελθοῦσα δὲ εἰς Σκυθίαν καὶ τὴν Κιμμερίδα γῆν,
#
# altjump 1 9 <lb n="52.20"/> παρὰ τῷ Νείλῳ ποταμῷ Ἔπαφον παῖδα.</p></div><milestone unit="altsect" n="2.9"/>
#
# altjump 1 10 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.10"/><lb n="53.5"/>Ἔπαφος δὲ βασιλεύων Αἰγυπτίων γαμεῖ Μέμφιν
#
# altjump 1 11 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.11"/>Βῆλος δὲ ὑπομείνας ἐν Αἰγύπτῳ βασιλεύει
#
# altjump 1 12 <lb n="53.19"/>ὠνόμασεν Αἴγυπτον.<milestone unit="altsect" n="2.12"/> γίνονται δὲ ἐκ πολλῶν γυναικῶν
#
# altjump 1 13 <lb n="54.2"/> καὶ τὰς θυγατέρας ἐνθέμενος ἔφυγε.</p></div><milestone unit="altsect" n="2.13"/>
#
# altjump 1 14 <lb n="54.8"/> τύρησεν εἶναι, τὰς θυγατέρας ὑδρευσομένας ἔπεμψε.</p></div><milestone unit="altsect" n="2.14"/>
#
# altjump 1 15 <lb n="54.14"/> πηγὰς ἐμήνυσεν.</p></div></div><milestone unit="altsect" n="2.15"/>
#
# altjump 1 16 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.16"/><lb n="54.20"/> Ὑπερμνήστραν μὲν οὖν τὴν πρεσβυτέραν ἐξεῖλον
#
# altjump 1 17 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.17"/>Ἴστρος δὲ Ἱπποδάμειαν,
#
# altjump 1 18 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.18"/>Ἀγαπτόλεμος
#
# altjump 1 19 <lb n="55.17"/>η Χρύσιππος Χρυσίππην.<milestone unit="altsect" n="2.19"/> οἱ δὲ ἐκ Καλιάδνης νηίδος
#
# altjump 1 20 <lb n="56.6"/> Στύγνη Βρύκη.<milestone unit="altsect" n="2.20"/> οἱ δὲ <add>ἐκ</add> Γοργόνος Αἰγύπτῳ γενό- s
#
# altjump 1 21 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.21"/><lb n="56.15"/> ὡς δὲ ἐκληρώσατο τοὺς γάμους, ἑστιάσας ἐγχειρίδια
#
# altjump 1 22 <lb n="56.19"/> καθείρξας αὐτὴν Δαναὸς ἐφρούρει.</p></div></div><milestone unit="altsect" n="2.22"/>
#
# altjump 1 23 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.23"/><lb n="57.7"/>Ἀμυμώνη δὲ ἐκ Ποσειδῶνος ἐγέννησε Ναύπλιον.
#
# altjump 1 24 <lb n="57.16"/>Λυγκεὺς δὲ μετὰ.<milestone unit="altsect" n="2.24"/> Δαναόν Ἄργους δυναστεύων ἐξ
#
# altjump 1 25 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.25"/>ὁ δ᾽ ἧκεν εἰς Λυκίαν πρὸς Ἰοβάτην, ὡς δέ
#
# altjump 1 26 <lb n="58.5"/> βασιλεύει, Προῖτος δὲ Τίρυνθος.</p></div></div><milestone unit="altsect" n="2.26"/>
#
# altjump 1 27 <lb n="58.11"/><milestone unit="altsect" n="2.27"/> γενόμεναι δὲ ἐμμανεῖς ἐπλανῶντο ἀνὰ τὴν
#
# altjump 1 25 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.25"/><lb n="58.18"/> οὐκ ἐπιτρέποντος δὲ Προίτου θεραπεύειν ἐπὶ μισθοῖς
#
# altjump 1 29 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.29"/><lb n="59.3"/>Μελάμπους δὲ παραλαβὼν τοὺς δυνατωτάτους τῶν
#
# altjump 1 30 <lb n="59.10"/><milestone unit="altsect" n="2.30"/> Βελλεροφόντης δὲ ὁ Γλαύκου τοῦ Σισύφου, κτείνας
#
# altjump 1 32 <lb n="60.5"/> Τυφῶνος καὶ Ἐχίδνης, καθὼς Ἡσίοδος ἱστορεῖ.</p></div></div><milestone unit="altsect" n="2.32"/>
#
# altjump 1 33 <lb n="60.11"/> τον, Ἀμαζόσιν ἐπέταξεν ἀγωνίσασθαι αὐτόν.<milestone unit="altsect" n="2.33"/> ὡς δὲ
#
# altjump 1 34 <lb n="60.18"/><milestone unit="altsect" n="2.34"/> Ἄκρισίῳ δὲ περὶ παίδων γενέσεως ἀρρένων χρηστηριαζομένῳ
#
# altjump 1 35 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.35"/>αἰσθόμενος
#
# altjump 1 36 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.36"/>βασιλεύων δὲ τῆς
#
# altjump 1 37 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.37"/><lb n="61.19"/>ὁ δὲ Ἑρμοῦ καὶ Ἀθηνᾶς προκαθηγουμένων ἐπὶ τὰς
#
# altjump 1 38 <lb n="62.3"/> ἐπὶ τὰς νύμφας φέρουσαν.<milestone unit="altsect" n="2.38"/> αὗται δὲ αἱ νύμφαι πτηνὰ
#
# altjump 1 39 <lb n="62.9"/> εἶχον δὲ καὶ τὴν <add>Ἄϊδος</add> κυνῆν.</p></div><milestone unit="altsect" n="2.39"/>
#
# altjump 1 40 <div type="textpart" subtype="subsection" n="7"><p><milestone unit="altsect" n="2.40"/><lb n="62.18"/> ἦσαν δὲ αὗται Σθενὼ Εὐρυάλη Μέδουσα. μόνη δὲ
#
# altjump 1 41 <lb n="62.23"/> δι' ὧν ἐπέτοντο.<milestone unit="altsect" n="2.41"/> τοὺς δὲ ἰδόντας λίθους ἐποίουν.
#
# altjump 1 42 <lb n="63.3"/>ἔβλεπεν, ἐκαρατόμησεν αὐτήν.<milestone unit="altsect" n="2.42"/> ἀποτμηθείσης δὲ τῆς
#
# altjump 1 43 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.43"/><lb n="63.11"/>παραγενόμενος δὲ εἰς Αιθιοπίαν, ἧς ἐβασίλευε
#
# altjump 1 44 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.44"/>ταύτην θεασάμενος
#
# altjump 1 45 <lb n="64.2"/> αὐτὸν ἐλίθωσε παραχρῆμα.</p></div><milestone unit="altsect" n="2.45"/>
#
# altjump 1 46 <lb n="64.8"/> στος ἔτυχε σχῆμα ἔχων, ἀπελιθώθη.</p></div><milestone unit="altsect" n="2.46"/>
#
# altjump 1 47 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.47"/><lb n="64.17"/> Περσεὺς δὲ μετὰ Δανάης καὶ Ἀνδρομέδας ἔσπευδεν
#
# altjump 1 48 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.48"/>αἰσθόμενος δὲ τὸν χρησμόν τετελειωμένον τον
#
# altjump 1 49 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.49"/>ἐγένοντο δὲ ἐξ Ἀνδρομέδας παῖδες αὐτῷ,
#
# altjump 1 10 <lb n="65.9"/><milestone unit="altsect" n="2.10"/> Κηφεῖ κατέλιπεν (ἀπὸ τούτου δὲ τοὺς Περσῶν βασιλέας
#
# altjump 1 50 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.50"/><lb n="65.13"/>ἐκ μὲν οὖν Ἀλκαίου καὶ Ἀστυδαμείας τῆς Πέλοπος,
#
# altjump 1 15 <lb n="65.14"/><milestone unit="altsect" n="2.15"/> ὡς δὲ ἔνιοι λέγουσι Λαονόμης τῆς Γουνέως, ὡς δὲ ἄλλοι
#
# altjump 1 20 <lb n="65.19"/><milestone unit="altsect" n="2.20"/> Τάφιον, ὃς ᾤκισε Τάφον καὶ τοὺς λαοὺς Τηλεβόας
#
# altjump 1 51 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.51"/>ἐκ Ταφίου δὲ
#
# altjump 1 25 <lb n="65.24"/><milestone unit="altsect" n="2.25"/> Χερσιδάμας Μήστωρ Εὐήρης.
#
# altjump 1 52 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.52"/><lb n="66.1"/> @ Ἠλεκτρύων δὲ γήμας τὴν Ἀλκαίου θυγατέρα Ἀναξώ,
#
# altjump 1 53 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.53"/><lb n="66.7"/> Σθενέλου δὲ καὶ Νικίππης τῆς Πέλοπος Ἀλκυόνη
#
# altjump 1 54 <lb n="66.15"/><milestone unit="altsect" n="2.54"/> Ἠλεκτρύονος δὲ βασιλεύοντος Μυκηνῶν, μετὰ Ταφίου
#
# altjump 1 55 <lb n="66.22"/> τὰς ναῦς ἐφύλασσε.<milestone unit="altsect" n="2.55"/> τῶν δὲ Ταφίων οἱ διαφυγόντες
#
# altjump 1 53 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.53"/>ἀπολαμβάνοντος δὲ αὐτοῦ τὰς
#
# altjump 1 57 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="2.57"/><lb n="67.16"/>Ἀμφιτρύων δὲ σὺν Ἀλκμήνῃ καὶ Λικυμνίῳ παραγενόμενος
#
# altjump 1 58 <lb n="68.1"/> αὐτὴν μηδέ τινα καταλαβεῖν.</p></div><milestone unit="altsect" n="2.58"/>
#
# altjump 1 50 <lb n="68.9"/> νειν.<milestone unit="altsect" n="2.50"/> διωκομένης οὖν ὑπὸ τοῦ κυνὸς τῆς ἀλώπεκος,
#
# altjump 1 60 <lb n="68.14"/> τὰς τῶν Ταφίων νήσους ἐπόρθει.</p></div></div><milestone unit="altsect" n="2.60"/>
#
# altjump 1 61 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.61"/><lb n="68.23"/> πρὸ τοῦ δὲ Ἀμφιτρύωνα παραγενέσθαι εἰς Θήβας
#
# altjump 1 62 <lb n="69.8"/>τερον, Ἀμφιτρύωνι δὲ Ἰφικλέα.<milestone unit="altsect" n="2.62"/> τοῦ δὲ παιδὸς ὄντος
#
# altjump 1 63 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.63"/><lb n="69.18"/>ἐδιδάχθη δὲ Ἡρακλῆς ἁρματηλατεῖν μὲν ὑπὸ Ἀμφιτρύωνος,
#
# altjump 1 64 <lb n="69.24"/>ὀργισθεὶς ἀπέκτεινε.<milestone unit="altsect" n="2.64"/> δίκην δὲ ἐπαγόντων τινῶν αὐτῷ
#
# altjump 1 65 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.65"/><lb n="70.8"/>. ἐν δὲ τοῖς βουκολίοις ὑπάρχων ὀκτωκαιδεκαέτης
#
# altjump 1 66 <lb n="70.12"/> ὃν ἀφίκετο Ἡρακλῆς ἑλεῖν βουλόμενος τον λέοντα.<milestone unit="altsect" n="2.66"/> ὁ
#
# altjump 1 67 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.67"/><lb n="70.21"/> ἀνακάμπτοντι δὲ αὐτῷ ἀπὸ τῆς θήρας συνήντησαν
#
# altjump 1 68 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.68"/>στρατευσάμενος
#
# altjump 1 69 <lb n="71.12"/>Μινύαις δασμὸν κομίζειν.<milestone unit="altsect" n="2.69"/> ἐφ᾽ οἷς ἀγανακτῶν ἐστράτευσεν
#
# altjump 1 71 <div type="textpart" subtype="subsection" n="8"><p><milestone unit="altsect" n="2.71"/><lb n="71.25"/>προσμαθὼν δὲ παρ᾽ αὐτοῦ τὴν τοξικὴν Ἡρακλῆς
#
# altjump 1 72 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.72"/><lb n="72.4"/> μετὰ δὲ τὴν πρὸς Μινύας μάχην συνέβη αὐτῷ κατὰ
#
# altjump 1 73 <lb n="72.9"/> νεται τοῦ θεοῦ τοῦ κατοικήσει.</p></div><milestone unit="altsect" n="2.73"/>
#
# altjump 1 74 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.74"/><lb n="72.15"/> τοῦτο ἀκούσας ὁ Ἡρακλῆς εἰς Τίρυνθα ἦλθε, καὶ
#
# altjump 1 75 <lb n="73.2"/><milestone unit="altsect" n="2.75"/> εἰς δὲ τὴν Νεμέαν ἀφικόμενος καὶ τὸν λέοντα μαστεύσας
#
# altjump 1 76 <lb n="73.12"/><milestone unit="altsect" n="2.76"/> Εὐρυσθεὺς δὲ καταπλαγείς αὐτοῦ τὴν ἀνδρείαν ἀπεῖπε
#
# altjump 1 77 <lb n="73.20"/><milestone unit="altsect" n="2.77"/> δεύτερον δὲ ἄθλον ἐπέταξεν αὐτῷ τὴν Λερναίαν
#
# altjump 1 79 <lb n="74.9"/> τῶν ποδῶν ἐνείχετο περιπλακεῖσα.<milestone unit="altsect" n="2.79"/> τῷ ῥοπάλῳ δὲ τὰς
#
# altjump 1 80 <lb n="74.16"/> ἀνιέναι.</p></div><milestone unit="altsect" n="2.80"/>
#
# altjump 1 81 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.81"/><lb n="75.1"/>τρίτον ἆθλον ἐπέταξεν αὐτῷ τὴν Κερυνῖτιν ἔλαφον
#
# altjump 1 82 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.82"/>μετ' Ἀπόλλωνος δὲ Ἄρτεμις
#
# altjump 1 83 <lb n="75.14"/><milestone unit="altsect" n="2.83"/> τέταρτον ἆθλον ἐπέταξεν αὐτῷ τὸν Ἐρυμάνθιον
#
# altjump 1 84 <lb n="75.20"/><milestone unit="altsect" n="2.84"/> αἰτοῦντος δὲ οἶνον Ἡρακλέους, ἔφη δεδοικέναι τον
#
# altjump 1 85 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.85"/><lb n="76.3"/> ἐκεῖθεν δὲ πρὸς Χείρωνα συνέφυγον, ὃς ἐξελαθεὶς ὑπὸ
#
# altjump 1 86 <lb n="76.13"/> μενον ἀθάνατον, οὕτως ἀπέθανεν.</p></div><milestone unit="altsect" n="2.86"/>
#
# altjump 1 87 <div type="textpart" subtype="subsection" n="8"><p><milestone unit="altsect" n="2.87"/><lb n="77.2"/>ἐπανελθὼν δὲ εἰς Φολόην Ἡρακλῆς καὶ Φόλον τελευτήσαντα
#
# altjump 1 88 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.88"/><lb n="77.7"/>πέμπτον ἐπέταξεν αὐτῷ ἆθλον τῶν Αὐγείου βοσκημάτων
#
# altjump 1 89 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.89"/>μαρτυράμενος δὲ Ἡρακλῆς
#
# altjump 1 90 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.90"/><lb n="77.23"/>καθεζομένων δὲ τῶν δικαστῶν κληθεὶς ὁ Φυλεὺς ὑπὸ
#
# altjump 1 5 <lb n="78.1"/><milestone unit="altsect" n="2.5"/> Ἡρακλέους τοῦ πατρὸς κατεμαρτύρησεν, εἰπὼν ὁμολογῆσαι
#
# altjump 1 91 <lb n="78.4"/> Ἡρακλέα βαδίζειν ἐξ Ἠλιδος ἐκέλευσε.</p></div><milestone unit="altsect" n="2.91"/>
#
# altjump 1 92 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.92"/><lb n="78.12"/> ἕκτον ἐπέταξεν ἆθλον αὐτῷ τὰς Στυμφαλίδας ὄρνιθας
#
# altjump 1 93 <lb n="78.16"/> ἁρπαγὴν δεδοικυῖαι.</p></div><milestone unit="altsect" n="2.93"/>
#
# altjump 1 94 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.94"/><lb n="78.23"/> ἕβδομον ἐπέταξεν ἆθλον τὸν Κρῆτα ἀγαγεῖν ταῦρον.
#
# altjump 1 95 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.95"/><lb n="79.6"/>ἐπὶ τοῦτον παραγενόμενος εἰς Κρήτην Ἡρακλῆς, ἐπειδὴ
#
# altjump 1 96 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.96"/><lb n="79.13"/>ὄγδοον ἆθλον ἐπέταξεν αὐτῷ τὰς Διομήδους τοῦ
#
# altjump 1 97 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.97"/>τῶν δὲ Βιστόνων
#
# altjump 1 98 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.98"/><lb n="80.5"/>. ἔνατον ἆθλον Ἡρακλεῖ ἐπέταξε ζωστήρα κομίζειν
#
# altjump 1 99 <lb n="80.13"/> ἁπασῶν.<milestone unit="altsect" n="2.99"/> ἐπὶ τοῦτον τὸν ζωστήρα Ἡρακλῆς ἐπέμπετο,
#
# altjump 1 100 <lb n="80.23"/> ἂν αὐτὸς θελήσειεν.</p></div><milestone unit="altsect" n="2.100"/>
#
# altjump 1 101 <div type="textpart" subtype="subsection" n="7"><p><milestone unit="altsect" n="2.101"/><lb n="81.6"/>καταπλεύσαντος δὲ εἰς τὸν ἐν Θεμισκύρᾳ λιμένα,
#
# altjump 1 102 <div type="textpart" subtype="subsection" n="8"><p><milestone unit="altsect" n="2.102"/>αἱ δὲ μεθ᾽ ὅπλων ἐπὶ τὴν ναῦν
#
# altjump 1 103 <div type="textpart" subtype="subsection" n="9"><p><milestone unit="altsect" n="2.103"/><lb n="81.17"/>συνεβεβήκει δὲ τότε κατὰ μῆνιν Ἀπόλλωνος καὶ
#
# altjump 1 104 <lb n="82.2"/> ἐν τῷ πεδίῳ συνήρπαζεν ἀνθρώπους.</p></div><milestone unit="altsect" n="2.104"/>
#
# altjump 1 105 <div type="textpart" subtype="subsection" n="13"><p><milestone unit="altsect" n="2.105"/><lb n="82.12"/> καὶ προσίσχει Αἴνῳ, ἔνθα ξενίζεται ὑπὸ Πόλτυος.
#
# altjump 1 106 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.106"/><lb n="82.22"/> δέκατον ἐπετάγη ἆθλον τὰς Γηρυόνου βόας ἐξ
#
# altjump 1 107 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.107"/>πορευόμενος
#
# altjump 1 109 <lb n="83.20"/><milestone unit="altsect" n="2.109"/> Ἡρακλῆς δὲ ἐνθέμενος τὰς βόας εἰς τὸ δέπας
#
# altjump 1 110 <div type="textpart" subtype="subsection" n="9"><p><milestone unit="altsect" n="2.110"/><lb n="84.4"/> ἀπὸ Ῥηγίου δὲ εἷς ἀπορρήγνυσι ταῦρος, καὶ ταχέως
#
# altjump 1 111 <lb n="84.7"/> πεδίον Ἐρυκος, ὃς ἐβασίλευεν Ἐλύμων.<milestone unit="altsect" n="2.111"/> Ἔρυξ δὲ ἦν
#
# altjump 1 112 <lb n="84.14"/> τῶν ἄλλων ἐπὶ τὸν Ιόνιον ἤλαυνε πόντον.</p></div><milestone unit="altsect" n="2.112"/>
#
# altjump 1 113 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.113"/><lb n="84.23"/> τελεσθέντων δὲ τῶν ἄθλων ἐν μηνὶ καὶ ἔτεσιν
#
# altjump 1 115 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="2.115"/>συλλαβὼν
#
# altjump 1 116 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="2.116"/><lb n="86.8"/> μετὰ Λιβύην δὲ Αἴγυπτον διεξῄει. ταύτης ἐβασίλευε
#
# altjump 1 117 <lb n="86.14"/> τῷ Διὶ σφάξωσι κατ᾽ ἔτος.</p></div><milestone unit="altsect" n="2.117"/>
#
# altjump 1 118 <div type="textpart" subtype="subsection" n="8"><p><milestone unit="altsect" n="2.118"/><lb n="86.19"/> διεξιὼν δὲ Ἀσίαν Θερμυδραῖς, Λινδίων λιμένι,
#
# altjump 1 119 <div type="textpart" subtype="subsection" n="9"><p><milestone unit="altsect" n="2.119"/><lb n="87.3"/>παριὼν δὲ Ἄραβίαν Ἠμαθίωνα κτείνει παῖδα Τιθωνοῦ.
#
# altjump 1 120 <div type="textpart" subtype="subsection" n="11"><p><milestone unit="altsect" n="2.120"/><lb n="87.11"/>ὡς δὲ ἧκεν εἰς Ὑπερβορέους πρὸς Ἄτλαντα, εἰπόντος
#
# altjump 1 121 <lb n="87.19"/>οὕτως ἀνελόμενος αὐτὰ Ἡρακλῆς ἀπηλλάττετο.<milestone unit="altsect" n="2.121"/> ἔνιοι
#
# altjump 1 122 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.122"/><lb n="88.5"/> δωδέκατον άθλον ἐπετάγη Κέρβερον ἐξ Ἄιδου κομίζειν.
#
# altjump 1 123 <lb n="88.14"/><milestone unit="altsect" n="2.123"/> και παραγενόμενος ἐπὶ Ταίναρον τῆς Λακωνικῆς, οὗ
#
# altjump 1 124 <lb n="88.19"/> Ἑρμοῦ μανθάνει ὅτι κενὸν εἴδωλόν ἐστι.</p></div><milestone unit="altsect" n="2.124"/>
#
# altjump 1 125 <div type="textpart" subtype="subsection" n="7"><p><milestone unit="altsect" n="2.125"/><lb n="89.3"/>ἀπεκύλισε δὲ καὶ τὸν Ἀσκαλάφου πέτρον. βουλόμενος
#
# altjump 1 126 <lb n="89.10"/><milestone unit="altsect" n="2.126"/> ὁ δὲ εὑρὼν αὐτὸν ἐπὶ ταῖς πύλαις τοῦ Ἀχέροντος,
#
# altjump 1 127 <lb n="89.19"/><milestone unit="altsect" n="2.127"/> μετὰ δὲ τοὺς ἄθλους Ἡρακλῆς ἀφικόμενος εἰς Θήβας
#
# altjump 1 128 <lb n="90.2"/> χοντας.</p></div><milestone unit="altsect" n="2.128"/>
#
# altjump 1 129 <lb n="90.7"/> τὰ γεννηθησόμενα πάλιν ἀποκτείνῃ.</p></div></div><milestone unit="altsect" n="2.129"/>
#
# altjump 1 40 <lb n="90.10"/><milestone unit="altsect" n="2.40"/> Ἴφιτος δὲ ἀπιστῶν ἀφικνεῖται πρὸς Ἡρακλέα, καὶ συν
#
# altjump 1 130 <lb n="90.15"/> τειχών.<milestone unit="altsect" n="2.130"/> καθαρθῆναι δὲ θέλων τὸν φόνον ἀφικνεῖται
#
# altjump 1 131 <lb n="90.24"/> τῷ Ἀπόλλωνος, ὁ Ζεὺς ἵησι μέσον αὐτῶν κεραυνόν.</p></div><milestone unit="altsect" n="2.131"/>
#
# altjump 1 132 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.132"/>τὴν μὲν
#
# altjump 1 133 <lb n="91.12"/>τὴν νῆσον ἀντὶ Δολίχης Ἰκαρίαν ἐκάλεσεν.<milestone unit="altsect" n="2.133"/> ἀντὶ τούτου
#
# altjump 1 134 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.134"/><lb n="91.19"/>μετὰ δὲ τὴν λατρείαν ἀπαλλαγεὶς τὴς νόσου ἐπὶ
#
# altjump 1 136 <lb n="92.9"/> Ἡρακλέους κατασκευάζειν καλλινίκου.</p></div><milestone unit="altsect" n="2.136"/>
#
# altjump 1 137 <lb n="92.19"/><milestone unit="altsect" n="2.137"/> πλέοντος δὲ ἀπὸ Τροίας Ἡρακλέους Ἥρα χαλεποὺς
#
# altjump 1 135 <lb n="92.23"/> βάλλοντες λίθοις προσπλεῖν ἐκώλυον.</p></div><milestone unit="altsect" n="2.135"/>
#
# altjump 1 139 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.139"/><lb n="93.4"/>μετ᾿ οὐ πολὺ δὲ ἐπ᾽ Αὐγείαν ἐστρατεύετο, συναθροίσας
#
# altjump 1 140 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.140"/>συνέβη δὲ Ἡρακλεῖ κατὰ τὴν
#
# altjump 1 141 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.141"/>καὶ κτείνας μετὰ
#
# altjump 1 142 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.142"/><lb n="93.24"/>μετὰ δὲ τὴν τῆς Ἠλιδος ἅλωσιν ἐστράτευσεν ἐπὶ
#
# altjump 1 143 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.143"/><lb n="94.4"/> ἑλὼν δὲ τὴν Πύλον ἐστράτευεν ἐπὶ Λακεδαίμονα,
#
# altjump 1 144 <lb n="94.12"/> ἀπέκτειναν.</p></div><milestone unit="altsect" n="2.144"/>
#
# altjump 1 145 <lb n="94.21"/> τροπὴν τῶν πολεμίων ἔσεσθαι.</p></div><milestone unit="altsect" n="2.145"/>
#
# altjump 1 146 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.146"/><lb n="95.3"/>παριὼν δὲ Τεγέαν Ἡρακλῆς τὴν Αἴγην Ἀλεοῦ
#
# altjump 1 147 <lb n="95.9"/><milestone unit="altsect" n="2.147"/> καὶ τοῦτο κατὰ θεῶν τινα πρόνοιαν ἐσώθη· θηλὴν μὲν
#
# altjump 1 148 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.148"/><lb n="95.15"/>παραγενόμενος δὲ Ἡρακλῆς εἰς Καλυδώνα τὴν
#
# altjump 1 149 <lb n="96.1"/><milestone unit="altsect" n="2.149"/> ἢ ποτόν, ὅπερ <add>ἂν</add> εὔξαιτό τις, παρέχειν
#
# altjump 1 150 <lb n="96.9"/>πέμπειν εἰς Σαρδὼ τὴν νῆσον ἐπ᾽ ἀποικίαν.</p></div><milestone unit="altsect" n="2.150"/>
#
# altjump 1 151 <lb n="96.16"/> ἀπιέναι.</p></div><milestone unit="altsect" n="2.151"/>
#
# altjump 1 152 <lb n="97.2"/>μεύων αὐτὴν ἐπεχείρει βιάζεσθαι.<milestone unit="altsect" n="2.152"/> τῆς δὲ ἀνακραγούσης
#
# altjump 1 153 <lb n="97.9"/><milestone unit="altsect" n="2.153"/> διεξιὼν δὲ Ἡρακλῆς τὴν Δρυόπων χώραν, ἀπορῶν
#
# altjump 1 154 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="2.154"/><lb n="97.14"/>αὖθις δὲ ἐκεῖθεν ὁρμηθεὶς Αἰγιμίῳ βασιλεῖ Δωριέων
#
# altjump 1 155 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.155"/>ἀπέκτεινε δὲ καὶ Λαογόραν μετὰ τῶν τέκνων,
#
# altjump 1 156 <lb n="98.6"/><milestone unit="altsect" n="2.156"/> ἀφικόμενος δὲ εἰς Τραχῖνα στρατιὰν ἐπ᾽ Οἰχαλίαν
#
# altjump 1 157 <lb n="98.14"/> αἰχμάλωτον.</p></div></div><milestone unit="altsect" n="2.157"/>
#
# altjump 1 158 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.158"/>ὡς δὲ θερμανθέντος
#
# altjump 1 159 <lb n="99.8"/>κομίζεται.<milestone unit="altsect" n="2.159"/> Δηιάνειρα δὲ αἰσθομένη τὸ γεγονὸς ἑαυτὴν
#
# altjump 1 160 <lb n="99.13"/>ἐπιβὰς ὑφάπτειν.<milestone unit="altsect" n="2.160"/> μηδενὸς δὲ τοῦτο πράττειν ἐθέλοντος,
#
# altjump 1 161 <lb n="99.20"/><milestone unit="altsect" n="2.161"/> ἦσαν δὲ παῖδες αὐτῷ ἐκ μὲν τῶν Θεσπίου θυγατέρων,
#
# altjump 1 162 <lb n="100.3"/><milestone unit="altsect" n="2.162"/> Μηλίνης Λαομέδων, Κλυτίππης Εὐρύκαπυς,
#
# altjump 1 163 <lb n="100.9"/><milestone unit="altsect" n="2.163"/> θρας, Ξανθίδος Ὁμόλιππος, Στρατονίκης Ἄτρομος,
#
# altjump 1 164 <lb n="100.14"/><milestone unit="altsect" n="2.164"/> Ἀμήτριος, Τιφύσης Λυγκαῖος, Ἀλοκράτης Ὀλυμπούσης,
#
# altjump 1 166 <div type="textpart" subtype="subsection" n="10"><p><milestone unit="altsect" n="2.166"/>Χαλκιόπης <add>δὲ</add> τῆς Εὐρυπύλου
#
# altjump 1 167 <lb n="101.14"/><milestone unit="altsect" n="2.167"/> μεταστάντος δὲ Ἡρακλέους εἰς θεοὺς οἱ παῖδες
#
# altjump 1 168 <lb n="101.20"/>ἠξίουν βοηθεῖσθαι.<milestone unit="altsect" n="2.168"/> Ἀθηναῖοι δὲ οὐκ ἐκδιδόντες αὐτοὺς
#
# altjump 1 169 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.169"/><lb n="102.6"/> ἀπολομένου δὲ Εὐρυσθέως ἐπὶ Πελοπόννησον ἦλθον
#
# altjump 1 170 <lb n="102.13"/><milestone unit="altsect" n="2.170"/> Τληπόλεμος οὖν κτείνας οὐχ ἑκὼν Λικύμνιον (τῇ
#
# altjump 1 171 <lb n="102.19"/><milestone unit="altsect" n="2.171"/> διὸ παραγενόμενος εἰς Δελφοὺς ἐπυνθάνετο πῶς ἂν
#
# altjump 1 172 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.172"/>ἐπεὶ δὲ ἠνδρώθησαν
#
# altjump 1 173 <div type="textpart" subtype="subsection" n="7"><p><milestone unit="altsect" n="2.173"/>ταῦτα
#
# altjump 1 174 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.174"/>συνέβη δὲ καὶ τὸν στρατὸν ἐν Ναυπάκτῳ συμφορᾷ
#
# altjump 1 175 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.175"/>χρωμένου δὲ περὶ τῆς συμφορᾶς Τημένου,
#
# altjump 1 176 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="2.176"/><lb n="104.8"/> συμβαλόντες οὖν τὸν χρησμόν, τοῦτον ἡγεμόνα ποιοῦνται.
#
# altjump 1 177 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="2.177"/><lb n="104.13"/> ἐπειδὴ δὲ ἐκράτησαν Πελοποννήσου, τρεῖς ἱδρύσαντο
#
# altjump 1 178 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.178"/><lb n="104.22"/> ἑλκυσθείσης δὲ πρώτης μὲν τῆς Τημένου, δευτέρας δὲ
#
# altjump 1 179 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="2.179"/><lb n="105.9"/>Τήμενος μὲν οὖν παραπεμπόμενος τοὺς παῖδας
#
# altjump 1 180 <lb n="105.15"/><milestone unit="altsect" n="2.180"/> Κρεσφόντης δὲ οὐ πολὺν Μεσσήνης βασιλεύσας
#
# altjump 1 3 <lb n="106.12"/> διὰ τῆς θαλάσσης ἐκόμισεν εἰς Κρήτην.<milestone unit="altsect" n="3.3"/> ἡ δέ, ἐκεῖ
#
# altjump 1 4 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.4"/>ὡς δὲ πᾶσαν
#
# altjump 1 5 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.5"/><lb n="107.13"/>Εὐρώπην δὲ γήμας Ἀστέριος ὁ Κρητῶν δυνάστης
#
# altjump 1 6 <lb n="107.18"/>οἰκείως ἔχοντος πολεμήσας Μίνως ἐπροτέρησεν.<milestone unit="altsect" n="3.6"/> οἱ δὲ
#
# altjump 1 7 <lb n="108.3"/> ἐν Ἄιδου μετὰ Μίνωος δικάζει.</p></div></div><milestone unit="altsect" n="3.7"/>
#
# altjump 1 8 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.8"/><lb n="108.11"/> Ἀστερίου δὲ ἄπαιδος ἀποθανόντος Μίνως βασιλεύειν
#
# altjump 1 9 <lb n="108.18"/> ταῦρον εἰς τὰ βουκόλια πέμψας ἔθυσεν ἕτερον.<milestone unit="altsect" n="3.9"/> θαλασσοκρατήσας
#
# altjump 1 10 <lb n="108.24"/> τέκτων, πεφευγὼς ἐξ Ἀθηνῶν ἐπὶ φόνῳ.</p></div><milestone unit="altsect" n="3.10"/>
#
# altjump 1 11 <lb n="109.5"/>ταῦρος ὡς ἀληθινῇ βοϊ συνῆλθεν.<milestone unit="altsect" n="3.11"/> ἡ δὲ Ἀστέριον
#
# altjump 1 12 <lb n="109.11"/><milestone unit="altsect" n="3.12"/> τὰ μὲν οὖν περὶ Μινωταύρου καὶ Ἀνδρόγεω καὶ
#
# altjump 1 13 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.13"/>Κατρεὺς μὲν
#
# altjump 1 14 <lb n="109.24"/>Διός.<milestone unit="altsect" n="3.14"/> μετ᾿ οὐ πολὺ δὲ τῆς ἀδελφῆς αὐτόχειρ ἐγένετο.
#
# altjump 1 15 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.15"/><lb n="110.7"/> Αερόπην δὲ καὶ Κλυμένην Κατρεύς Ναυπλίῳ
#
# altjump 1 16 <lb n="110.14"/> τοῦτο ἦλθεν εἰς Ρόδον.<milestone unit="altsect" n="3.16"/> ἀποβὰς δὲ τῆς νεὼς σὺν τοῖς
#
# altjump 1 17 <lb n="110.22"/><milestone unit="altsect" n="3.17"/> Δευκαλίωνι δὲ ἐγένοντο Ιδομενεύς τε καὶ Κρήτη
#
# altjump 1 18 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.18"/>Κούρητες δὲ
#
# altjump 1 19 <lb n="111.7"/>διά τινος μαντείας ἀνεῦρε.<milestone unit="altsect" n="3.19"/> λέγοντος δὲ Μίνωος
#
# altjump 1 20 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.20"/>θεασάμενος δὲ Πολύιδος
#
# altjump 1 21 <lb n="112.1"/><milestone unit="altsect" n="3.21"/> Τὰ μὲν οὖν περὶ τῶν τῆς Εὐρώπης ἀπογόνων μέχρι
#
# altjump 1 5 <lb n="112.4"/><milestone unit="altsect" n="3.5"/> μὲν Εὐρώπης μὴ πολυπραγμονεῖν, χρῆσθαι δὲ καθοδηγῷ
#
# altjump 1 22 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.22"/><lb n="112.6"/> τοιοῦτον λαβὼν χρησμόν διὰ Φωκέων ἐπορεύετο, εἶτα
#
# altjump 1 10 <lb n="112.9"/> † πόλις ἔνθα νῦν εἰσι Θῆβαι.</p></div><milestone unit="altsect" n="3.10"/>
#
# altjump 1 23 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.23"/><lb n="112.14"/> ἀγανακτήσας δὲ Κάδμος κτείνει τὸν δράκοντα, καὶ τῆς
#
# altjump 1 24 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.24"/><lb n="112.19"/> Φερεκύδης δέ φησιν ὅτι Κάδμος, ἰδὼν ἐκ γῆς ἀναφυομένους
#
# altjump 1 25 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.25"/><lb n="113.6"/>μετὰ δὲ τὴν θητείαν Ἀθηνᾶ αὐτῷ τὴν βασιλείαν
#
# altjump 1 26 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.26"/>γίνονται δὲ Κάδμῳ θυγατέρες
#
# altjump 1 27 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.27"/>Ζεὺς δὲ μὴ δυνάμενος ἀνανεῦσαι παραγίνεται
#
# altjump 1 28 <lb n="114.4"/>νώθη.</p></div><milestone unit="altsect" n="3.28"/>
#
# altjump 1 29 <lb n="114.11"/> μετὰ νεκροῦ τοῦ παιδὸς ἥλατο κατὰ βυθοῦ.</p></div><milestone unit="altsect" n="3.29"/>
#
# altjump 1 30 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.30"/><lb n="114.20"/> Αὐτονόης δὲ καὶ Ἀρισταίου παῖς Ἄκταίων ἐγένετο,
#
# altjump 1 31 <lb n="115.3"/>λουομένην εἶδε.<milestone unit="altsect" n="3.31"/> καί φασι τὴν θεὸν παραχρῆμα αὐτοῦ
#
# altjump 1 32 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.32"/><lb n="115.11"/>[τὰ ὀνόματα τῶν Ἀκταίωνος κυνῶν ἐκ τῶν ...
#
# altjump 1 33 <lb n="116.10"/><milestone unit="altsect" n="3.33"/> Διόνυσος δὲ εὑρετὴς ἀμπέλου γενόμενος, Ἥρας
#
# altjump 1 34 <lb n="116.16"/> [ἐπὶ Ἰνδοὺς] διὰ τῆς Θράκης ἠπείγετο.</p></div><milestone unit="altsect" n="3.34"/>
#
# altjump 1 35 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.35"/>αὖθις δὲ αἱ Βάκχαι
#
# altjump 1 36 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.36"/><lb n="117.10"/>διελθὼν δὲ Θράκην [καὶ τὴν Ἰνδικὴν ἅπασαν,
#
# altjump 1 37 <lb n="117.17"/>ἐμελίσθη· ἐνόμισε γὰρ αὐτὸν θηρίον εἶναι.<milestone unit="altsect" n="3.37"/> δείξας δὲ
#
# altjump 1 38 <lb n="117.23"/>σατο τριήρη.<milestone unit="altsect" n="3.38"/> οἱ δὲ αὐτὸν ἐνθέμενοι Νάξον μὲν παρέπλεον,
#
# altjump 1 39 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.39"/><lb n="118.6"/> ὁ δὲ Κάδμος μετὰ Ἄρμονίας Θήβας ἐκλιπών πρὸς
#
# altjump 1 40 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.40"/><lb n="118.14"/> Πολύδωρος δὲ Θηβῶν βασιλεὺς γενόμενος Νυκτηίδα
#
# ...
#
# altjump 1 95 <lb n="133.24"/>δεδοικυίας μὴ Κρέων αὐτὴν γαμετὴν ποιήσηται.<milestone unit="altsect" n="3.95"/> τὸν
#
# altjump 1 96 <lb n="134.3"/><milestone unit="altsect" n="3.96"/> Ἐπανάγωμεν δὲ νῦν πάλιν ἐπὶ τὸν Πελασγόν, ὃν
#
# altjump 1 97 <lb n="134.10"/><milestone unit="altsect" n="3.97"/> Καύκωνα Μηκιστέα Ὁπλέα Μακαρία Μάκεδνον, Ὅρον
#
# altjump 1 98 <lb n="134.17"/> Κλείτορα Στύμφαλον Ὀρχομενόν...</p></div><milestone unit="altsect" n="3.98"/>
#
# altjump 1 99 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="3.99"/><lb n="135.6"/>Ζεὺς δὲ <add>μυσαχθεὶς</add> τὴν μὲν τράπεζαν ἀνέτρεψεν, ἔνθα
#
# altjump 1 100 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.100"/><lb n="135.14"/>Εύμηλος δὲ καί τινες ἕτεροι λέγουσι Λυκάονι και
#
# altjump 1 101 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.101"/>βουλόμενος δὲ Ἥραν λαθεῖν εἰς ἄρκτον
#
# altjump 1 102 <lb n="136.6"/><milestone unit="altsect" n="3.102"/> Ἀρκάδος δὲ καὶ Λεανείρας τῆς Ἀμύκλου ἢ Μεγανείρας
#
# altjump 1 103 <lb n="136.13"/> μὲν Αὔγη, υἱοὶ δὲ Κηφεὺς καὶ Λυκοῦργος.<milestone unit="altsect" n="3.103"/> Αὔγη μὲν
#
# altjump 1 104 <lb n="136.20"/> ἔγημε.</p></div><milestone unit="altsect" n="3.104"/>
#
# altjump 1 105 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.105"/><lb n="137.3"/>Λυκούργου δὲ καὶ Κλεοφύλης ἢ Εὐρυνόμης Ἀγκαῖος
#
# altjump 1 106 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.106"/>τελεία δὲ 'Αταλάντη γενομένη παρθένον ἑαυτὴν
#
# altjump 1 107 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.107"/>ἀνευροῦσα δὲ ὕστερον
#
# altjump 1 108 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="3.108"/><lb n="137.22"/>ἤδη δὲ πολλῶν ἀπολομένων Μελανίων αὐτῆς ἐρασθεὶς
#
# altjump 1 109 <lb n="138.6"/> εἰς λέοντας ἀλλαγῆναι.</p></div><milestone unit="altsect" n="3.109"/>
#
# altjump 1 110 <lb n="138.11"/><milestone unit="altsect" n="3.110"/> Ἀτλαντος δὲ καὶ τῆς Ὠκεανοῦ Πληιόνης ἐγένοντο
#
# altjump 1 15 <lb n="138.14"/> Στερόπη Ταϋγέτη Μαῖα.</p></div><milestone unit="altsect" n="3.15"/>
#
# altjump 1 111 <lb n="138.15"/> Οἰνόμαος ἔγημε, Σίσυφος (δὲ) Μερόπην.<milestone unit="altsect" n="3.111"/> δυσὶ δὲ ἐμίχθη
#
# altjump 1 20 <lb n="138.19"/><milestone unit="altsect" n="3.20"/> Ἀπόλλωνι Ἐλευθῆρα τεκοῦσαν, υἱοὺς δὲ Ὑριέα καὶ
#
# altjump 1 113 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.113"/>καὶ ταχέως εἰς Κυλλήνην
#
# altjump 1 114 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.114"/><lb n="139.19"/>μαθὼν δὲ ἐκ τῆς μαντικῆς τὸν κεκλοφότα πρὸς Μαῖαν
#
# altjump 1 115 <lb n="139.25"/>δὲ τῆς λύρας ὁ Ἀπόλλων ἀντιδίδωσι τὰς βόας.<milestone unit="altsect" n="3.115"/> Ἑρμῆς
#
# altjump 1 116 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.116"/><lb n="140.8"/> Ταϋγέτη δὲ ἐκ Διὸς <add>ἐγέννησε</add> Λακεδαίμονα, ἀφ᾽
#
# altjump 1 117 <lb n="140.15"/> βαλὼν ἄκων ἀπέκτεινε.</p></div><milestone unit="altsect" n="3.117"/>
#
# altjump 1 118 <lb n="140.23"/>τες ἔγημαν Διόσκουροι.<milestone unit="altsect" n="3.118"/> πρὸς δὲ ταύταις Ἄρσινόην
#
# altjump 1 119 <div type="textpart" subtype="subsection" n="7"><p><milestone unit="altsect" n="3.119"/><lb n="141.6"/>Ἀπόλλων δὲ τὸν μὲν ἀπαγγείλαντα κόρακα καταρᾶται,
#
# altjump 1 120 <lb n="141.11"/><milestone unit="altsect" n="3.120"/> καὶ γενόμενος χειρουργικὸς καὶ τὴν τέχνην
#
# altjump 1 121 <div type="textpart" subtype="subsection" n="10"><p><milestone unit="altsect" n="3.121"/><lb n="141.18"/>[εὗρον δέ τινας λεγομένους ἀναστῆναι ὑπ᾽ αὐτοῦ,
#
# altjump 1 122 <lb n="142.6"/></p></div></div><milestone unit="altsect" n="3.122"/>
#
# altjump 1 123 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.123"/><lb n="142.15"/> εἰσὶ δὲ οἱ λέγοντες Ἀφαρέα μὲν καὶ Λεύκιππον
#
# altjump 1 124 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.124"/><lb n="142.19"/> Ἱπποκόωντος μὲν οὖν ἐγένοντο παῖδες Δορυκλεὺς
#
# altjump 1 125 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.125"/>οἱ δὲ φεύγουσι πρὸς Θέστιον,
#
# altjump 1 126 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.126"/><lb n="143.9"/>Ἰκαρίου μὲν οὖν καὶ Περιβοίας νύμφης νηίδος Θόας
#
# altjump 1 127 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.127"/>λέγουσι δὲ ἔνιοι Νεμέσεως
#
# altjump 1 128 <lb n="144.1"/> τρέφειν.</p></div><milestone unit="altsect" n="3.128"/>
#
# altjump 1 129 <lb n="144.5"/> μητέρα Αίθραν ἄγουσιν αἰχμάλωτον.</p></div></div><milestone unit="altsect" n="3.129"/>
#
# altjump 1 130 <lb n="144.11"/><milestone unit="altsect" n="3.130"/> Ἀμφιαράου, Μενεσθεὺς Πετεώ, Σχεδίος (καὶ) Ἐπίστροφος
#
# altjump 1 131 <lb n="144.16"/><milestone unit="altsect" n="3.131"/> Κορώνου, Ποδαλείριος καὶ Μαχάων Ἀσκληπιού, Φιλοκτήτης
#
# altjump 1 132 <lb n="144.21"/> οἱ λοιποί.<milestone unit="altsect" n="3.132"/> ὑποσχομένου δὲ Ὀδυσσέως, ἐὰν συλλάβηται
#
# altjump 1 133 <lb n="145.5"/><milestone unit="altsect" n="3.133"/> Μενέλαος μὲν οὖν ἐξ Ἑλένης Ἐρμιόνην ἐγέννησε
#
# altjump 1 134 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.134"/><lb n="145.10"/>τῶν δὲ ἐκ Λήδας γενομένων παίδων Κάστωρ μὲν
#
# altjump 1 136 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.136"/>στρατεύσαντες
#
# altjump 1 137 <lb n="146.5"/> ἐκείνου πέτρᾳ κατὰ τῆς κεφαλῆς, πίπτει σκοτωθείς.<milestone unit="altsect" n="3.137"/> καὶ
#
# altjump 1 138 <lb n="146.12"/><milestone unit="altsect" n="3.138"/> Ἠλέκτρας δὲ τῆς Ἄτλαντος καὶ Διὸς Ιασίων καὶ
#
# altjump 1 15 <lb n="146.14"/><milestone unit="altsect" n="3.15"/> τρος καὶ θέλων καταισχῦναι τὴν θεὸν κεραυνοῦται,
#
# altjump 1 139 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.139"/><lb n="146.17"/>ταύτης δὲ ἐβασίλευε Τεῦκρος ποταμοῦ Σκαμάνδρου καὶ
#
# altjump 1 20 <lb n="146.19"/> Τεύκροι προσηγορεύοντο.</p></div><milestone unit="altsect" n="3.20"/>
#
# altjump 1 140 <lb n="146.23"/><milestone unit="altsect" n="3.140"/> γενομένων δὲ αὐτῷ παίδων Ἴλου καὶ Ἐριχθονίου, Ἰλος
#
# altjump 1 25 <lb n="146.24"/><milestone unit="altsect" n="3.25"/> μὲν ἄπαις ἀπέθανεν, Ἐριχθόνιος δὲ διαδεξάμενος τὴν
#
# altjump 1 141 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.141"/>τοῦτον μὲν
#
# altjump 1 142 <lb n="147.10"/><milestone unit="altsect" n="3.142"/> Ἶλος δὲ εἰς Φρυγίαν ἀφικόμενος καὶ καταλαβὼν
#
# altjump 1 144 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.144"/><lb n="148.1"/> [ἱστορία δὲ ἡ περὶ τοῦ παλλαδίου τοιάδε φέρεται·
#
# altjump 1 145 <lb n="148.7"/> καὶ οὕτως ὑπὸ τῆς Ἀθηνᾶς τρωθεῖσαν πεσεῖν.</p></div><milestone unit="altsect" n="3.145"/>
#
# altjump 1 146 <lb n="148.16"/></p></div><milestone unit="altsect" n="3.146"/>
#
# altjump 1 147 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.147"/><lb n="149.1"/>Τιθωνὸν μὲν οὖν Ἠὼς ἁρπάσασα δι᾽ ἔρωτα εἰς Αἰθιοπίαν
#
# altjump 1 148 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.148"/>Πρίαμος δὲ Ἄρίσβην
#
# altjump 1 150 <lb n="149.21"/>Ἀγέλαος ὠνομάζετο.<milestone unit="altsect" n="3.150"/> τὸ δὲ ἐκτεθὲν ὑπὸ τούτου βρέφος
#
# altjump 1 151 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="3.151"/><lb n="150.7"/> μετὰ τοῦτον ἐγέννησεν Ἕκάβη θυγατέρας μὲν
#
# altjump 1 152 <div type="textpart" subtype="subsection" n="8"><p><milestone unit="altsect" n="3.152"/><lb n="150.15"/> ἐκ δὲ ἄλλων γυναικῶν Πριάμῳ παῖδες γίνονται
#
# altjump 1 153 <lb n="150.19"/> Τελέστας Εὔανδρος Κεβριόνης,</p></div><milestone unit="altsect" n="3.153"/>
#
# altjump 1 154 <lb n="151.1"/><milestone unit="altsect" n="3.154"/> Ἕκτωρ μὲν οὖν Ἀνδρομάχην τὴν Ηετίωνος γαμεῖ,
#
# altjump 1 155 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.155"/>τὸν δὲ Ἑλένην ἐκ Σπάρτης
#
# altjump 1 156 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.156"/><lb n="151.14"/>Ὁ δὲ Ἀσωπὸς ποταμὸς Ὠκεανοῦ καὶ Τηθύος, ὡς δὲ
#
# altjump 1 157 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.157"/>ταύτην 'Ασωπὸς
#
# altjump 1 158 <lb n="152.4"/><milestone unit="altsect" n="3.158"/> τούτῳ Ζεὺς ὄντι μόνῳ ἐν τῇ νήσῳ τοὺς μύρμηκας ἀνθρώπους
#
# altjump 1 159 <div type="textpart" subtype="subsection" n="9"><p><milestone unit="altsect" n="3.159"/><lb n="152.12"/> ἦν δὲ εὐσεβέστατος πάντων Αιακός. διὸ καὶ τὴν
#
# altjump 1 160 <div type="textpart" subtype="subsection" n="11"><p><milestone unit="altsect" n="3.160"/><lb n="152.22"/> διαφέροντος δὲ ἐν τοῖς ἀγῶσι Φώκου, τοὺς ἀδελφοὺς
#
# altjump 1 161 <lb n="153.3"/>κρύπτει κατά τινος ὕλης.<milestone unit="altsect" n="3.161"/> φωραθέντος δὲ τοῦ φόνου
#
# altjump 1 162 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.162"/><lb n="153.9"/>ὁ δὲ γαμεῖ Περίβοιαν τὴν Ἀλκάθου τοῦ Πέλοπος
#
# altjump 1 163 <lb n="153.15"/><milestone unit="altsect" n="3.163"/> Πηλεὺς δὲ εἰς Φθίαν φυγὴν πρὸς Εὐρυτίωνα τὸν
#
# altjump 1 164 <lb n="153.22"/>κτείνει τοῦτον ἄκων.<milestone unit="altsect" n="3.164"/> πάλιν οὖν ἐκ Φθίας φυγών εἰς
#
# altjump 1 165 <lb n="154.4"/> αὐτῷ λόγους.</p></div></div><milestone unit="altsect" n="3.165"/>
#
# altjump 1 166 <lb n="154.11"/><milestone unit="altsect" n="3.166"/> ἔνθα ἁμίλλης περὶ θήρας γενομένης, Πηλεὺς μὲν ὧν
#
# altjump 1 167 <lb n="154.16"/> σαῦτα ἔφη τεθηρευκέναι.<milestone unit="altsect" n="3.167"/> ἀποκοιμηθέντος δὲ αὐτοῦ ἐν
#
# altjump 1 168 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.168"/><lb n="154.22"/> γαμεῖ δὲ ὁ Πηλεὺς Πολυδώραν τὴν Περιήρους, ἐξ
#
# altjump 1 169 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.169"/>ἔνιοι δέ φασι, Διὸς ὁρμῶντος
#
# altjump 1 170 <lb n="155.8"/>αὐτὴν συνοικίσαι.<milestone unit="altsect" n="3.170"/> Χείρωνος οὖν ὑποθεμένου Πηλεῖ
#
# altjump 1 172 <lb n="156.2"/> τὸν παῖδα ἀπολιποῦσα πρὸς Νηρηίδας ᾤχετο.<milestone unit="altsect" n="3.172"/> κομίζει
#
# altjump 1 173 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.173"/><lb n="156.7"/> Πηλεὺς δὲ μετὰ ταῦτα σὺν Ἰάσονι καὶ Διοσκούροις
#
# altjump 1 174 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.174"/><lb n="156.11"/> ὡς δὲ ἐγένετο ἐνναετὴς Ἀχιλλεύς, Κάλχαντος λέγοντος
#
# altjump 1 175 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.175"/><lb n="156.20"/> συνείπετο δὲ αὐτῷ Φοίνιξ ὁ Ἀμύντορος. οὗτος ὑπὸ
#
# altjump 1 176 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.176"/><lb n="157.1"/>συνείπετο δὲ καὶ Πάτροκλος ὁ Μενοιτίου και Σθενέλης
#
# altjump 1 177 <lb n="157.8"/><milestone unit="altsect" n="3.177"/> Κέκροψ αὐτόχθων, συμφνὲς ἔχων σῶμα ἀνδρὸς καὶ
#
# altjump 1 178 <lb n="157.11"/>ὠνόμασεν.<milestone unit="altsect" n="3.178"/> ἐπὶ τούτου, φασίν, ἔδοξε τοῖς θεοῖς πόλεις
#
# altjump 1 179 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.179"/>γενομένης δὲ ἔριδος ἀμφοῖν περὶ τῆς χώρας,
#
# altjump 1 180 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.180"/><lb n="158.7"/> Κέκροψ δὲ γήμας τὴν Ἀκταίου κόρην Ἄγραυλον
#
# altjump 1 181 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.181"/><lb n="158.15"/> Ἕρσης δὲ καὶ Ἑρμοῦ Κέφαλος, οὗ ἐρασθεῖσα Ηὼς
#
# altjump 1 182 <lb n="158.20"/> τοῦ Ὑριέων βασιλέως ἐγέννησε Κινύραν.</p></div></div><milestone unit="altsect" n="3.182"/>
#
# altjump 1 183 <lb n="159.4"/><milestone unit="altsect" n="3.183"/> Ἄδωνις δὲ ἔτι παῖς ὢν Ἀρτέμιδος χόλῳ πληγείς
#
# altjump 1 184 <lb n="159.10"/>ἀγνοοῦντι τῷ πατρὶ νύκτας δώδεκα συνευνάσθη.<milestone unit="altsect" n="3.184"/> ὁ δὲ
#
# altjump 1 187 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.187"/><lb n="160.6"/> Κραναὸν δὲ ἐκβαλών Ἀμφικτύων ἐβασίλευσε· τοῦτον
#
# altjump 1 188 <lb n="160.11"/>νᾶς, οὕτως·</p></div><milestone unit="altsect" n="3.188"/>
#
# altjump 1 189 <lb n="160.20"/> Ἐριχθόνιος γίνεται.<milestone unit="altsect" n="3.189"/> τοῦτον Ἀθηνᾶ κρύφα τῶν ἄλλων
#
# altjump 1 190 <div type="textpart" subtype="subsection" n="6"><p><milestone unit="altsect" n="3.190"/>ἐν δὲ τῷ
#
# altjump 1 191 <lb n="161.11"/><milestone unit="altsect" n="3.191"/> Ἐριχθονίου δὲ ἀποθανόντος καὶ ταφέντος ἐν τῷ αὐτῷ
#
# altjump 1 193 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.193"/><lb n="161.25"/>Πανδίων δὲ γήμας Ζευξίππην τῆς μητρὸς τὴν ἀδελφὴν
#
# altjump 1 194 <lb n="162.5"/>τὴν ἑαυτοῦ θυγατέρα Πρόκνην.</p></div><milestone unit="altsect" n="3.194"/>
#
# altjump 1 195 <lb n="162.11"/><milestone unit="altsect" n="3.195"/> ἡ δὲ ἀναζητήσασα τὴν ἀδελφὴν κτείνει τὸν παῖδα
#
# altjump 1 196 <lb n="162.19"/><milestone unit="altsect" n="3.196"/> Πανδίονος δὲ ἀποθανόντος οἱ παῖδες τὰ πατρῷα
#
# altjump 1 197 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.197"/><lb n="163.3"/>Χθονίαν μὲν οὖν ἔγημε Βούτης, Κρέουσαν δὲ Ξοῦθος,
#
# altjump 1 198 <div type="textpart" subtype="subsection" n="5"><p><milestone unit="altsect" n="3.198"/>ἔχοντος οὖν αὐτοῦ κύνα
#
# altjump 1 199 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.199"/><lb n="163.20"/>Ὠρείθυιαν δὲ παίζουσαν ἐπὶ Ἰλισσοῦ ποταμοῦ ἁρπάσας
#
# altjump 1 200 <lb n="164.1"/> Τῆνον ὑφ᾽ Ἡρακλέους ἀπώλοντο.</p></div></div><milestone unit="altsect" n="3.200"/>
#
# altjump 1 201 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.201"/><lb n="164.8"/> Χιόνη δὲ Ποσειδῶνι μίγνυται. ἡ δὲ κρύφα τοῦ
#
# altjump 1 202 <lb n="164.14"/> θυγατέρων δίδωσιν.<milestone unit="altsect" n="3.202"/> ὁ δὲ καὶ τὴν ἀδελφὴν τῆς γαμηθείσης
#
# altjump 1 203 <lb n="164.22"/> διαλυσάμενος τὴν βασιλείαν παρέλαβε.</p></div><milestone unit="altsect" n="3.203"/>
#
# altjump 1 204 <lb n="165.8"/><milestone unit="altsect" n="3.204"/> γενομένης δὲ μετὰ τὴν σφαγὴν τῆς μάχης
#
# altjump 1 205 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.205"/>οὗτος μετὰ Κέκροπα βασιλεύων ὑπὸ τῶν
#
# altjump 1 206 <div type="textpart" subtype="subsection" n="4"><p><milestone unit="altsect" n="3.206"/><lb n="165.21"/>Πανδίονι δὲ ἐν Μεγάροις ὄντι παῖδες ἐγένοντο
#
# altjump 1 207 <lb n="166.1"/><milestone unit="altsect" n="3.207"/> γαμεῖ δὲ πρώτην μὲν Μήταν τὴν Ὁπλῆτος, δευτέραν
#
# altjump 1 208 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.208"/><lb n="166.7"/> ἀπορῶν δὲ τὸν χρησμὸν ἀνῄει πάλιν εἰς Ἀθήνας. καὶ
#
# altjump 1 209 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.209"/><lb n="166.16"/> αὐτὸς δὲ ἧκεν εἰς Ἀθήνας, καὶ τὸν τῶν Παναθηναίων
#
# altjump 1 210 <lb n="166.22"/>ἀπολέσθαι.</p></div><milestone unit="altsect" n="3.210"/>
#
# altjump 1 211 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.211"/>ἔχοντι γὰρ αὐτῷ πορφυρέων ἐν
#
# altjump 1 212 <div type="textpart" subtype="subsection" n="3"><p><milestone unit="altsect" n="3.212"/><lb n="167.14"/>χρονιζομένου δὲ τοῦ πολέμου, μὴ δυνάμενος ἑλεῖν
#
# altjump 1 213 <lb n="167.21"/><milestone unit="altsect" n="3.213"/> ὡς δὲ οὐδὲν ὄφελος ἦν τοῦτο, ἐχρῶντο περὶ ἀπαλλαγῆς.
#
# altjump 1 214 <lb n="168.6"/><milestone unit="altsect" n="3.214"/> κατεσκευάκει δὲ αὐτὸν Δαίδαλος ὁ Εὐπαλάμου
#
# altjump 1 215 <lb n="168.12"/> εὑρὼν ξύλον λεπτὸν ἔπρισε.</p></div><milestone unit="altsect" n="3.215"/>
#
# altjump 1 216 <lb n="168.19"/><milestone unit="altsect" n="3.216"/> Θησεὺς δὲ γεννηθεὶς ἐξ Αίθρας Αἰγεῖ παῖς, ὡς
#
# altjump 1 217 <div type="textpart" subtype="subsection" n="2"><p><milestone unit="altsect" n="3.217"/>πρῶτον μὲν γὰρ Περιφήτην τὸν Ἡφαίστου
#
# altjump 1 218 <div type="textpart" subtype="subsection" n="1"><p><milestone unit="altsect" n="3.218"/>δεύτερον δὲ κτείνει Σίνιν τὸν Πολυπήμονος
