# %%
import requests, time, re, csv

# Parameters
BASE_SEARCH = "https://www.loc.gov/search/"
PER_PAGE = 100
MAX_PAGES = 5      # Increase for deeper scan
SLEEP = 0.2
OUTPUT_CSV = "loc_iiif_books.csv"

IIIF_RE = re.compile(r"/iiif/|manifest\.json", re.IGNORECASE)

# Helpers
def iter_strings(obj):
    if isinstance(obj, dict):
        for v in obj.values():
            yield from iter_strings(v)
    elif isinstance(obj, list):
        for v in obj:
            yield from iter_strings(v)
    elif isinstance(obj, str):
        yield obj

def detect_iiif(json_obj):
    """Return (True, sample_url) if anything looks like an IIIF link."""
    for s in iter_strings(json_obj):
        if IIIF_RE.search(s):
            return True, s
    return False, None

def get_json(url, params=None):
    r = requests.get(url, params=params, timeout=20)
    r.raise_for_status()
    return r.json()

# Main loop
total_examined = 0
total_iiif = 0
records = []  # for CSV

print('starting')
for page in range(1, MAX_PAGES + 1):
    params = {
        "fo": "json",
        "c": PER_PAGE,
        "sp": page,
        "fa": "original_format:Book/Printed Material",
    }
    search_json = get_json(BASE_SEARCH, params=params)
    results = search_json.get("results", [])
    print('\nres',len(results))
    if not results:
        break
    
    for res in results:
        item_url = res.get("id")
        title = res.get("title", "")
        if not item_url:
            continue
        item_json_url = item_url + ("&" if "?" in item_url else "?") + "fo=json"
        try:
            item_json = get_json(item_json_url)
        except:
            continue

        total_examined += 1
        has_iiif, sample = detect_iiif(item_json or {})
        if has_iiif:
            total_iiif += 1
            records.append({
                "title": title,
                "loc_url": item_url,
                "iiif_sample": sample or ""
            })

        time.sleep(SLEEP)
    
    print(f"Page {page}: examined={total_examined}, IIIF-ish={total_iiif}")

print('RUNNING')
# Write CSV
with open(OUTPUT_CSV, "w", newline='', encoding="utf-8") as f:
    print('in loop')
    writer = csv.DictWriter(f, fieldnames=["title", "loc_url", "iiif_sample"])
    writer.writeheader()
    writer.writerows(records)

print("\n=== Summary ===")
print(f"Examined items: {total_examined}")
print(f"Likely IIIF-enabled items: {total_iiif}")
print(f"CSV saved to {OUTPUT_CSV}")
# Out:
# starting
# [{'access_restricted': False, 'aka': ['http://www.loc.gov/item/sn87060004/1898-12-08/ed-1/', 'http://www.loc.gov/resource/sn87060004/1898-12-08/ed-1/'], 'batch': ['kyu_aluminum_ver01'], 'campaigns': [], 'composite_location': ['0/united states/', '1/united states/kentucky/', '2/united states/kentucky/hopkins/', '3/united states/kentucky/hopkins/earlington/'], 'contributor': ['university of kentucky, lexington, ky'], 'date': '1898-12-08', 'dates': ['1898-12-08'], 'description': ['Earlington, Ky.'], 'digitized': True, 'extract_timestamp': '2025-07-21T10:34:47.330Z', 'group': ['ndnp/kyu', 'university-of-kentucky-lexington-ky-awardee'], 'hassegments': True, 'id': 'http://www.loc.gov/item/sn87060004/1898-12-08/ed-1/', 'image_url': ['https://tile.loc.gov/image-services/iiif/service:ndnp:kyu:batch_kyu_aluminum_ver01:data:sn87060004:0017504615A:1898120801:0449/full/pct:6.25/0/default.jpg#h=492&w=377', 'https://tile.loc.gov/image-services/iiif/service:ndnp:kyu:batch_kyu_aluminum_ver01:data:sn87060004:0017504615A:1898120801:0449/full/pct:12.5/0/default.jpg#h=984&w=754'], 'index': 1, 'item': {'batch': ['kyu_aluminum_ver01'], 'call_number': ['Newspaper'], 'contributor_names': ['University of Kentucky, Lexington, KY'], 'created_published': ['Earlington, Ky., December 8, 1898'], 'date': '1889', 'date_issued': '1898-12-08', 'dates': ['1898-12-08'], 'digitized_label': 'Present', 'format': ['newspaper'], 'genre': ['Newspapers'], 'language': ['eng'], 'library_of_congress_control_number': 'sn87060004', 'location': ['Earlington (Ky.)', 'Hopkins County (Ky.)', 'Kentucky--Earlington', 'Kentucky--Hopkins County'], 'medium': '6 pages', 'newspaper_title': ['The bee'], 'notes': ['Semiweekly', 'Began in 1889.', 'Archived issues are available in digital forma as part of the Library of Congress Chronicling America online collection.', 'Description based on: 3rd year, no. 21 (Apr. 28, 1892).', 'Earlington news (DLC)sn 87060005 (OCoLC)15057343'], 'other_formats': ['https://tile.loc.gov/storage-services/service/ndnp//kyu/batch_kyu_aluminum_ver01/data/sn87060004/0017504615A/1898120801/1898120801_1.xml', 'http://lccn.loc.gov/sn87060004/marcxml'], 'place_of_publication': 'Earlington, Ky.', 'raw_lccn': 'sn 87060004 ', 'reel_numbers': ['0017504615a'], 'source_group': 'ndnp/kyu', 'subjects': ['Earlington (Ky.)--Newspapers', 'Hopkins County (Ky.)--Newspapers', 'Kentucky--Earlington', 'Kentucky--Hopkins County', 'United States--Kentucky--Hopkins--Earlington'], 'title': 'The bee (Earlington, Ky.), December 8, 1898'}, 'language': ['english'], 'location': ['united states', 'hopkins', 'hopkins county', 'earlington', 'kentucky'], 'location_city': ['earlington'], 'location_country': ['united states'], 'location_county': ['hopkins'], 'location_state': ['kentucky'], 'method': 'mets_filesec', 'mime_type': ['image/jp2', 'application/pdf', 'text/xml', 'image/jpeg'], 'number': ['1', '0017504615a', 'sn87060004'], 'number_edition': ['1'], 'number_lccn': ['sn87060004'], 'number_reel': ['0017504615a'], 'numeric_shelf_id': 189812081, 'online_format': ['image', 'pdf', 'online text'], 'original_format': ['newspaper'], 'partof': ['chronicling america', 'serial and government publications division', 'the bee (earlington, ky.) 1889-19??'], 'partof_collection': ['chronicling america'], 'partof_division': ['serial and government publications division'], 'partof_title': ['the bee (earlington, ky.) 1889-19??'], 'publication_frequency': ['semiweekly'], 'resources': [{'files': 6, 'image': 'https://tile.loc.gov/image-services/iiif/service:ndnp:kyu:batch_kyu_aluminum_ver01:data:sn87060004:0017504615A:1898120801:0449/full/pct:6.25/0/default.jpg', 'search': 'https://www.loc.gov/search/?c=100&fa=segmentof:sn87060004/1898-12-08/ed-1/&fo=json&st=gallery', 'segments': 6, 'url': 'https://www.loc.gov/resource/sn87060004/1898-12-08/ed-1/', 'word_coordinates': 'https://tile.loc.gov/text-services/word-coordinates-service'}], 'segments': [{'count': 6, 'link': 'https://www.loc.gov/search/?c=100&fa=segmentof:s ...
