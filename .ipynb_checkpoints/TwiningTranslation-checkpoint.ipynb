# %%
twining_alignment_keys = {
    "MY design is to treat of POETRY in general": "1.1",
    "Epic Poetry, Tragedy, Comedy, Dithyrambics": "1.2",
    "differing, however, from each other in three respects": "1.3",
    "For, as men, some through art, and some through habit": "1.4",
    "For example: in the imitations of the flute": "1.5",
    "In those of Dance, rhythm alone, without melody": "1.6",
    "The EPOPOEIA imitates by words alone, or by verse": "1.7",
    "For we should, otherwise, have no general name": "1.8",
    "or Poems in Iambic, Elegiac, or other metres": "1.9",
    "Custom, indeed, connecting the poetry or making with the metre": "1.10",
    "For even they, who compose treatises of medicine": "1.11",
    "So, also, though any one should chuse to convey his imitation": "1.12",
    "There are, again, other species of Poetry which make use": "1.13",
    "And such are the differences of these arts": "1.14",
    "But, as the objects of imitation are the actions of men": "2.1",
    "just as, in Painting, the pictures of Polygnotus": "2.2",
    "Now it is evident that each of the imitations": "2.3",
    "This may be the case with Dancing": "2.4",
    "and, also, with the Poetry which employs words": "2.5",
    "So, again, with respect to Dithyrambics, and Nomes": "2.6",
    "Tragedy, also, and Comedy, are distinguished": "2.7",
    "There remains the third difference": "3.1",
    "For the Poet, imitating the same object": "3.2",
    "These, then, are the three differences": "3.3",
    "so that Sophocles is, in one respect, an imitator": "3.4",
    "Upon this it is that the Dorians ground their claim": "3.5",
    "They allege, that the Doric word for a village is COME": "3.6",
    "And thus much as to the differences of imitation": "3.7",
    "POETRY, in general, seems to have derived its origin": "4.1",
    "1. TO IMITATE is instinctive in man from his infancy": "4.2",
    "This is evident from what we experience": "4.3",
    "And the reason of this is, that to learn, is a natural pleasure": "4.4",
    "Hence the pleasure they receive from a picture": "4.5",
    "For if we suppose the object represented to be something": "4.6",
    "Imitation, then, being thus natural to us, and, 2ndly, MELODY": "4.7",
    "But this Poetry, following the different characters": "4.8",
    "Of the lighter kind, we have no Poem anterior": "4.9",
    "but, from his time, we have; as, his Margites": "4.10",
    "And thus these old Poets were divided into two classes": "4.11",
    "And as, in the serious kind, HOMER alone may be said": "4.12",
    "But when Tragedy and Comedy, had once made their appearance": "4.13",
    "Both Tragedy, then, and Comedy, having originated": "4.14",
    "TRAGEDY, after various changes, reposed at length": "4.15",
    "ÆSCHYLUS first added a second actor": "4.16",
    "It was also late before Tragedy threw aside the short": "4.17",
    "The Iambic measure was then first adopted": "4.18",
    "For the iambic is, of all metres, the most colloquial": "4.19",
    "Episodes were, also, multiplied": "4.20",
    "to enter into a minute detail would, perhaps, be a task": "4.21",
    "COMEDY, as was said before, is an imitation of bad characters": "5.1",
    "since it may be defined to be a fault or deformity": "5.2",
    "The successive improvements of Tragedy": "5.3",
    "From the time, indeed, when it began to acquire": "5.4",
    "Epicharmus and Phormis were the first who invented": "5.5",
    'But, <pb n="74"/> of Athenian Poets, Crates was the first': "5.6",
    "Epic Poetry agrees so far with Tragic": "5.7",
    "It also differs in length": "5.8",
    "This, however, at first, was equally the case": "5.9",
    "Of their constituent parts, some are common": "5.10",
    "He, therefore, who is a judge of the beauties": "5.11",

    # Section 1
    "OF the species of Poetry which imitates in hexameters": "6.1",
    "Tragedy, then, is an imitation of some action that is important": "6.2",
    "By pleasurable language, I mean a language that has the embellishments": "6.3",
    "And I add, by different means in different parts": "6.4",
    
    # Section 2
    "Now as Tragedy imitates by acting, the DECORATION": "6.5",
    'By diction<note n="2" place="foot">Not ': "6.6",
    "Again—Tragedy being an imitation of an action, and the persons": "6.7",
    "The imitation of the action is the FABLE": "6.8",
    "Hence, all Tragedy must necessarily contain six parts": "6.9",
    "Of these parts, two relate to the means": "6.10",
    "And these are all. These specific parts": "6.11",
    
    # Section 3
    "But of all these parts the most important is the combination": "6.12",
    "Tragedy, therefore, does not imitate action, for the sake": "6.13",
    "Again—Tragedy cannot subsist without action; without manners it may": "6.14",
    "the Tragedies of most modern Poets have this defect": "6.15",
    "Farther—suppose any one to string together a number of speeches": "6.16",
    "Add to this, that those parts of Tragedy, by means of which it becomes": "6.17",
    "As a farther proof, adventurers in Tragic writing are sooner able": "6.18",
    "The fable, then, is the principal part, the soul": "6.19",
    "Tragedy being an imitation of an action, and through": "6.20",
    "In the third place stand the SENTIMENTS. To this part it belongs": "6.22",  # Note: 6.20 is skipped / omitted in Twining's section breaks here
    "the antients made their characters speak in the style": "6.23",
    "The manners are, whatever manifests the disposition of the speaker": "6.24",
    "The sentiments comprehend whatever is said; whether proving": "6.25",
    "Fourth, in order, is the DICTION; that is, as I have already said": "6.26",
    "Of the remaining two parts, the MUSIC stands next": "6.27",
    "The DECORATION has, also, a great effect, but, of all the parts": "6.28",
    
    # Section 4
    "These things being thus adjusted, let us go on to examine": "7.1",
    "Now we have defined Tragedy to be an imitation of an action that is complete": "7.2",
    "1. By entire, I mean that which has a beginning, a middle, and an end": "7.3",
    "A beginning, is that which does not, necessarily, suppose": "7.4",
    "An end, on the contrary, is that which supposes something to precede": "7.5",
    "A middle, is that which both supposes something to precede": "7.6",
    "The Poet, therefore, who would construct his fable properly": "7.7",
    "2. Again: whatever is beautiful, whether it be an animal": "7.8",
    "Hence it is that no very minute animal can be beautiful": "7.9",
    "so, in the fable, a certain length is requisite": "7.10",
    "With respect to the measure of this length—if referred to actual representation": "7.11",
    "But, if we determine this measure by the nature of the thing": "7.12",
    
    # Section 5
    "A fable is not one, as some conceive it to be, merely because the hero": "8.1",
    "Hence appears the mistake of all those Poets who have composed HERCULEIDS": "8.2",
    "But HOMER, among his many other excellences, seems also to have been perfectly aware": "8.3",
    "As, therefore, in other mimetic arts, one imitation is an imitation of one thing": "8.4",
    
    # Section 6
    "It appears, farther, from what has been said, that it is not the Poet's province": "9.1",
    "For it is not by writing in verse, or prose, that the Historian": "9.2",
    "On this account, Poetry is a more philosophical, and a more excellent thing": "9.3",
    "In what manner, for example, any person of a certain character would speak": "9.4",
    "With respect to Comedy, this is now become obvious": "9.5",
    "Tragedy, indeed, retains the use of real names": "9.6",
    "There are, however, some Tragedies in which one or two of the names are historical": "9.7",
    "It is by no means, therefore, essential, that a Poet should confine himself": "9.8",
    "From all this it is manifest, that a Poet should be a Poet": "9.9",
    "nor is he the less a Poet, though the incidents of his fable should chance": "9.10",
    
    # Section 7
    "Of simple fables or actions, the episodic are the worst": "9.11",
    "a fault into which bad Poets are betrayed by their want of skill": "9.11b",
    "But Tragedy is an imitation, not only of a complete action, but also of an action exciting terror": "9.11c",
    "for, by this means, they will have more of the wonderful": "9.12",
    "It follows then, that such fables as are formed on these principles": "9.13",
    
    # Section 8
    "Fables are of two sorts, simple and complicated": "10.1",
    "An action, (having the continuity and unity prescribed,) I call simple": "10.2",
    "complicated, when with one, or both": "10.3",
    "And these should arise from the structure of the fable itself": "10.4",
    
    # Section 9
    "A REVOLUTION, is a change, (such as has already been mentioned": "11.1",
    "Thus, in the Oedipus": "11.2",
    'Thus, also, <pb n="85"/> in the Tragedy of Lynceus': "11.3",
    "A DISCOVERY, as, indeed, the word implies, is a change from unknown to known": "11.4",
    "The best sort of Discovery is that which is accompanied by a Revolution": "11.5",
    "There are, also, other Discoveries; for inanimate things": "11.6",
    "but the Discovery most appropriated to the fable": "11.7",
    "Now Discoveries, being relative things, are sometimes of one of the persons": "11.8",
    "These then are two parts of the fable-Revolution and Discovery": "11.9",
    "Disasters comprehend all painful or destructive actions": "11.10",
    
    # Section 10
    "The parts of Tragedy which are necessary to constitute its quality": "12.1",
    "which last is also divided into the PARODE, and the STASIMON": "12.2",
    "The COMMOI are found in some only": "12.3",
    'The Prologue<note n="*" place="foot">Prologue-This may': "12.4",
    'The Episode<note n="*" place="foot">Episode-i. e. a': "12.5",
    'The Exode<note n="*" place="foot">Exode-i. e. the going out, or exit:': "12.6",
    "Of the Choral part, the Parode": "12.7",
    "the Stasimon<note": "12.8",
    "The Commos<note": "12.9",
    "Such are the separate parts into which Tragedy is divided": "12.10",

    # Section 11
    "The order of the subject leads us to consider, in the next place": "13.1",
    "Now since it is requisite to the perfection of a Tragedy that its plot should be of the complicated": "13.2",
    "Neither should the contrary change, from adversity to prosperity, be exhibited in a vitious character": "13.3",
    "Nor, again, should the fall of a very bad man from prosperous to adverse fortune be represented": "13.4",
    "There remains, then, for our choice, the character between these extremes": "13.5",

    # Section 12
    "Hence it appears, that, to be well constructed, a fable, contrary to the opinion of some, should be single": "13.6",
    "These principles are confirmed by experience; for Poets, formerly, admitted almost any story": "13.7",
    "The most perfect Tragedy, then, according to the principles of the art, is of this construction": "13.8",
    "Whence appears the mistake of those critics who censure EURIPIDES for this practice": "13.9",
    "And, as the strongest proof of it, we find that upon the stage, and in the dramatic contests": "13.10",
    "I place in the second rank, that kind of fable to which some assign the first": "13.11",
    "That this passes for the best, is owing to the weakness of the spectators": "13.12",
    "This kind of pleasure, however, is not the proper pleasure of Tragedy": "13.13",

    # Section 13
    "Terror and pity may be raised by the decoration-the mere spectacle": "14.1",
    "For the fable should be so constructed, that, without the assistance of the sight": "14.2",
    "But, to produce this effect by means of the decoration, discovers want of art": "14.3",
    "As to those Poets, who make use of the decoration in order to produce, not the terrible": "14.4",
    "Since, therefore, it is the business of the Tragic Poet to give that pleasure": "14.5",

    # Section 14
    "Let us, then, see, of what kind those incidents are, which appear most terrible, or piteous": "14.6",
    "If an enemy kills, or purposes to kill, an enemy, in neither case is any commiseration": "14.7",
    "The case is the same, when the persons are neither friends nor enemies": "14.8",
    "But when such disasters happen between friends-when, for instance, the brother kills": "14.9",
    "The received Tragic subjects, therefore, he is not at liberty essentially to alter": "14.10",
    "but it is his province to invent other subjects, and to make a skilful use": "14.11",
    "The atrocious action may be perpetrated knowingly and intentionally": "14.12",
    "It may, likewise, be perpetrated by those, who are ignorant, at the time": "14.13",
    "There is yet a third way, where a person upon the point of perpetrating, through ignorance": "14.14",
    "Beside these, there is no other proper way. For the action must of necessity": "14.15",
    "but of all these ways": "14.16",
    "Next to this, is the actual execution of the purpose": "14.17",
    "To execute, through ignorance, and afterwards to discover, is better": "14.18",
    "But the best of all these ways, is the last. Thus, in the Tragedy of Cresphontes": "14.19",
    "On this account it is, that the subjects of Tragedy, as before remarked, are confined": "14.20",
    "Of the PLOT, or FABLE, and its requisites, enough has now been said": "14.21",

    # Section 15
    "With respect to the MANNERS, four things are to be attended to by the Poet": "15.1",
    "First, and principally, they should be good. Now manners, or character, belong": "15.2",
    "This goodness of manners may be found in persons of every description": "15.3",
    "The second requisite of the manners, is propriety": "15.4",
    "The third requisite is resemblance; for this is a different thing": "15.5",
    "The fourth, is uniformity; for even though the model of the Poet's imitation": "15.6",
    "We have an example of manners unnecessarily bad, in the character of Menelaus": "15.7",
    "of improper and unbecoming manners": "15.8", # Note: Twining reads 'lamentation' in translation but his footnote glosses this text
    "of ununiform manners, in the Iphigenia": "15.9",
    "In the manners, as in the fable, the Poet should always aim, either at what is necessary": "15.10",
    "Hence it is evident, that the development also of a fable should arise out of the fable itself": "15.10b",
    "The proper application of machinery is to such circumstances, as are extraneous to the drama": "15.10c",
    "But nothing improbable should be admitted in the incidents of the fable": "15.10d",
    "Since Tragedy is an imitation of what is best, we should follow the example of skilful portrait-painters": "15.11",
    "These things the Poet should keep in view; and, besides these, whatever relates to those senses": "15.12",

    # Section 16
    "What is meant by a DISCOVERY, has already been explained. Its kinds are the following": "16.1",
    "First, the most inartificial of all, and to which, from poverty of invention, the generality": "16.2",
    "others are adventitious; and of these, some are corporal, as scars-some external": "16.3",
    'Even <pb n="96"/> these, however': "16.4",
    "For all those discoveries, in which the sign is produced by way of proof, are inartificial": "16.5",
    "Secondly-Discoveries invented, at pleasure, by the Poet, and, on that account, still inartificial": "16.6",
    "Another instance, is the discovery by the sound of the shuttle in the Tereus of SOPHOCLES": "16.7",
    "Thirdly-The Discovery occasioned by memory; as, when some recollection is excited": "16.8",
    "Fourthly-The Discovery occasioned by reasoning or inference": "16.9",
    "There is also a compound sort of discovery, arising from false inference in the audience": "16.10",
    "But, of all Discoveries, the best is that, which arises from the action itself": "16.11",
    "Next to these, are the discoveries by inference": "16.12",

    # Section 17
    "The Poet, both when he plans, and when he writes, his Tragedy, should put himself": "17.1",
    "The fault objected to Carcinus is a proof of this": "17.2",
    "In composing, the Poet should even, as much as possible, be an actor": "17.3",
    "Hence it is, that Poetry demands, either great natural quickness of parts, or an enthusiasm": "17.4",
    "When the Poet invents a subject, he should, first, draw a general sketch of it": "17.5",
    "The general argument, for instance,": "17.6",
    "After this, the Poet, when he has given names to his characters, should proceed to the Episodes": "17.7",
    "and he must take care, that these belong properly to the subject": "17.8",
    "In dramatic Poetry the Episodes are short; but, in the Epic, they are the means": "17.9",
    "The general story of the ODYSSEY, for example, lies in a small compass": "17.10",
    "This is the essential; the rest is Episode": "17.11",

    # Section 18
    "Every Tragedy consists of two parts-the complication, and the development": "18.1",
    "I call complication, all that is between the beginning of the piece": "18.2",
    "Thus, in the Lynceus of Theodectes, the events antecedent to the action": "18.3",

    # Section 19
    "There are four kinds of Tragedy, deducible from so many parts, which have been mentioned": "18.4",
    "One kind is the COMPLICATED; where all depends on revolution and discovery": "18.5",
    "another is the DISASTROUS": "18.6",
    "another, the ": "18.7",
    "and, fourthly, the SIMPLE, such as the Phorcides": "18.8",
    'It <pb n="101"/> should': "18.9",
    "One Tragedy may justly be considered as the same with another, or different": "18.10",
    "Many Poets, when they have complicated well, develop badly": "18.11",
    "They should endeavour to deserve equal applause in both": "18.12",

    # Section 20
    "We must also be attentive to what has been often mentioned": "18.13",
    "In the Epic Poem, the length of the whole admits of a proper magnitude in the parts": "18.14",
    "As a proof of this, those Poets, who have formed the whole of the destruction of Troy": "18.15",
    "Even Agatho has failed on this account, and on this only": "18.16",
    "as when, for example, a character of great wisdom, but without integrity, is deceived": "18.17",
    "Such events, as Agatho says, are probable": "18.18",
    "The CHORUS should be considered as one of the persons in the drama": "18.19",
    "As for other Poets-their": "18.20",
    # Section 21
    #"Yet where is the difference, between this arbitrary insertion of an Ode": "18.20", # Continuing the end of Kassel 18th chapter

    # Section 22
    "Of the other parts of Tragedy enough has now been said. We are next to consider": "19.1",
    "For what concerns the sentiments, we refer to the principles laid down": "19.2",
    "The sentiments include whatever is the object of speech": "19.3",
    "as, for instance, to prove, to confute, to move the passions": "19.4",
    "But it is evident, that, with respect to the things themselves also": "19.5",
    "with this difference only, that, in the drama, these things must appear": "19.6",

    # Section 23
    "With respect to DICTION, one part of its theory is that, which treats": "19.7",
    "The Poet's knowledge, or ignorance, of these things, cannot any way": "19.8",
    "This subject, therefore, we pass over, as belonging to an art distinct": "19.9",

    # Section 24
    "TO ALL DICTION, belong the following parts:-the letter, the syllable": "20.1",
    "A letter is an indivisible sound; yet not all such sounds are letters": "20.2",
    "Letters are of three kinds; vowels, semivowels, and mutes": "20.3",
    "These all differ from each other, as they are produced by different configurations": "20.4",
    "A syllable, is a sound without signification, composed of a mute and a vowel": "20.5",
    "A conjunction, is a sound without signification": "20.6",
    "An article, is a sound without signification, which marks the beginning": "20.7",
    "A noun, is a sound, composed of other sounds; significant, without expression of time": "20.8",
    "A verb, is a sound composed of other sounds;-significant-with expression of time": "20.9",
    "Cases belong to nouns and verbs": "20.10",
    "Discourse, or speech, is a sound significant, composed of other sounds": "20.11",
    "for all discourse is not composed of verbs and nouns": "20.12",
    "A discourse <pb n=": "20.13",

    # Section 25
    "Of WORDS, some are single-by which I mean, composed of parts not significant": "21.1",
    "of which last, some have one part significant, and the other not significant": "21.2",
    "A word may also be triple, quadruple,": "21.3",
    "Every word is either common, or foreign, or metaphorical, or ornamental": "21.4",
    "By COMMON words, I mean, such as are in general and established, use": "21.5",
    "By FOREIGN, such as belong to a different language": "21.6",
    "A METAPHORICAL<note ": "21.7",
    "1. From genus to species: as, Secure in yonder port my vessel STANDS": "21.8",
    "2. From <pb n=": "21.9",
    "3. From one species to another": "21.10",
    "4. In the way of analogy-when, of four terms, the second bears the same relation": "21.11",
    "And, sometimes, the proper term is also introduced, besides its relative term": "21.12",
    "Again-evening being to day, what old age is to life": "21.13",
    "It sometimes happens, that there is no proper analogous term, answering": "21.14",
    "There is, also, another way of using this kind of metaphor": "21.15",
    "as if, instead of calling a shield the cup of Mars, we should call it the wineless cup": "21.16",
    "An INVENTED word, is a word never before used by any one, but coined by the Poet": "21.17",
    "A word is EXTENDED, when for the proper vowel a longer is substituted": "21.18",
    "contracted, such as KPI": "21.19",
    "An ALTERED word, is a word, of which part remains in its usual state": "21.20",
    "Farther;- <pb n=": "21.21",
    "The masculine are those which end in ν, ρ, σ": "21.22",
    "The feminine, are those which end in the vowels always long, as η, or ω": "21.23",
    "so that the masculine and the feminine terminations are equal in number": "21.24",
    "No noun ends in a mute, or a short vowel": "21.25",
    "There are but three ending in ι; μελι, κομμι, πεπερι": "21.26",

    # Section 26
    "The excellence of diction consists in being perspicuous without being mean": "22.1",
    "The most perspicuous is that which is composed of common words": "22.2",
    "That language, on the contrary, is elevated, and remote from the vulgar idiom": "22.3",
    "Yet, should a Poet compose his diction entirely of such words": "22.4",
    "For the essence of an aenigma consists in putting together things apparently inconsistent": "22.5",
    "With respect to barbarism, it arises from the use of foreign words": "22.6",
    "A judicious intermixture is, therefore, requisite": "22.7",
    "But nothing contributes more considerably to produce clearness": "22.8",
    "It is without reason, therefore, that some critics have censured these modes": "22.9",
    "Undoubtedly, when these licences appear to be thus purposely used": "22.10",
    "In the employment of all the species of unusual words, moderation is necessary": "22.11",
    "But how great a difference is made by a proper and temperate use": "22.12",
    "Let any one only substitute common words in the place of the metaphorical": "22.13",
    "Ariphrades, also, endeavoured to throw ridicule upon the Tragic Poets": "22.14",
    "Now it is precisely owing to their being not in common use": "22.15",
    "To employ with propriety any of these modes of speech-the double words": "22.16",
    "but the greatest of all, is to be happy in the use of metaphor": "22.17",
    "Of the different kinds of words, the double are best suited to Dithyrambic": "22.18",
    "In Heroic Poetry, indeed, they have all their place; but to Iambic verse": "22.19",
    "Concerning TRAGEDY, and the imitation by ACTION, enough has now been said": "22.20",
    # Section 1
    "WITH respect to that species of Poetry which imitates by NARRATION": "23.1",
    "widely differing, in its construction, from history": "23.2",
    "For, as the naval action at Salamis, and the battle with the Carthaginians": "23.3",
    "And this is the practice of the generality of Poets": "23.4",
    "Even in this, therefore, as we have before observed": "23.5",
    "Other Poets take for their subject the actions of one person": "23.6",
    "Hence it is, that the ILIAD, and the ODYSSEY, each of them, furnish matter": "23.7",
    "Again-the Epic Poem must also agree with the Tragic": "24.1",
    "Its parts, also, setting aside Music": "24.2",
    "of all which HOMER gave both the first": "24.3",

    # Section 2
    "The Epic Poem differs from Tragedy, in the length of its plan, and in its metre": "24.4", # Kassel switches order slightly here relative to Twining's structure
    "With respect to length, a sufficient measure has already been assigned": "24.5",
    "But there is a circumstance in the nature of Epic Poetry which affords it peculiar latitude": "24.6",
    "And this gives it a great advantage, both in point of magnificence": "24.7",
    "With respect to metre, the heroic is established by experience as the most proper": "24.8",
    "For the heroic is the gravest and most majestic of all measures": "24.9",
    "But the Iambic and Trochaic have more motion": "24.10",
    "To mix these different metres, as Chaeremon has done, would be still more absurd": "24.11",
    "No one, therefore, has ever attempted to compose a Poem of an extended plan": "24.12",

    # Section 3
    "Among the many just claims of HOMER to our praise, this is one": "24.13",
    "The Poet, in his own person, should speak as little as possible": "24.14",

    # Section 4
    "The surprising is necessary in Tragedy": "24.15",
    "The circumstances, for example, of the": "24.16",
    "Now the wonderful always pleases; as is evident from the additions": "24.17",

    # Section 5
    "It is from HOMER principally, that other Poets have learned the art of feigning well": "24.18",

    # Section 6
    "The Poet should prefer impossibilities which appear probable, to such things": "24.19",
    "Far from <pb n=": "24.20",
    "To say, that without these circumstances the fable would have been destroyed": "24.21",
    "Thus in the Odyssey<note": "24.22",
    "The Diction should be most laboured in the idle parts of the Poem": "24.23",
    # Section 1
    "WITH respect to CRITICAL OBJECTIONS": "25.1",
    "1. The Poet, being an imitator, like the painter or any other artist": "25.2",
    "2. Again: all this he is to express in words, either common, or foreign": "25.3",
    "3. To this we must add, that what is right in the Poetic art": "25.4",
    "The faults of Poetry are of two kinds, essential and accidental": "25.5",
    "If the Poet has undertaken to imitate without talents for imitation": "25.6",
    
    # Section 2
    "To the foregoing considerations, then, we must have recourse": "25.7",
    #"For, in the first place, suppose the Poet to have represented things impossible": "25.7", # Parallel structural transition in Twining
    "Yet it may be an excusable fault": "25.8",
    "The pursuit of Hector is an instance": "25.9",
    "Still we are to consider, farther, whether a fault be in things essential": "25.10",
    "If it be objected to the Poet, that he has not represented things conformably": "25.11",
    "But if the Poet has represented things in neither of these ways": "25.12",
    #"Of this kind are the poetical descriptions of the Gods": "25.12",
    "It cannot, perhaps, be said, that they are either what is best": "25.13",
    "Again-What the Poet has exhibited is, perhaps, not what is best": "25.14",
    
    # Section 4 (Note: Twining labels the next section chunk as IV, stepping over III in his header sequence)
    "In order to judge whether what is said, or done, by any character, be well": "25.15",
    
    # Section 5
    "For the solution of some objections, we must have recourse to the Diction": "25.16",
    #"This may be defended by saying, that the Poet has, perhaps, used the word ουρηας": "25.16",
    "2. The following passages may be defended by METAPHOR": "25.17",
    "3. To ACCENT: as the following passage": "25.18",
    "4. To PUNCTUATION; as in this passage of Empedocles": "25.19",
    "5. To AMBIGUITY; as in παρωχηκεν δε ΠΛΕΩΝ νυξ": "25.20",
    "6. To CUSTOMARY SPEECH: thus, wine mixed with water": "25.21",
    "7. When a word, in any passage, appears to express a contradiction": "25.22",
    #"the meaning is, was stopped only, or repelled": "25.22",
    "Of how many different senses a word is capable, may best be discovered": "25.23",
    "We may also say, with Glauco, that some critics, first take things for granted": "25.24",
    "Of this kind is the cavil of the critics concerning Icarius": "25.25",
    
    # Section 6
    "The Impossible, in general, is to be justified by referring": "25.26",
    "For, with respect to Poetry, impossibilities, rendered probable": "25.27",
    "With respect also to what is best, the imitations of Poetry should resemble": "25.28",
    "To opinion, or what is commonly said to be, may be referred": "25.29",
    
    # Section 7
    "When things are said, which appear to be contradictory, we must examine them": "25.30",
    
    # Section 8
    "Improbability, and vitious manners, when excused by no necessity": "25.31",
    "Thus, the sources from which the critics draw their objections are five": "25.32",
    #"The answers, which are twelve in number, may be deduced from what has been said": "25.32",
    # Section 1
    "IT may be inquired, farther, which of the two imitations": "26.1",
    "If that, which is the least vulgar, or popular, of the two, be the best": "26.2",
    #"the imitation, which extends to every circumstance, must, evidently, be the most vulgar": "26.2",
    "for there, the imitators have recourse to every kind of motion and gesticulation": "26.3",
    "Such is Tragedy. It may also be compared to what the modern actors are": "26.4",
    #"What these performers are with respect to their predecessors": "26.4",
    "The latter, then, it is urged, addresses itself to hearers of the better sort": "26.5",

    # Section 2
    "But now, in the first place, this censure falls, not upon the Poet's art": "26.6",
    "Again-All gesticulation is not to be condemned; since even all dancing is not": "26.7",
    "Farther-Tragedy, as well as the Epic, is capable of producing its effect": "26.8",
    #"If, then, in other respects, Tragedy be superior, it is sufficient": "26.8",

    # Section 3
    "Tragedy has the advantage in the following respects. It possesses all that is possessed": "26.9",
    "and to this it makes no inconsiderable addition, in the Music and the Decoration": "26.10",
    "It has the advantage of greater": "26.11",
    "It has also that, of attaining the end of its imitation in a shorter compass": "26.12",
    "Farther-there is less unity in all Epic imitation; as appears from this": "26.13",
    "The Iliad, for example, and the Odyssey contain many such subordinate parts": "26.14",

    # Section 4
    "If then TRAGEDY be superior to the EPIC in all these respects": "26.15",
    "AND THUS MUCH concerning TRAGIC and EPIC Poetry in general": "26.16"
}

# %%
import re

f = open('/Users/gcrane/github/Poetics2.0/eng/twining.poetics-1789.xml')
#outf = open('/Users/gcrane/github/Poetics2.0/eng/aristotle.poetics.twining1789-eng2.xml','w')
exit
usetext = f.read()
f.close()

prevsectn = 0

prevchap = ''
for foo in twining_alignment_keys:
    curchap,cursect = twining_alignment_keys[foo].split('.')
    #print(curchap,cursect)
    if(not prevchap == curchap):
        prevsectn  = 0
    prevchap = curchap
    if(re.search('[a-z]',cursect)):
        continue
    cursectn = int(cursect)
    if(not cursectn == prevsectn + 1):
        print('skipped',curchap,cursect)
    prevsectn = cursectn
    
    
for foo in twining_alignment_keys:
    if(not usetext.count(foo) == 1 ):
        print(foo,usetext.count(foo))
    usetext = usetext.replace(foo,'<milestone unit="' + twining_alignment_keys[foo] + '"/>'+foo)

outf.write(usetext)

outf.close()
# Out:
# skipped 6 22
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 31
#      28         print(foo,usetext.count(foo))
#      29     usetext = usetext.replace(foo,'<milestone unit="' + twining_alignment_keys[foo] + '"/>'+foo)
# ---> 31 outf.write(usetext)
#      33 outf.close()
#
# ValueError: I/O operation on closed file.
