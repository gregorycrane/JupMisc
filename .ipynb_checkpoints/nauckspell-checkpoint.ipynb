# %%
curpage = 0
import re
from greek_normalisation.utils import (
     nfd, nfc, nfkc,
     strip_accents, count_accents, strip_last_accent, grave_to_acute,
     strip_last_accent_if_two, breathing_check, convert_to_2019
 )
pagebuf = {}
nauckpages = {}
wordindex = {}
xmlindex = {}
wordtots = {}
g2r = {
    'Α' : 'A',
    'Β' : 'B',
    'Ε' : 'E',
    'Ζ' : 'Z',
    'Η' : 'H',
    'Ι' : 'I',
    'Κ' : 'K',
    'Μ' : 'M',
    'Ν' : 'N',
    'Ο' : 'O',
    'Ρ' : 'P',
    'Τ' : 'T',
    'Χ' : 'X',
}
g2rreg = '(['
for foo in g2r:
    g2rreg = g2rreg + foo 
g2rreg = g2rreg + '])'

r2g = {}
for foo in g2r:
    r2g[g2r[foo]] = foo

    
for i in range(3,959):
    #if(i> 913 and i< 948):
        
    #    continue
    if(i<10):
        fname = '../../Downloads/nauck/000' + str(i) + '.txt'
    elif(i<100):
        fname = '../../Downloads/nauck/00' + str(i) + '.txt'
    elif(i<1000):
        fname = '../../Downloads/nauck/0' + str(i) + '.txt'
    else:
        fname = '../../Downloads/nauck/' + str(i) + '.txt'
    
    f = open(fname)
    curbuf = ''
    for l in f:
       # if(re.search('ΑΛΕΑΔΑΙ',l)):
       #     print('0',l)
        while(re.search('([Α-Ω])([A-Z])',l)):
            m = re.search('([Α-Ω])([A-Z])',l)
            if(m):
                #print(m[1],m[2],l)
                curkey = m[1] + m[2]
                curroman = m[1]
                if curroman in r2g:
                    cursub =  m[1] + r2g[curroman]
                else:
                    cursub = m[1] + '<1>' +  m[2]
                l = re.sub(curkey,cursub,l,1)
                #print(fname,'G+R',m[1],m[2],l,'\n')
        l = re.sub('<1>','',l)
        while(re.search('([0-9]+\s+|chol\.\s+)'+g2rreg+'\\b',l)):
            m = re.search('([0-9]+\s+|chol\.\s+)'+g2rreg+'\\b',l)
            if(m):
                #print(fname,'a',m[1],m[2],l)
                curkey = m[1] + m[2]
                cursub = m[1] + g2r[m[2]]
                l = re.sub(curkey,cursub,l,1)
       # if(re.search('ΑΛΕΑΔAI',l)):
       #     print('1a',l)
       # elif(re.search('ΑΛΕΑΔΑΙ',l)):
       #     print('stillok')
        while(re.search('\\b'+g2rreg+'(\\b|[:,\.a-zA-Z])',l)):
            m = re.search('\\b'+g2rreg+'(\\b|[:,\.a-zA-Z])',l)
            if(m):
                #print(m[1],m[2])
                curkey = m[1] + m[2]
                cursub = g2r[m[1]] + m[2] 
                l = re.sub(curkey,cursub,l,1)
       # if(re.search('ΑΛΕΑΔAI',l)):
       #     print('1',l)
        l = re.sub('\s+$','',l)
        if(re.search('(\\b[ΧΙ]+\\b)',l)):
            #print('rn',fname,l)
            while(re.search(g2rreg,l)):
                m = re.search(g2rreg,l)
                subval = g2r[m[1]]
                l = re.sub(m[1],subval,l)
            
        l = re.sub('\\bef\\b','cf',l)
        l = re.sub('[MΜ][AΑ]','MA',l)
        l = re.sub('˙','·',l)
        l = re.sub('·','·',l)
        l = re.sub('”,','’,',l)
        l = re.sub('^\s+','',l)
        l = re.sub('\s+','\n',l)
        l = re.sub('᾽','’',l)
        l = re.sub('Αι','Αἰ',l)
        l = re.sub('Ει','Εἰ',l)
        l = re.sub('Οι','Οἰ',l)
        l = re.sub('"Α','Ἄ',l)
        l = re.sub('\\bΡ','Ῥ',l)
        l = re.sub('”\.','῾.',l)
        l = re.sub('\\bΑ([βγδεζηθικλμνξοπρστυχφψω])','Ἀ\g<1>',l)
        l = re.sub('\\bΙ([βγδεζηθικλμνξοπρστυχφψω])','Ἰ\g<1>',l)
        l = re.sub('\\bΕ([βγδεζηθικλμνξοπρστυχφψω])','Ἐ\g<1>',l)
        l = re.sub('\\bΟ([βγδεζηθικλμνξοπρστυχφψω])','Ὀ\g<1>',l)
        l = re.sub('\\bΥ([βγδεζηθικλμνξοπρστυχφψω])','Ὑ\g<1>',l)
        l = re.sub('κτέ','κτἑ',l)
        l = re.sub('Σοφοκλ[ήὴ]ς','Σοφοκλῆς',l)
        #l = re.sub('Α([a-z])','A\g<1>', l)
        l = re.sub("\.'",".’",l)
        l = re.sub('·','·',l)
        #θέμιν’.	replace	θέμιν‘.
        l = re.sub('‘','’',l)
        # ignore mdashes
        #l = re.sub('—',' ', l)
      
        
        l = re.sub("([α-ω])'",'\g<1>’',l)
        l = re.sub("(᾿Ἀ|'Ἀ)","Ἀ",l)
        l = re.sub("\\bν\.",'v.',l)
        l = re.sub('Εust','Eust',l)
        l = re.sub('Ο([a-z])','O\g<1>',l)
        l = re.sub('῾','‘',l)
        l = re.sub('᾿','’',l)
        l = re.sub('[-]([A-ZΑ-Ω])','\g<1>',l)

        l = re.sub('Ἐι','Εἰ',l)
        l = re.sub('Ἀι','Αἰ',l)
        l = re.sub('Ὀι','Οἰ',l)

        l = re.sub('Ἐυ','Εὐ',l)
        l = re.sub('Ἀυ','Αὐ',l)
        l = re.sub('Ὀυ','Οὐ',l)

        if(curbuf):
            curbuf = curbuf + '\n' + l
        else:
            curbuf = l
    curbuf = re.sub('-\s+','',curbuf)

    
    usepage = str(i)
    pagebuf[usepage] = curbuf
    wordindex[usepage] = {}
    for foo in curbuf.split():
        wordindex[usepage][foo] = 1
    f.close()

pageoffset = 32
pageoffset2 = 66
# > 879

f = open('../GRC_misc/nauck.tragfrag.xml')
outf = open('../GRC_misc/nauck.tragfrag-2.xml','w')

for l in f:
    l = re.sub('\s+$','',l)
    m = re.search('([0-9]+\s+)'+g2rreg+'\\b',l)
    if(m):
        #print(m[1],m[2])
        curkey = m[1] + m[2]
        cursub = m[1] + g2r[m[2]]
        l = re.sub(curkey,cursub,l)

    if(re.search('·',l)):
        print('middot',l)
    print(l,file=outf)
outf.close()
f.close()

f = open('../GRC_misc/nauck.tragfrag-2.xml')
nauckbuf = re.sub('᾽','’',nfc(f.read()))
nauckbuf = re.sub('·','·',nauckbuf)
nauckbuf = re.sub('᾽','’',nauckbuf)
nauckbuf = re.sub('—',' ',nauckbuf)
nauckbuflist = nauckbuf.split('<pb n="')
for foo in nauckbuflist:
    m = re.search('(^[0-9IVXLC]+)',foo)
    if(m):
        foo = re.sub('<[/]*add>','',foo)
        foo = re.sub('<[^>]+>',' ',foo)
        foo = re.sub('\s+','\n',foo)
        nauckpages[m[1]] = foo
        xmlindex[m[1]] = {}
        for word in foo.split():
            xmlindex[m[1]][word] = 1
        #print(m[1])
f.close()

# %%
import difflib
tokenlist= []
def side_by_side_diff(fout,i,a: str, b: str, width=60):
    from itertools import zip_longest
    global tokenlist
    global wordindex
    global xmlindex

    a_lines = a.splitlines()
    b_lines = b.splitlines()
    sm = difflib.SequenceMatcher(None, a_lines, b_lines)

    tokennum = -1
    if(int(i)>947):
        curpage = str(int(i) + 66+3)
    elif(int(i)>879):
        curpage = str(int(i) + 66)
    else:
        curpage = str(int(i) + 32)

    curpage = str(i)

 
        
    for tag, i1, i2, j1, j2 in sm.get_opcodes():
        for left, right in zip_longest(a_lines[i1:i2], b_lines[j1:j2], fillvalue=''):
            print(i,left,tag,right,sep='\t',file=fout)
            continue
            if(i == '316'):
                print(i,left,tag,right,sep='\t')
            
            #if(left == '‘σὺ'):
            #    print('x',i,left,tag,right,sep='\t')
                
            if( tag == 'delete'):
                if(curpage in wordindex and left in wordindex[curpage]):
                    tag = tag + '2'
            if(tag == 'insert' ):
                if(i in xmlindex and right in xmlindex[i]):
                    tag = tag + '4'
                

            if(left == '' and right in wordindex[curpage] and tag == 'replace'):
                tag = tag + '5'
            if( left in ['—'] and tag == 'delete'):
                tag = 'equal9'
            #if(tag == 'replace' and re.sub('\*','',left) == right):
            #    tag = 'equal*'
            if tag == 'equal':
                marker = ' '
            elif tag == 'replace' or tag == 'delete':
                if(re.sub('[‘῾῾ ̔’,᾿]','',left) == re.sub("[῾\"'‘”’]",'',right)):
                    tag = 'equal22'
                if(left.replace('’','') == right):
                    tag = 'equal4'
                if(re.sub('·','',left) == right):
                    tag = 'equal11'
                
                    
                if(curpage in wordindex and left in wordindex[curpage] and not re.search('[0-9]',tag)):
                    #print('a',i,left,tag,right,sep='\t')
                    tag = tag + '8'
                marker = '|'
            elif tag == 'delete':
                marker = '<'
                right = ''
            elif tag == 'insert':
                marker = '>'
                left = ''
            #print(f"{left:<{width}} {marker} {right}")

            if(i == '316'):
                print(i,left,tag,right,sep='\t')

            if(left == '' and right):
                tag = "insert20"

            if(left and right == ''):
                tag = 'insert30'
            print(i,left,tag,right,sep='\t',file=fout)
            tag = re.sub('[0-9]+$','',tag)
            #print(curtoken,left,tag,right,sep='\t',file=fout)
                
fout = open('nauckdiffs.txt','w')
textoff = 32
#if(i>947):
#    textoff = textoff + 3
for i in range(3,959):
    side_by_side_diff(fout,str(i),nauckpages[str(i)],pagebuf[str(i)])
fout.close()
# Out:
# 316	316"/>	replace	316
# 316	316"/>	replace	316
# 316		replace	SOPHOCLIS
# 316		replace5	SOPHOCLIS
# 316	vulgo,	equal	vulgo,
# 316	vulgo,	equal	vulgo,
# 316	εὐπρεπεστάτη	equal	εὐπρεπεστάτη
# 316	εὐπρεπεστάτη	equal	εὐπρεπεστάτη
# 316	in	equal	in
# 316	in	equal	in
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	p.	equal	p.
# 316	p.	equal	p.
# 316	517	equal	517
# 316	517	equal	517
# 316	praebet	equal	praebet
# 316	praebet	equal	praebet
# 316	codex	equal	codex
# 316	codex	equal	codex
# 316	D,	equal	D,
# 316	D,	equal	D,
# 316	ut	equal	ut
# 316	ut	equal	ut
# 316	coniecerunt	equal	coniecerunt
# 316	coniecerunt	equal	coniecerunt
# 316	Ritschl	equal	Ritschl
# 316	Ritschl	equal	Ritschl
# 316	Opusc.	equal	Opusc.
# 316	Opusc.	equal	Opusc.
# 316	1	equal	1
# 316	1	equal	1
# 316	p.	equal	p.
# 316	p.	equal	p.
# 316	739	equal	739
# 316	739	equal	739
# 316	et	equal	et
# 316	et	equal	et
# 316	F.	equal	F.
# 316	F.	equal	F.
# 316	G.	equal	G.
# 316	G.	equal	G.
# 316	Schmidt	equal	Schmidt
# 316	Schmidt	equal	Schmidt
# 316	Anal.	equal	Anal.
# 316	Anal.	equal	Anal.
# 316	Soph.	equal	Soph.
# 316	Soph.	equal	Soph.
# 316	et	equal	et
# 316	et	equal	et
# 316	Eur.	equal	Eur.
# 316	Eur.	equal	Eur.
# 316	p.	equal	p.
# 316	p.	equal	p.
# 316	51.	equal	51.
# 316	51.	equal	51.
# 316	v.	equal	v.
# 316	v.	equal	v.
# 316	8	equal	8
# 316	8	equal	8
# 316	κἀπὶ	equal	κἀπὶ
# 316	κἀπὶ	equal	κἀπὶ
# 316	μηδὲν]	equal	μηδὲν]
# 316	μηδὲν]	equal	μηδὲν]
# 316	κεἰς	equal	κεἰς
# 316	κεἰς	equal	κεἰς
# 316	τὸ	equal	τὸ
# 316	τὸ	equal	τὸ
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	V.	equal	V.
# 316	V.	equal	V.
# 316	Demetr.,	equal	Demetr.,
# 316	Demetr.,	equal	Demetr.,
# 316	quae	equal	quae
# 316	quae	equal	quae
# 316	lectio	equal	lectio
# 316	lectio	equal	lectio
# 316	praeferenda	equal	praeferenda
# 316	praeferenda	equal	praeferenda
# 316	videtur.	equal	videtur.
# 316	videtur.	equal	videtur.
# 316	788	equal	788
# 316	788	equal	788
# 316	καὶ	equal	καὶ
# 316	καὶ	equal	καὶ
# 316	τὰν	replace	τὴν
# 316	τὰν	replace	τὴν
# 316	νέορτον	equal	νέορτον
# 316	νέορτον	equal	νέορτον
# 316	ἇς	replace	ἷς
# 316	ἇς	replace	ἷς
# 316	ἔτ’	equal	ἔτ’
# 316	ἔτ’	equal	ἔτ’
# 316	ἄστολος	equal	ἄστολος
# 316	ἄστολος	equal	ἄστολος
# 316	χιτὼν	replace	χιτών
# 316	χιτὼν	replace	χιτών
# 316	ὡραῖον	equal	ὡραῖον
# 316	ὡραῖον	equal	ὡραῖον
# 316	ἀμφὶ	equal	ἀμφὶ
# 316	ἀμφὶ	equal	ἀμφὶ
# 316	μηρὸν	equal	μηρὸν
# 316	μηρὸν	equal	μηρὸν
# 316	πτύσσεται	equal	πτύσσεται
# 316	πτύσσεται	equal	πτύσσεται
# 316	Ἑρμιόναν	replace	Ἐρμιόναν
# 316	Ἑρμιόναν	replace	Ἐρμιόναν
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	Lycurgi	equal	Lycurgi
# 316	Lycurgi	equal	Lycurgi
# 316	et	equal	et
# 316	et	equal	et
# 316	Numae	equal	Numae
# 316	Numae	equal	Numae
# 316	comp.	equal	comp.
# 316	comp.	equal	comp.
# 316	c.	equal	c.
# 316	c.	equal	c.
# 316	3:	equal	3:
# 316	3:	equal	3:
# 316	τοῦ	equal	τοῦ
# 316	τοῦ	equal	τοῦ
# 316	παρθενικοῦ	equal	παρθενικοῦ
# 316	παρθενικοῦ	equal	παρθενικοῦ
# 316	χιτῶνος	equal	χιτῶνος
# 316	χιτῶνος	equal	χιτῶνος
# 316	αἱ	equal	αἱ
# 316	αἱ	equal	αἱ
# 316	πτέρυγες	equal	πτέρυγες
# 316	πτέρυγες	equal	πτέρυγες
# 316	οὐκ	equal	οὐκ
# 316	οὐκ	equal	οὐκ
# 316	ἦσαν	equal	ἦσαν
# 316	ἦσαν	equal	ἦσαν
# 316	συνερραμμέναι	equal	συνερραμμέναι
# 316	συνερραμμέναι	equal	συνερραμμέναι
# 316	κάτωθεν,	equal	κάτωθεν,
# 316	κάτωθεν,	equal	κάτωθεν,
# 316	ἀλλ’	equal	ἀλλ’
# 316	ἀλλ’	equal	ἀλλ’
# 316	ἀνεπτύσσοντο	equal	ἀνεπτύσσοντο
# 316	ἀνεπτύσσοντο	equal	ἀνεπτύσσοντο
# 316	καὶ	equal	καὶ
# 316	καὶ	equal	καὶ
# 316	συνανεγύμνουν	equal	συνανεγύμνουν
# 316	συνανεγύμνουν	equal	συνανεγύμνουν
# 316	ὅλον	equal	ὅλον
# 316	ὅλον	equal	ὅλον
# 316	ἐν	equal	ἐν
# 316	ἐν	equal	ἐν
# 316	τῷ	equal	τῷ
# 316	τῷ	equal	τῷ
# 316	βαδίζειν	equal	βαδίζειν
# 316	βαδίζειν	equal	βαδίζειν
# 316	τὸν	equal	τὸν
# 316	τὸν	equal	τὸν
# 316	μηρόν.	equal	μηρόν.
# 316	μηρόν.	equal	μηρόν.
# 316	καὶ	equal	καὶ
# 316	καὶ	equal	καὶ
# 316	σαφέστατα	equal	σαφέστατα
# 316	σαφέστατα	equal	σαφέστατα
# 316	τὸ	equal	τὸ
# 316	τὸ	equal	τὸ
# 316	γινόμενον	equal	γινόμενον
# 316	γινόμενον	equal	γινόμενον
# 316	εἴρηκε	equal	εἴρηκε
# 316	εἴρηκε	equal	εἴρηκε
# 316	Σοφοκλῆς	equal	Σοφοκλῆς
# 316	Σοφοκλῆς	equal	Σοφοκλῆς
# 316	ἐν	equal	ἐν
# 316	ἐν	equal	ἐν
# 316	τούτοις	equal	τούτοις
# 316	τούτοις	equal	τούτοις
# 316	῾καὶ	replace	καὶ
# 316	῾καὶ	equal22	καὶ
# 316	τὸν	equal	τὸν
# 316	τὸν	equal	τὸν
# 316	Ἑρμιόναν᾿.	replace	—
# 316	Ἑρμιόναν᾿.	replace	—
# 316	v.	replace	Ἐρμιόναν.
# 316	v.	replace8	Ἐρμιόναν.
# 316	1	replace
# 316	1	replace8
# 316	νέορτον	equal	νέορτον
# 316	νέορτον	equal	νέορτον
# 316	Valckenaer,	equal	Valckenaer,
# 316	Valckenaer,	equal	Valckenaer,
# 316	νεοργὸν	equal	νεοργὸν
# 316	νεοργὸν	equal	νεοργὸν
# 316	vel	equal	vel
# 316	vel	equal	vel
# 316	νεουργὸν	equal	νεουργὸν
# 316	νεουργὸν	equal	νεουργὸν
# 316	libri.	equal	libri.
# 316	libri.	equal	libri.
# 316	ἇς	replace	ἷς
# 316	ἇς	replace	ἷς
# 316	ἔτ’	equal	ἔτ’
# 316	ἔτ’	equal	ἔτ’
# 316	Auratus,	equal	Auratus,
# 316	Auratus,	equal	Auratus,
# 316	ἄσετ᾿	replace	ἄσετ’
# 316	ἄσετ᾿	equal22	ἄσετ’
# 316	libri.	equal	libri.
# 316	libri.	equal	libri.
# 316	v.	equal	v.
# 316	v.	equal	v.
# 316	2	equal	2
# 316	2	equal	2
# 316	θυραῖον	equal	θυραῖον
# 316	θυραῖον	equal	θυραῖον
# 316	libri,	equal	libri,
# 316	libri,	equal	libri,
# 316	ὡραῖον	equal	ὡραῖον
# 316	ὡραῖον	equal	ὡραῖον
# 316	Gomperz	equal	Gomperz
# 316	Gomperz	equal	Gomperz
# 316	Mus.	equal	Mus.
# 316	Mus.	equal	Mus.
# 316	Rhen.	equal	Rhen.
# 316	Rhen.	equal	Rhen.
# 316	13	equal	13
# 316	13	equal	13
# 316	p.	equal	p.
# 316	p.	equal	p.
# 316	479.	equal	479.
# 316	479.	equal	479.
# 316	789	equal	789
# 316	789	equal	789
# 316	ὅστις	equal	ὅστις
# 316	ὅστις	equal	ὅστις
# 316	γὰρ	equal	γὰρ
# 316	γὰρ	equal	γὰρ
# 316	ὡς	equal	ὡς
# 316	ὡς	equal	ὡς
# 316	τύραννον	equal	τύραννον
# 316	τύραννον	equal	τύραννον
# 316	ἐμπορεύεται,	equal	ἐμπορεύεται,
# 316	ἐμπορεύεται,	equal	ἐμπορεύεται,
# 316	κείνου	equal	κείνου
# 316	κείνου	equal	κείνου
# 316	ἐστὶ	equal	ἐστὶ
# 316	ἐστὶ	equal	ἐστὶ
# 316	δοῦλος,	equal	δοῦλος,
# 316	δοῦλος,	equal	δοῦλος,
# 316	κἂν	equal	κἂν
# 316	κἂν	equal	κἂν
# 316	ἐλεύθερος	equal	ἐλεύθερος
# 316	ἐλεύθερος	equal	ἐλεύθερος
# 316	μόλῃ.	equal	μόλῃ.
# 316	μόλῃ.	equal	μόλῃ.
# 316		insert	v.
# 316		insert4	v.
# 316		insert	1
# 316		insert4	1
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	V.	equal	V.
# 316	V.	equal	V.
# 316	Pomp.	equal	Pomp.
# 316	Pomp.	equal	Pomp.
# 316	c.	equal	c.
# 316	c.	equal	c.
# 316	78	equal	78
# 316	78	equal	78
# 316	(Zonar.	equal	(Zonar.
# 316	(Zonar.	equal	(Zonar.
# 316	Annal.	equal	Annal.
# 316	Annal.	equal	Annal.
# 316	10,	equal	10,
# 316	10,	equal	10,
# 316	10):	equal	10):
# 316	10):	equal	10):
# 316	μεταστραφεὶς	equal	μεταστραφεὶς
# 316	μεταστραφεὶς	equal	μεταστραφεὶς
# 316	πρὸς	equal	πρὸς
# 316	πρὸς	equal	πρὸς
# 316	τὴν	equal	τὴν
# 316	τὴν	equal	τὴν
# 316	γυναῖκα	equal	γυναῖκα
# 316	γυναῖκα	equal	γυναῖκα
# 316	καὶ	equal	καὶ
# 316	καὶ	equal	καὶ
# 316	τὸν	equal	τὸν
# 316	τὸν	equal	τὸν
# 316	υἱὸν	equal	υἱὸν
# 316	υἱὸν	equal	υἱὸν
# 316	εἶπε	equal	εἶπε
# 316	εἶπε	equal	εἶπε
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	ἰαμβεῖα	equal	ἰαμβεῖα
# 316	ἰαμβεῖα	equal	ἰαμβεῖα
# 316	῾ὅστις	replace	ὅστις
# 316	῾ὅστις	equal22	ὅστις
# 316	μόλῃ᾿.	equal	μόλη‘.
# 316	μόλῃ᾿.	equal	μόλη‘.
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	Regum	equal	Regum
# 316	Regum	equal	Regum
# 316	et	equal	et
# 316	et	equal	et
# 316	imperat.	equal	imperat.
# 316	imperat.	equal	imperat.
# 316	apophthegm.	equal	apophthegm.
# 316	apophthegm.	equal	apophthegm.
# 316	p.	equal	p.
# 316	p.	equal	p.
# 316	204	equal	204
# 316	204	equal	204
# 316	E:	equal	E:
# 316	E:	equal	E:
# 316	τὸ	equal	τὸ
# 316	τὸ	equal	τὸ
# 316	τοῦ	equal	τοῦ
# 316	τοῦ	equal	τοῦ
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	εἶπεν	equal	εἶπεν
# 316	εἶπεν	equal	εἶπεν
# 316	῾ὅστις	replace	ὅστις
# 316	῾ὅστις	equal22	ὅστις
# 316	μόλῃ᾿.	equal	μόλη.
# 316	μόλῃ᾿.	equal	μόλη.
# 316	Appian.	equal	Appian.
# 316	Appian.	equal	Appian.
# 316	B.	equal	B.
# 316	B.	equal	B.
# 316	civ.	equal	civ.
# 316	civ.	equal	civ.
# 316	2,	equal	2,
# 316	2,	equal	2,
# 316	85:	equal	85:
# 316	85:	equal	85:
# 316	τοσοῦτο	equal	τοσοῦτο
# 316	τοσοῦτο	equal	τοσοῦτο
# 316	δ’	equal	δ’
# 316	δ’	equal	δ’
# 316	ἐκ	equal	ἐκ
# 316	ἐκ	equal	ἐκ
# 316	τῶν	equal	τῶν
# 316	τῶν	equal	τῶν
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	ἰαμβείων	replace	ιαμβείων
# 316	ἰαμβείων	replace	ιαμβείων
# 316	πρὸς	equal	πρὸς
# 316	πρὸς	equal	πρὸς
# 316	ἑαυτὸν	equal	ἑαυτὸν
# 316	ἑαυτὸν	equal	ἑαυτὸν
# 316	ἀνενεγκών	equal	ἀνενεγκών
# 316	ἀνενεγκών	equal	ἀνενεγκών
# 316	῾ὅστις	replace	ὅστις
# 316	῾ὅστις	equal22	ὅστις
# 316	μόλῃ᾿	equal	–
# 316	μόλῃ᾿	equal	–
# 316	ἐνέβαινεν	equal	μόλῃς
# 316	ἐνέβαινεν	equal	μόλῃς
# 316		equal	ἐνέ
# 316		equal	ἐνέ
# 316		insert	βαινεν
# 316		insert	βαινεν
# 316	εἰς	equal	εἰς
# 316	εἰς	equal	εἰς
# 316	τὸ	equal	τὸ
# 316	τὸ	equal	τὸ
# 316	σκάφος.	equal	σκάφος.
# 316	σκάφος.	equal	σκάφος.
# 316	Dio	equal	Dio
# 316	Dio	equal	Dio
# 316	Cass.	equal	Cass.
# 316	Cass.	equal	Cass.
# 316	42,	equal	42,
# 316	42,	equal	42,
# 316	4:	equal	4:
# 316	4:	equal	4:
# 316	ἐξῆλθε	equal	ἐξῆλθε
# 316	ἐξῆλθε	equal	ἐξῆλθε
# 316	τοσοῦτον	equal	τοσοῦτον
# 316	τοσοῦτον	equal	τοσοῦτον
# 316	μόνον	equal	μόνον
# 316	μόνον	equal	μόνον
# 316	εἰπών	equal	εἰπών
# 316	εἰπών	equal	εἰπών
# 316	῾ὅστις	replace	ὅστις
# 316	῾ὅστις	equal22	ὅστις
# 316	μόλῃ᾿.	equal	μόλη.
# 316	μόλῃ᾿.	equal	μόλη.
# 316	Macar.	equal	Macar.
# 316	Macar.	equal	Macar.
# 316	6,	equal	6,
# 316	6,	equal	6,
# 316	50:	equal	50:
# 316	50:	equal	50:
# 316	῾ὅστις	replace	ὅστις
# 316	῾ὅστις	equal22	ὅστις
# 316	μόλῃ᾿.	equal	—
# 316	μόλῃ᾿.	equal	—
# 316		equal	μόλη.
# 316		equal	μόλη.
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	καὶ	equal	καὶ
# 316	καὶ	equal	καὶ
# 316	αὕτη.	equal	αὕτη.
# 316	αὕτη.	equal	αὕτη.
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	de	equal	de
# 316	de	equal	de
# 316	audiendis	equal	audiendis
# 316	audiendis	equal	audiendis
# 316	poetis	equal	poetis
# 316	poetis	equal	poetis
# 316	c.	equal	c.
# 316	c.	equal	c.
# 316	12	equal	12
# 316	12	equal	12
# 316	p.	equal	p.
# 316	p.	equal	p.
# 316	33	equal	33
# 316	33	equal	33
# 316	D:	equal	D:
# 316	D:	equal	D:
# 316	καὶ	equal	καὶ
# 316	καὶ	equal	καὶ
# 316	ὁ	equal	ὁ
# 316	ὁ	equal	ὁ
# 316	Ζήνων	equal	Ζήνων
# 316	Ζήνων	equal	Ζήνων
# 316	ἐπανορθούμενος	equal	ἐπανορθούμενος
# 316	ἐπανορθούμενος	equal	ἐπανορθούμενος
# 316	τὸ	equal	τὸ
# 316	τὸ	equal	τὸ
# 316	τοῦ	equal	τοῦ
# 316	τοῦ	equal	τοῦ
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	῾ὅστις	replace	ὅστις
# 316	῾ὅστις	equal22	ὅστις
# 316	μόλῃ᾿,	equal	–
# 316	μόλῃ᾿,	equal	–
# 316		equal	μόλῃ,
# 316		equal	μόλῃ,
# 316	μετέγραφεν	equal	μετέγραφεν
# 316	μετέγραφεν	equal	μετέγραφεν
# 316	῾οὐκ	delete
# 316	῾οὐκ	delete
# 316	ἔστι	insert
# 316		insert
# 316	δοῦλος,	insert
# 316		insert
# 316	ἂν	insert
# 316		insert
# 316	ἐλεύθερος	insert
# 316		insert
# 316	μόλῃ᾿.	insert
# 316		insert
# 316	Laert.	equal	Laert.
# 316	Laert.	equal	Laert.
# 316	Diog.	equal	Diog.
# 316	Diog.	equal	Diog.
# 316	2,	equal	2,
# 316	2,	equal	2,
# 316	82:	equal	82:
# 316	82:	equal	82:
# 316	εἰπόντος	equal	εἰπόντος
# 316	εἰπόντος	equal	εἰπόντος
# 316	πρὸς	replace	―
# 316	πρὸς	replace8	―
# 316	αὐτὸν	replace	οὐκ
# 316	αὐτὸν	replace8	οὐκ
# 316	(Aristippum)	replace
# 316	(Aristippum)	replace8
# 316	Διονυσίου	insert
# 316		insert
# 316	῾ὅστις	insert
# 316		insert
# 316	μόλῃ᾿,	insert
# 316		insert
# 316	ὑπολαβὼν	insert
# 316		insert
# 316	῾οὐκ	insert
# 316		insert
# 316	ἔστι	equal	ἔστι
# 316	ἔστι	equal	ἔστι
# 316	δοῦλος,	equal	δοῦλος,
# 316	δοῦλος,	equal	δοῦλος,
# 316	ἂν	equal	ἂν
# 316	ἂν	equal	ἂν
# 316	ἐλεύθερος	equal	ἐλεύθερος
# 316	ἐλεύθερος	equal	ἐλεύθερος
# 316	μόλῃ᾿.	replace	μόλῃ.
# 316	μόλῃ᾿.	equal22	μόλῃ.
# 316		equal	πρὸς
# 316		equal	πρὸς
# 316		insert	αὐτὸν
# 316		insert4	αὐτὸν
# 316		insert	(Aristippum)
# 316		insert4	(Aristippum)
# 316		insert	Διονυσίου
# 316		insert4	Διονυσίου
# 316		insert	ὅστις
# 316		insert4	ὅστις
# 316		insert	μόλῃ,
# 316		insert	μόλῃ,
# 316		insert	ὑπολαβὼν
# 316		insert4	ὑπολαβὼν
# 316		insert	οὐκ
# 316		insert4	οὐκ
# 316		insert	ἔστι
# 316		insert4	ἔστι
# 316		insert	δοῦλος,
# 316		insert4	δοῦλος,
# 316		insert	ἂν
# 316		insert4	ἂν
# 316		insert	ἐλεύθερος
# 316		insert4	ἐλεύθερος
# 316		insert	μόλῃ.
# 316		insert4	μόλῃ.
# 316	v.	equal	v.
# 316	v.	equal	v.
# 316	1	equal	1
# 316	1	equal	1
# 316	γὰρ	equal	γὰρ
# 316	γὰρ	equal	γὰρ
# 316	ὡς]	equal	ὡς]
# 316	ὡς]	equal	ὡς]
# 316	δὲ	equal	δὲ
# 316	δὲ	equal	δὲ
# 316	πρὸς	equal	πρὸς
# 316	πρὸς	equal	πρὸς
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	et	equal	et
# 316	et	equal	et
# 316	Zon.,	equal	Zon.,
# 316	Zon.,	equal	Zon.,
# 316	πρὸς	equal	πρὸς
# 316	πρὸς	equal	πρὸς
# 316	Macar.	equal	Macar.
# 316	Macar.	equal	Macar.
# 316	790	equal	790
# 316	790	equal	790
# 316	ὦ	equal	ὦ
# 316	ὦ	equal	ὦ
# 316	θεοί,	equal	θεοί,
# 316	θεοί,	equal	θεοί,
# 316	τίς	equal	τίς
# 316	τίς	equal	τίς
# 316	ἆρα	equal	ἆρα
# 316	ἆρα	equal	ἆρα
# 316	Κύπρις	equal	Κύπρις
# 316	Κύπρις	equal	Κύπρις
# 316	ἢ	equal	ἢ
# 316	ἢ	equal	ἢ
# 316	τίς	equal	τίς
# 316	τίς	equal	τίς
# 316	ἵμερος	equal	ἵμερος
# 316	ἵμερος	equal	ἵμερος
# 316	τοῦδε	equal	τοῦδε
# 316	τοῦδε	equal	τοῦδε
# 316	ξυνήψατο;	equal	ξυνήψατο;
# 316	ξυνήψατο;	equal	ξυνήψατο;
# 316	Plut.	equal	Plut.
# 316	Plut.	equal	Plut.
# 316	V.	equal	V.
# 316	V.	equal	V.
# 316	Timol.	equal	Timol.
# 316	Timol.	equal	Timol.
# 316	c.	equal	c.
# 316	c.	equal	c.
# 316	36:	equal	36:
# 316	36:	equal	36:
# 316	τῶν	equal	τῶν
# 316	τῶν	equal	τῶν
# 316	δὲ	equal	δὲ
# 316	δὲ	equal	δὲ
# 316	Τιμολέοντος	equal	Τιμολέοντος
# 316	Τιμολέοντος	equal	Τιμολέοντος
# 316	ἔργων	equal	ἔργων
# 316	ἔργων	equal	ἔργων
# 316	οὐδὲν	equal	οὐδὲν
# 316	οὐδὲν	equal	οὐδὲν
# 316	ἔστιν	equal	ἔστιν
# 316	ἔστιν	equal	ἔστιν
# 316	ᾧ	equal	ᾧ
# 316	ᾧ	equal	ᾧ
# 316	μὴ	equal	μὴ
# 316	μὴ	equal	μὴ
# 316	τὰ	equal	τὰ
# 316	τὰ	equal	τὰ
# 316	τοῦ	equal	τοῦ
# 316	τοῦ	equal	τοῦ
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	Σοφοκλέους	equal	Σοφοκλέους
# 316	(τιμοκλέους	equal	(τιμοκλέους
# 316	(τιμοκλέους	equal	(τιμοκλέους
# 316	ΒΜ),	equal	ΒΜ),
# 316	ΒΜ),	equal	ΒΜ),
# 316	ὡς	equal	ὡς
# 316	ὡς	equal	ὡς
# 316	φησὶ	equal	φησὶ
# 316	φησὶ	equal	φησὶ
# 316	Τίμαιος,	equal	Τίμαιος,
# 316	Τίμαιος,	equal	Τίμαιος,
# 316	ἐπιφωνεῖν	equal	ἐπιφωνεῖν
# 316	ἐπιφωνεῖν	equal	ἐπιφωνεῖν
# 316	ἔπρεπεν	equal	ἔπρεπεν
# 316	ἔπρεπεν	equal	ἔπρεπεν
# 316	῾ὦ	replace	ὦ
# 316	῾ὦ	equal22	ὦ
# 316	θεοί	equal	θεοί
# 316	θεοί	equal	θεοί
# 316	ξυνήψατο;᾿	replace	—
# 316	ξυνήψατο;᾿	replace	—
# 316		replace	ξυνήψατο;
# 316		replace5	ξυνήψατο;
# 316	v.	equal	v.
# 316	v.	equal	v.
# 316	1	equal	1
# 316	1	equal	1
# 316	ὦ	equal	ὦ
# 316	ὦ	equal	ὦ
# 316	θεοί]	equal	θεοί]
# 316	θεοί]	equal	θεοί]
# 316	ὦ	equal	ὦ
# 316	ὦ	equal	ὦ
# 316	θεά	equal	θεά
# 316	θεά	equal	θεά
# 316	ΒM.	replace	ΒΜ.
# 316	ΒM.	replace	ΒΜ.
# 316		replace	༩༣
# 316		replace5	༩༣
# 316	791	equal	791
# 316	791	equal	791
# 316	ὀρθόκερως	equal	ὀρθόκερως
# 316	ὀρθόκερως	equal	ὀρθόκερως
# 316	φρίκη	equal	φρίκη
# 316	φρίκη	equal	φρίκη

# %%
xmlindex['282']['αὐτῷ']
# Out:
# 1
