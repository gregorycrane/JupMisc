# %%
moerbeke_sections = {
    "De poetica ipsaque et speciebus ipsius": "1.1",
    "Epopoiia itaque et que tragodie poesis": "1.2",
    "differunt autem ab invicem tribus": "1.3",
    "Sicut enim et coloribus et figuris multa": "1.4",
    "puta armonia quidem ": "1.5",
    "ipso autem rythmo imitantur sine armonia": "1.6",
    "Epopoiia autem solum sermonibus nudis": "1.7",
    "Nichil enim habemus nominare commune": "1.8",
    "neque si quis per trimetra aut elegeia": "1.9",
    "nisi quod homines, copulantes metro": "1.10",
    "Et enim si medicinale aut musicum aliquid": "1.11",
    "Similiter autem et si quis omnia metra": "1.12",
    "Sunt autem aliqui qui omnibus dictis": "1.13",
    "Has quidem igitur dico differentias": "1.14",
    # Chapter 2
    "Quoniam autem imitantes imitantur agentes": "2.1",
    "Polygnostus quidem enim meliores, Pauson autem peiores": "2.2",
    "Palam autem quod et dictarum imitationum": "2.3",
    "Et enim in saltatione et fystulatione": "2.4",
    "Et circa sermones autem et nudam metrizationem": "2.5",
    "Similiter autem et circa dithyrambos et circa leges": "2.6",
    "In ipsa autem differentia et tragodia ad komodiam": "2.7",
    
    # Chapter 3
    "Adhuc autem horum tertia differentia per quomodo": "3.1",
    "Et enim in eisdem et eadem imitari est aliquando": "3.2",
    "In tribus itaque hiis differentiis imitatio est": "3.3",
    "Quare hac": "3.4",
    "Unde et dramata (idest actitamina) vocari ipsa quidam": "3.5",
    "Signum autem: isti quidem enim 'komas' perioikidas": "3.6",
    "De differentiis quidem igitur, et quot et que": "3.7",

    # Chapter 4
    "Videntur autem genuisse omnino poeticam cause due": "4.1",
    "Nam imitari connatum hominibus est ex pueris": "4.2",
    "Signum autem huius, quod accidit in opere": "4.3",
    "Causa autem et huius, quia addiscere non solum": "4.4",
    "Propter hoc enim gaudent ymagines aspicientes": "4.5",
    "quoniam si forte non prius vidit, non imitamen": "4.6",
    "Secundum\nnaturam autem ente nobis ipso imitari": "4.7",
    "Distracta est autem, secundum proprios mores": "4.8",
    "Eorum quidem igitur qui ante Homerum, nullius": "4.9",
    "Ab Homero\nautem incipiens est, puta illius Margeites": "4.10",
    "et fuerunt antiquorum hii quidem eroycorum": "4.11",
    "Sicut autem secundum studiosa maxime poeta Homerus": "4.12",
    "Secus apparentie autem tragodie et komodie qui ad utramque": "4.13",
    "Facta\nigitur a principio autoschediastica (idest informi)": "4.14",
    "Et multis transmutationibus transmutata tragodia requievit": "4.15",
    "Et ypocritarum multitudinem ex uno in duo primus": "4.16",
    "Adhuc autem magnitudo ex parvis fabulis et locutione": "4.17",
    "Metrumque ex tetrametro iambiale factum est": "4.18",
    "plurima enim iambialia\ndicimus in loquela": "4.19",
    "Adhuc autem episodiorum multitudines. Et alia singulas": "4.20",
    "Multum enim utique forsitan opus erit pertransire": "4.21",

    # Chapter 5
    "Komodia autem est, sicut diximus, imitatio peiorum": "5.1",
    "nam risile est. peccatum aliquod et turpitudo non dolorosa": "5.2",
    "Que quidem\nigitur tragodie transitiones, et per que": "5.3",
    "lam autem scemata quedam habente ipsa, qui dicuntur": "5.4",
    "Quis autem larvas tradidit aut prologos aut multitudines": "5.5",
    "eorum\nautem qui Athenis, Krates primus incepit": "5.6",
    "Epopoiia\nquidem igitur tragodie usque ad solum metrum": "5.7",
    "adhuc autem longitudine, hec quidem quam maxime temptat": "5.8",
    "equidem primo similiter in tragodiis": "5.9",
    "Propter quod\nquicumque de tragodia novit studiosa": "5.11", # Moerbeke omits/merges 5.10 into this transition

    # Chapter 6
    "De ea igitur que in exametris imitativa": "6.1",
    "Est igitur tragodia imitatio actionis studiose et perfecte": "6.2",
    "Dico autem delectantem quidem sermonem habentem": "6.3",
    "seorsum autem speciebus per metra solum": "6.4",
    "Quoniam autem agentes faciunt imitationem, primo quidem": "6.5",
    "Dico autem locutionem quidem ipsam metrorum compositionem": "6.6",
    "Quoniam autem actio est imitatio, agitur autem ab aliquibus": "6.7",
    "Est autem actionis quidem fabula imitatio": "6.8",
    "Necesse igitur omnis tragodie partes esse sex": "6.9",
    "Quibus quidem enim imitantur due partes sunt": "6.10",
    "Hiis quidem igitur non pauci ipsorum ut est dicere": "6.11",
    "Maximum autem horum est rerum consistentia; tragodia enim": "6.12",
    "Igitur quatinus mores imitentur agunt, sed mores simul": "6.13",
    "Adhuc sine actione quidem non utique fiet tragodia": "6.14",
    "Nam iuvenum plurimorum sine moribus tragodie sunt": "6.15",
    "Adhuc si quis consequenter ponat series morales": "6.16",
    "Fabule partes sunt et peripetie et anagnorisees": "6.17",
    "Adhuc signum quod et conantes poetizare prius possunt": "6.18",
    "Principium quidem igitur et velut anima tragodie fabula": "6.19",
    "Consimile enim est et in pictura; si enim aliquis inunxerit": "6.20",
    "Estque imitatio actionis et propter hanc maxime": "6.21",
    "Tertium autem ratiocinatio, scilicet posse dicere inentia": "6.22",
    "antiqui quidem enim politice faciebant dicentes": "6.23",
    "Est autem mos quidem tale quod manifestat electionem": "6.24",
    "Ratiocinatio autem in quibus demonstrant aliquid": "6.25",
    "Quartum autem sermonum quidem locutio; dico autem": "6.26",
    "Reliquorum autem quinque que melodie factio maximum": "6.27",
    "Visus autem anime abductivum quidem, inartificiosissimum": "6.28",
#}


# Chapters 7, 8, and 9 Subchapter Mappings
#chapters_7_9_table = {
    # Chapter 7
    "Determinatis autem hiis, dicamus post hec qualem": "7.1",
    "Supponitur autem nobis tragodiam perfecte et totalis": "7.2",
    "est enim totum et nullam habens magnitudinem": "7.3",
    "Principium autem est quod ipsum quidem non ex necessitate": "7.4",
    "Finis autem contrarium quod et ipsum post aliud": "7.5",
    "medium autem quod et ipsum post aliud et post illud": "7.6",
    "Oportet igitur constituentes bene fabulas neque": "7.7",
    "Adhuc autem quoniam quod pulchrum, et animal": "7.8",
    "neque omnino parvum utique aliquid fiet pulcrum": "7.9",
    "Quare oportet, sicut in corporibus et in animalibus": "7.10",
    "Longitudinis terminus quidem ad agones et ad sensum": "7.11",
    "Qui autem secundum ipsam naturam rei terminus": "7.12",

    # Chapter 8
    "Fabula autem est una non, sicut quidam putant": "8.1",
    "Sic autem et actiones unius multe sunt": "8.2",
    "Homerus autem, sicut et secundum alia differt": "8.3",
    "Oportet igitur, sicut et in aliis imitativis una": "8.4",

    # Chapter 9
    "Manifestum autem ex dictis et quod non gesta": "9.1",
    "Hystoricus enim et poeta non per metrizata dicere": "9.2",
    "Propter quod et magis philosophicum et studiosius": "9.3",
    "Est autem universaliter quidem, quali qualia quedam": "9.4",
    "In komodia quidem igitur iam hoc palam factum": "9.5",
    "In tragodia autem facta nomina attendunt": "9.6",
    "Quin immo et in tragodiis quibusdam quidem unum": "9.7",
    "quare non omnino esse querendum traditas fabulas": "9.8",
    "Palam igitur ex hiis, quod poetam magis oportet": "9.9",
    "Quamvis ergo accidat gesta poetizare, nichil\nminus": "9.10",
    "Simplicibus autem fabulis et actionibus que episodiodees": "9.11",
    "Tales autem poetizantur a pravis quidem poetis": "9.11b",
    "Quoniam autem non solum perfecte actionis est imitatio": "9.11c",
    "Nam quod mirabile sic habebit magis quam si a casu": "9.12",
    "Quare necesse tales esse pulcriores fabulas": "9.13",
#}

# Chapters 10, 11, and 12 Subchapter Mappings
#chapters_10_12_table = {
    # Chapter 10
    "Sunt autem fabularum hee quidem simplices": "10.1",
    "Dico autem simplicem quidem actionem qua": "10.2",
    "complexa autem locutio cum anagnorismo": "10.3",
    "Hec autem oportet fieri ex ipsa consistentia": "10.4",

    # Chapter 11
    "Est autem peripeteia quidem que ad contrarium": "11.1",
    "sicut in Oidipode veniens tamquam letificaturus": "11.2",
    "et in Lynkei hic quidem ductus tamquam": "11.3",
    "Anagnorisis autem, sicut et nomen significat": "11.4",
    "pulcherrima autem anagnorisis, quando simul": "11.5",
    "Sunt quidem igitur et alia anagnorisees": "11.6",
    "sed que maxime fabule et que maxime actionis": "11.7",
    "Quoniam anagnorisis aliquorum est anagnorisis": "11.8",
    "Due quidem igitur fabule partes hee sunt": "11.9",
    "passio autem est actio corruptiva et dolorosa": "11.10",

    # Chapter 12
    "Partes autem tragodie quibus quidem ut speciebus": "12.1",
    "et huius hoc quidem parodus, hoc autem stasimon": "12.2",
    "Communia quidem omnium hec, propria autem": "12.3",
    "Est autem prologus quidem pars tota tragodie": "12.4",
    "episodion autem pars tota tragodie que intermedia": "12.5",
    "exodus autem (idest exitus) pars tota tragodie": "12.6",
    "Khorici autem parodus quidem prima locutio": "12.7",
    "stasimon autem melodia khori que sine anapesto": "12.8",
    "kommos autem lamentatio nova khori et a scene": "12.9",
    "Partes autem tragodie quibus quidem oportet uti": "12.10",
#}
# Chapters 13, 14, and 15 Subchapter Mappings
#chapters_13_15_table = {
    # Chapter 13
    "Que autem oportet coniecturare et que oportet vereri": "13.1",
    "Quoniam igitur oportet compositionem optime tragodie": "13.2",
    "neque pestilentes ex infortunio in eufortunium": "13.3",
    "neque ipsum valde malignum ex eufortunio in infortunium": "13.4",
    "qui intermedius ergo horum reliquus. Est autem talis": "13.5",
    "Necesse ergo bene habentem fabulam simplicem magis": "13.6",
    "Signum autem et quod fit; primo quidem enim poete": "13.7",
    "Que quidem igitur secundum artem pulcherrima tragodia": "13.8",
    "Propter quod et Euripedem incusantes idem peccant": "13.9",
    "Signum autem maximum, in skenis enim et agonibus": "13.10",
    "Secunda autem, que prima dicitur a quibusdam": "13.11",
    "Putatur autem prima propter theatrorum debilitatem": "13.12",
    "Est autem non hec a tragodia delectatio, sed magis": "13.13",

    # Chapter 14
    "Est quidem igitur quod terribile et miserabile ex visu": "14.1",
    "Oportet enim et sine videre sic consistere fabulam": "14.2",
    "Per visum autem hoc preparare inartificialius": "14.3",
    "Qui autem non terribile per visum sed monstruosum": "14.4",
    "Quoniam autem eam que a miseratione et terrore": "14.5",
    "Qualia igitur dira aut qualia miserabilia videntur": "14.6",
    "Si quidem igitur inimicus inimicum, nichil miserabile": "14.7",
    "neque si neutro modo habentes;": "14.8",
    "quando autem in amicitiis ingeruntur passiones, puta": "14.9",
    "Assumptas quidem igitur fabulas solvere non est": "14.10",
    "Ipsam autem invenire oportet et traditis uti bene": "14.11",
    "Est quidem enim sic fieri actionem, sicut antiqui": "14.12",
    "Est autem agere quidem ignorantes, ignorantes autem agere": "14.13",
    "Est autem tertium preter hec futurum facere aliquid": "14.14",
    "Et preter hec non est aliter \u0387 aut enim agere": "14.15",
    "Horum autem cognoscentem quidem futurum agere et non agere": "14.16",
    "Agere autem secundum.": "14.17",
    "Melius autem ignorantem quidem agere, postquam egit": "14.18",
    "Optimum autem quod ultimum; dico autem quale in Kresfonte": "14.19",
    "Propter hoc enim, quod quidem olim dictum est": "14.20",
    "De rerum quidem igitur consistentia et quales quasdam": "14.21",

    # Chapter 15
    "Circa mores autem quatuor sunt que oportet coniecturare": "15.1",
    "unum quidem et primum, quatinus boni sint": "15.2",
    "Est autem in unoquoque genere; et enim mulier est bona": "15.3",
    "Secundum autem congruentia; est enim virilis quidem mos": "15.4",
    "Tertium autem quod simile; hoc enim alterum": "15.5",
    "Quartum autem quod regulare. Et si enim irregularis": "15.6",
    "Est autem exemplum malignitatis quidem moris": "15.7",
    "indecentis autem et non congruentis lamentatio Odysei": "15.8",
    "irregularis autem que in Aulide Ifigenia; nichil enim": "15.9",
    "Oportet autem et in moribus sicut et in rerum": "15.10",
    "Manifestum igitur quod et solutiones fabularum oportet": "15.10b",
    "sed ingenio utendum deinde extra opus, aut quecumque": "15.10c",
    "Irrationabile autem nichil esse in rebus, si autem non": "15.10d",
    "Quoniam autem imitatio est tragodia meliorum, nos oportet": "15.11",
    "Hec itaque observare eas que preter eas que ex necessitate": "15.12",
#}

# Chapters 16, 17, and 18 Subchapter Mappings
#chapters_16_18_table = {
    # Chapter 16
    "Anagnorisis autem quid quidem sit, dictum est prius": "16.1",
    "species autem anagnoriseos, prima quidem inartificiosissima": "16.1b",  # Transitions into the list of species
    "que per signa. Horum autem hec quidem connaturalia": "16.2",
    "hec autem adventitia, et horum hec quidem in corpore": "16.3",
    "Est autem et hiis uti aut melius aut peius, puta": "16.4",
    "sunt enim que quidem fidei gratia inartificialiores": "16.5",
    "Secunde autem que poetizate a poeta, propter quod": "16.6",
    "quia prope dictum peccatum est; licebat enim": "16.7",
    "aut per memoriam fore aliquid scientem, sicut qui in Cypriis": "16.8",
    "Quarta autem que ex sillogismo, puta in Khloiforis": "16.9",
    "Est autem quedam et composita ex paralogismo theatri": "16.10",
    "Omnium autem optima recognitio que ex ipsis rebus": "16.11",
    "Secunde autem que ex sillogismo.": "16.12",

    # Chapter 17
    "Oportet enim fabulas consistere et locutione cooperari": "17.1",
    "signum autem huius quod increpat Karkino": "17.2",
    "quecumque autem possibile et scematibus cooperantem": "17.3",
    "Propter quod eius qui apte nature poetica est quam manici": "17.4",
    "Hosque sermones et poetizatos oportet et ipsum facientem": "17.5",
    "exponere universaliter, puta Ifigeneie": "17.6",
    "Post hec autem iam supponentem nomina episodizare": "17.7",
    "qualiter autem erunt congrua episodia, puta in Horeste": "17.8",
    "In curribus quidem igitur episodia brevia": "17.9",
    "Nam Odysseie longus sermo est; peregrinante quodam": "17.10",
    "Proprium quidem igitur hoc, alia autem episodia.": "17.11",

    # Chapter 18
    "Est autem omnis tragodie hoc quidem colligatio": "18.1",
    "Dico autem colligationem quidem esse eam que a principio": "18.2",
    "sicut in Lykei Theodecti; colligatio anteacta": "18.3",
    "Tragodie autem species sunt quatuor, tot enim et partes": "18.4",
    "hec quidem complexa, cuius totum est peripeteia": "18.5",
    "hec autem passionalis, velut que Aiaces et Ixyones": "18.6",
    "hec vero moralis, velut que Fthiotides et Pileus": "18.7",
    "quarta autem , velut que Forkides et Prometheus": "18.8",
    "Maxime quidem igitur omnes oportet temptare habere": "18.9",
    "Iustum autem et tragodiam aliam et eandem dicere nichil": "18.10",
    "Multi autem complectentes bene solvunt prave": "18.11",
    "oportet autem ambo semper coadiuvare.": "18.12",
    "Oportet autem, ut dictum est sepe, memorari et non facere": "18.13",
    "Ibi quidem enim propter longitudinem sumunt partes": "18.14",
    "Signum autem; quicumque quidem Sinili totam poetizaverunt": "18.15",
    "In peripetiis autem et in simplicibus rebus coniecturant": "18.16",
    "Tragicum enim hoc et philanthropon; est autem hoc": "18.17",
    "Est autem hoc verisimile sicut Agathon dicit": "18.18",
    "Et chorum autem unum oportet suscipere ypocritas": "18.19",
    "Reliquis autem data magis fabule quam alterius": "18.20",
#}
# Chapters 19, 20, and 21 Subchapter Mappings
#chapters_19_21_table = {
    # Chapter 19
    "De aliis quidem igitur iam dictum est. Reliquum autem": "19.1",
    "Que quidem igitur circa dianoiam (idest ratiocinationem)": "19.2",
    "Sunt autem secundum dianoiam hec, quecumque a ratione": "19.3",
    "Partes autem horum demonstrareque et solvere": "19.4",
    "Palam autem quod et in rebus ab eisdem speciebus": "19.5",
    "preter quam tantum differt, quod hec quidem oportet": "19.6",
    "Eorum autem que circa locutionem una quidem est species": "19.7",
    "Preter enim horum cognitionem aut ignorantiam nulla": "19.8",
    "Propter quod pretermittatur tamquam alterius": "19.9",

    # Chapter 20
    "Locutionis autem omnis hee sunt partes\u00b7 elementum": "20.1",
    "Elementum quidem igitur vox indivisibilis, non omnis": "20.2",
    "huius autem partes vocalis et semivocalis et muta. Est": "20.3",
    "Hec autem differunt figurisque oris et locis": "20.4",
    "Sillaba autem est vox non significativa composita ex non": "20.5",
    "Coniunctio autem est vox non significativa que neque": "20.6",
    "Articulus autem est vox non significativa aut orationis": "20.7",
    "Nomen autem est vox conficta significativa sine tempore": "20.8",
    "Verbum autem vox conficta significativa cum tempore": "20.9",
    "Casus autem est nominis aut verbi, hic quidem": "20.10",
    "Oratio autem vox significativa composita cuius quedam": "20.11",
    "non enim omnis oratio ex verbis et nominibus": "20.12",
    "Una autem est oratio dupliciter, aut enim que unum": "20.13",

    # Chapter 21
    "Nominis autem species hoc quidem simplex (simplex autem": "21.1",
    "huius autem hoc quidem ex significante et non": "21.2",
    "Erit autem utique triplum et quadruplum nomen": "21.3",
    "Omne autem nomen est aut proprium aut lingua": "21.4",
    "Dico autem proprium quidem quo utuntur singuli": "21.5",
    "linguam autem quo alteri. \u2014 Quare manifestum": "21.6",
    "Metaphora autem est nominis alieni illatio aut a genere": "21.7",
    "Dico autem a genere quidem ad speciem, puta \u00abnavis": "21.8",
    "A specie autem ad genus «iam": "21.9",
    "A specie autem ad speciem, puta \u00abere animam exsecuit": "21.10",
    "'Proportionale' autem dico quando similiter habet": "21.11",
    "Dico autem puta similiter inquit \u02bdfyala\" ad Bachum": "21.12",
    "Aut quod senectus ad vitam et vespera ad diem": "21.13",
    "Quibusdam autem non est nomen iacens proportionalium": "21.14",
    "Est autem modo hoc metafore uti et aliter": "21.15",
    "appellantem quod alienum negare propriorum aliquid": "21.16",
    "Poetizatum autem est quod, totaliter non vocatum": "21.17",
    "Superextensum autem est aut sublatum hoc quidem": "21.18",
    "superextensum quidem puta 'poleos' (idest canus": "21.19",
    "Permutatum autem est quando eius quod nominatur": "21.20",
    "Ipsorum autem nominum hec quidem masculina, hec": "21.21",
    "masculina quecumque terminantur in 'n' et 'r'": "21.22",
    "feminina autem quecumque ex vocalibus in semper": "21.23",
    "quare equales accidunt multitudines in quecumque": "21.24",
    "In mutam autem nullum nomen terminatur, neque in": "21.25",
    "In 'iota' autem tres partes, 'meli' (idest mel)": "21.26",
#}

#poetics_chapters_22_23 = {
    # Chapter 22
    "Locutionis autem virtus planam et non humilem esse.": "22.1",
    "Planissima quidem igitur est que ex propriis nominibus, sed humilis.": "22.2",
    "Venerabilis autem et permutans quod idioticale que extraneis utitur.": "22.3",
    "Sed si quis utique omnia talia faciat, aut enigma erit aut barbarismus": "22.4",
    "Enigmatis enim species hec est, dicentem existentia inpossibilia copulare.": "22.5",
    "barbarismus autem. Oportet ergo discretionem factam": "22.6",
    "esse aliqualiter hiis ; hoc quidem enim non idioticale faciet": "22.7",
    "Non minimam autem partem confert ad planum locutionis": "22.8",
    "Quare non recte vituperant qui increpant talem modum": "22.9",
    "Apparere quidem igitur aliqualiter utentem isto modo risile.": "22.10",
    "Metrum autem commune est omnium partium": "22.11",
    "quod autem congruum quantum differt in versibus consideretur": "22.12",
    "Et in lingua autem et in metaforis et in aliis speciebus transponens": "22.13",
    "Adhuc autem Arifrades tragicos komodizabat, quod que nullus": "22.14",
    "Propter non esse enim in propriis faciunt non idioticale": "22.15",
    "Est autem magnum quidem unoquoque dictorum decenter uti": "22.16",
    "Solum enim hoc neque ab alio est accipere, estque signum eufye": "22.17",
    "Nominum autem dupla quidem maxime congruunt dithyrambis": "22.18",
    "Et in eroicis quidem omnia opportuna que dicta, in iambialibus autem": "22.19",
    "De tragodia quidem igitur et de ea que in agere imitatione": "22.20",

    # Chapter 23
    "De narrativa autem et in metro imitativa, quod oportet": "23.1",
    "et non similes hystorias consuetas esse, in quibus": "23.2",
    "Sicut enim secundum eadem tempora et in Salamina factum": "23.3",
    "Fere autem multi poetarum hoc actitant. Propter": "23.4",
    "quod, sicut diximus iam, et sic admirandus utique apparebit Homerus": "23.5",
    "Alii autem circa unum faciunt et circa unum tempus et unam": "23.6",
    "Namque ex Iliade quidem et Odysseia unam tragodiam efficit": "23.7",
#}

#poetics_chapters_24_25 = {
    # Chapter 24
    "Adhuc autem species easdem oportet habere epopoiiam": "24.1",
    "et partes extra melopoiiam (idest melodie factionem)": "24.2",
    "Quibus omnibus Homerus usus est et primus et sufficienter.": "24.3",
    "Differt autem secundum consistentie longitudinem epopoia et metrum.": "24.4",
    "Longitudinis quidem igitur terminus sufficiens qui dictus est": "24.5",
    "Habet autem ad superextendi magnitudinem aliquam epopoia": "24.6",
    "Quare hoc habet bonum ad magnificentiam et ad transmutari": "24.7",
    "Metrum autem quod eroicum ab experientia congruit. Si enim": "24.8",
    "quod enim eroicum stabilissimum et maxime molis metrorum": "24.9",
    "quod autem iambiale et tetrametrum motiva hoc quidem": "24.10",
    "Adhuc autem inconvenientius, si misceat quis ipsa, sicut Chairemon.": "24.11",
    "Propter quod nullus magnam consistentiam in alio poetizavit": "24.12",
    "Homerus autem alias in multis dignus laudari, et etiam quia": "24.13",
    "Ipsum enim utique poetam paucissima prologizare. Non enim": "24.14",
    'Oportet quidem\n\n<pb n="32"/>': "24.15",
    "deinde que circa Hectoris persecutionem in scene entia": "24.16",
    "Ouod autem mirabile delectabile; signum autem": "24.17",
    "Docuit autem maxime Homerus et alios falsa dicere ut .": "24.18",
    "Preelegi hoc inpossibilia signa magis quam possibilia inprobabilia": "24.19",
    "sermonesque non consistere ex partibus irrationabilibus": "24.20",
    "Quare dicere quod interimetur utique fabula risile": "24.21",
    "Nunc autem alis bonis poeta occultat delectans quod inconveniens.": "24.22",
    "Locutioni autem oportet pervigilare in ociosis partibus": "24.23",

    # Chapter 25
    "De problematibus autem et solutionibus, ex quantisque": "25.1",
    "Quoniam enim est imitator poeta sicut pictor": "25.2",
    "Hec autem enuntiantur locutione aut et linguis et metaforis": "25.3",
    "Ad hec autem non eadem rectificatio est politice et poetice": "25.4",
    "Ipsius autem poetice duplex peccatum, hoc quidem enim": "25.5",
    "Si quidem enim preeligebat imitari inpossibilitatem ipsius": "25.6",
    "Quare oportet increpationes in problematibus ex hiis": "25.7",
    "Primo quidem igitur que ad ipsam artem inpossibilia": "25.8",
    "et secundum eam que de hiis artem peccare non recte": "25.9",
    "Adhuc utrum est peccatum, eorum que secundum artem": "25.10",
    "Ad hec autem, si increpatur quod non vera, sed forte utique": "25.11",
    "Si autem neutro modo, quod sic aiunt": "25.12",
    "velut que de diis, forte enim neque melius neque dicere": "25.13",
    "Hec forte non melius quidem, sed sic habebat": "25.14",
    "De eo autem quod bene aut non bene aut dictum est": "25.15",
    "Que autem ad locutionem aspicientem oportet dissolvere": "25.16",
    "Hoc autem secundum metaforam": "25.17",
    "Secundum accentum autem, sicut Ippias Thasius solvit": "25.18",
    "Hec autem divisione, velut Empedocles « cito autem": "25.19",
    "Hec autem amfibolia «transivit autem pleonyx»": "25.20",
    "Hec autem secundum consuetudinem locutionis": "25.21",
    "Oportet autem et quando nomen aliquid videtur significare": "25.22",
    "per sic prohiberi quot modis contingit ; sic aut sic": "25.23",
    "Secundum eam que secundum econtrarietatem, ut Glaucon": "25.24",
    "Hoc autem passa sunt que circa Karium. Putant enim": "25.25",
    "Totaliter autem inpossibile quidem ad poesim aut ad melius": "25.26",
    "Ad poesim enim eligibilius probabile inpossibille": "25.27",
    "Et possibile tales esse, quale Xeuxis scripsit": "25.28",
    "Ad que aiunt irrationabilia ; sicque et quod aliquando": "25.29",
    "Que autem subcontraria ut dicta considerare, sicut qui in": "25.30",
    "Recta autem increpatio et irrationabilitas et pravitas": "25.31",
    "Increpationes quidem igitur ex quinque speciebus ferunt": "25.32",
#}
#poetics_chapter_26 = {
    # Chapter 26
    "Utrum autem melior epopoiika imitatio aut tragica dubitabit utique quis.": "26.1",
    "Si enim que minus honerosa melior, talis autem": "26.2",
    "ut enim non sentientem si non ipse apponat, multum motum": "26.3",
    "Tragodia quidem igitur talis est ut et qui prius posteriores": "26.4",
    "Hanc quidem igitur ad inspectores epieikees aiunt esse": "26.5",
    "Primo quidem non poetice accusatio sed ypocritice": "26.6",
    "Deinde neque motus omnis reprobandus, si quidem neque": "26.7",
    "Adhuc tragodia sine motu facit quod ipsius, sicut epopoiia": "26.8",
    "Deinde propterea quod omnia habet quecumque quidem epopoiia": "26.9",
    "et adhuc non parvam partem musicam et visus per quam": "26.10",
    "Deinde et quod evidens habet et in recognitione": "26.11",
    "Adhuc per in minori longitudine finem imitationis esse": "26.12",
    "Adhuc minus una imitatio que epopoiorum ; signum autem": "26.13",
    "Dico autem puta si ex pluribus actionibus sit composita": "26.14",
    "Si igitur omnibus hiis differt et adhuc artis opere": "26.15",
    "De tragodia quidem igitur et epopoiia ipsisque": "26.16"
}

# %%
import re

f = open('/Users/gcrane/github/Poetics2.0/lat/tlg0086.tlg034.morbeke-lat.xml')
outf = open('/Users/gcrane/github/Poetics2.0/data/tlg0086/tlg034/tlg0086.tlg034.moerbeke1277-lat1.xml','w')
exit
usetext = f.read()
f.close()

prevsectn = 0

prevchap = ''
for foo in moerbeke_sections:
    curchap,cursect = moerbeke_sections[foo].split('.')
    #print(curchap,cursect)
    if(not prevchap == curchap):
        prevsectn  = 0
    prevchap = curchap
    if(re.search('[a-z]',cursect)):
        continue
    cursectn = int(cursect)
    if(not cursectn == prevsectn + 1):
        print('skipped',curchap,cursect,prevsectn,foo)
    prevsectn = cursectn
    
    
for foo in moerbeke_sections:
    if(re.search('\.1$',moerbeke_sections[foo])):
        continue
    shortkey = foo
    if(not usetext.count(shortkey) == 1 ):
        if(usetext.count(shortkey) == 0):
            shortkey = ''
            if(len(foo.split()) > 4):
                
                for i in range(0,4):
                    if(shortkey):
                        shortkey = shortkey + ' '
                    shortkey = shortkey + foo.split()[i]
            if(not usetext.count(shortkey) == 1 and len(foo.split()) > 3):
                shortkey = ''
                for i in range(0,3):
                    if(shortkey):
                        shortkey = shortkey + ' '
                    shortkey = shortkey + foo.split()[i]
            if(not usetext.count(shortkey) == 1):
                shortkey,rval = re.subn('([^\s]+)\s+','\g<1>\n',foo,1)
            if(not usetext.count(shortkey) == 1):
                shortkey,rval = re.subn('([^\s]+\s+[^\s]+)\s+','\g<1>\n',foo,1)
                #print(shortkey,foo)
        if(not usetext.count(shortkey) == 1):
                
            print(foo,usetext.count(foo),usetext.count(shortkey))
    
    curchap,cursect = moerbeke_sections[foo].split('.')
    subpat = '</p></div>\n\n<div type="textpart" subtype="subchapter" xml:base="tlg0086.tlg034.moerbeke1277-lat1:' + curchap + '"  n="'+cursect+'">\n<p>'
    usetext = usetext.replace(shortkey,subpat+shortkey)

outf.write(usetext)

outf.close()
# Out:
# skipped 5 11 9 Propter quod
# quicumque de tragodia novit studiosa
