# %%
import re

eumtb = '/Users/gcrane/github/glaux-trees/public/xml/0085-007.xml'


oedrtb = '/Users/gcrane/github/glaux-trees/public/xml/0011-002.xml'

iontb = '/Users/gcrane/github/glaux-trees/public/xml/0006-010.xml'

def proctb(tbname):
    f = open(tbname)
    for l in f:

    f.close()
