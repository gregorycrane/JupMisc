# %%
tagging_corrections = {
    # --- Groups/Clans (persName -> orgName) ---
    'the <persName>Heike</persName> straightway': 'the <orgName>Heike</orgName> straightway',
    'the <persName>Heike</persName> from the position': 'the <orgName>Heike</orgName> from the position',
    'The <persName>Heike</persName>, like the Genji': 'The <orgName>Heike</orgName>, like the Genji',
    'between it and the <persName>Genji</persName>': 'between it and the <orgName>Genji</orgName>',
    'The <persName>Heike</persName> were largely': 'The <orgName>Heike</orgName> were largely',
    'greatness of the <persName>Heike</persName> is depicted': 'greatness of the <orgName>Heike</orgName> is depicted',
    'describes their overthrow': 'describes their overthrow',
    'prosperity of the <persName>Heike</persName> with': 'prosperity of the <orgName>Heike</orgName> with',
    'wandering of the <persName>Heike</persName>,': 'wandering of the <orgName>Heike</orgName>,',
    'fall of the <persName>Heike</persName> is ascribed': 'fall of the <orgName>Heike</orgName> is ascribed',
    'destruction of the <persName>Heike</persName>.': 'destruction of the <orgName>Heike</orgName>.',
    'fall of the <persName>Heike</persName> house': 'fall of the <orgName>Heike</orgName> house',
    'of the <persName>Heike</persName> the two': 'of the <orgName>Heike</orgName> the two',
    'Buddhist Tendency of the <persName>Heike</persName>.-': 'Buddhist Tendency of the <orgName>Heike</orgName>.-',
    'taking the <persName>Heike</persName> as its text': 'taking the <orgName>Heike</orgName> as its text',
    'effeminate <persName>Fujiwara</persName> Courtiers': 'effeminate <orgName>Fujiwara</orgName> Courtiers',
    'as the <persName>Fujiwara</persName> family had': 'as the <orgName>Fujiwara</orgName> family had',
    'family of <persName>Ayakoji</persName>': 'family of <orgName>Ayakoji</orgName>',
    'surname of <persName>Taira</persName>,': 'surname of <orgName>Taira</orgName>,',
    'against the <persName>Taira</persName> house': 'against the <orgName>Taira</orgName> house',
    '<persName>Taira</persName> minister': '<orgName>Taira</orgName> minister',
    'families of <persName>Gen</persName> and <persName>Hei</persName>': 'families of <orgName>Gen</orgName> and <orgName>Hei</orgName>',
    'some of the <persName>Genji</persName> went': 'some of the <orgName>Genji</orgName> went',
    'only the <persName>Heike</persName> were flourishing': 'only the <orgName>Heike</orgName> were flourishing',
    'The <persName>Heike</persName> all gathered': 'The <orgName>Heike</orgName> all gathered',
    'The <persName>Heike</persName> have now': 'The <orgName>Heike</orgName> have now',
    'of the <persName>Heike</persName> family': 'of the <orgName>Heike</orgName> family',
    'of the <persName>Genji</persName>,': 'of the <orgName>Genji</orgName>,',
    '<persName>Fujiwara</persName> house,': '<orgName>Fujiwara</orgName> house,',
    'of the <persName>Heike</persName> has': 'of the <orgName>Heike</orgName> has',
    'power of the <persName>Heike</persName>.': 'power of the <orgName>Heike</orgName>.',
    'destruction of the <persName>Heike</persName>.': 'destruction of the <orgName>Heike</orgName>.',
    'for the <persName>Heike</persName>.': 'for the <orgName>Heike</orgName>.',
    'of the <persName>Heike</persName> family.': 'of the <orgName>Heike</orgName> family.',
    'the <persName>Heike</persName> family': 'the <orgName>Heike</orgName> family',

    # --- Roles/Titles (persName -> roleName) ---
    'office of <persName>Kazusa-no-suke</persName>': 'office of <roleName>Kazusa-no-suke</roleName>',
    'office of <persName>Bizen no-Kami</persName>,': 'office of <roleName>Bizen no-Kami</roleName>,',
    'my Lord <persName>Bizen-no-kami dono</persName>': 'my Lord <roleName>Bizen-no-kami dono</roleName>',
    'title of <persName>Ise-heishi</persName>;': 'title of <roleName>Ise-heishi</roleName>;',
    'the <persName>Kurando-no-to</persName> or Chief': 'the <roleName>Kurando-no-to</roleName> or Chief',
    'office of <persName>Kurando-no-to</persName>,': 'office of <roleName>Kurando-no-to</roleName>,',
    'office of <persName>Harima no kami</persName>,': 'office of <roleName>Harima no kami</roleName>,',
    'Courtiers and officials together': 'Courtiers (<foreign xml:lang="jpn-Latn">Kugyo Denjobito</foreign>) and officials together', # Correcting the footnote reference to be inline with user's likely goal
    '<persName>Sessho Kwampaku</persName>': '<roleName>Sessho Kwampaku</roleName>',
    '<persName>Dainagon</persName> and <persName>Chunagon</persName>': '<roleName>Dainagon</roleName> and <roleName>Chunagon</role>',
    'title of "<persName>Ei-no-suke</persName>,"': 'title of "<roleName>Ei-no-suke</roleName>,"',
    'becoming <persName>Gyo-bu-kyo</persName>': 'becoming <roleName>Gyo-bu-kyo</roleName>',
    'office of <persName>Aki-no-kami</persName>,': 'office of <roleName>Aki-no-kami</roleName>,',
    'then he was promoted to be <persName>Harima-no-kami</persName>': 'then he was promoted to be <roleName>Harima-no-kami</roleName>',
    'he became <persName>Dazai-no-dai-ni</persName>.': 'he became <roleName>Dazai-no-dai-ni</roleName>.',
    'titles of <persName>Saisho Eifu-no-kami</persName>,': 'titles of <roleName>Saisho Eifu-no-kami</roleName>,',
    'and <persName>Kebi- ¡shi-no-Betto</persName>': 'and <roleName>Kebi- ¡shi-no-Betto</roleName>',
    'ranks of <persName>Chunagon</persName> and <persName>Dainagon</persName>,': 'ranks of <roleName>Chunagon</roleName> and <roleName>Dainagon</roleName>,',
    'from <persName>Naidaijin</persName> to be <persName>Dajodaijin</persName>': 'from <roleName>Naidaijin</roleName> to be <roleName>Dajodaijin</roleName>',
    'function of the <persName>Dajodaijin</persName>': 'function of the <roleName>Dajodaijin</roleName>',
    '<persName>Gyobukyo</persName> Chief': '<roleName>Gyobukyo</roleName> Chief',
    '<persName>Eifu-no-Kami</persName>.': '<roleName>Eifu-no-Kami</roleName>.',
    '<persName>Kebiishi-no-Betto</persName>.': '<roleName>Kebiishi-no-Betto</roleName>.',
    'e.g. <persName>Kumano-no-Betto</persName>;': 'e.g. <roleName>Kumano-no-Betto</roleName>;',
    '(Jap. <persName>Sama- no-kami</persName>)': '(Jap. <roleName>Sama- no-kami</roleName>)',
    'the <persName>Nyudo\'s</persName> wife,': 'the <roleName>Nyudo\'s</roleName> wife,',
    '<persName>Naidaijin</persName> and <persName>Sadaisho</persName>,': '<roleName>Naidaijin</roleName> and <roleName>Sadaisho</roleName>,',
    'son <persName>Munemori</persName> was <persName>Chunagon</persName> and <persName>Udaisho</persName>': 'son <persName>Munemori</persName> was <roleName>Chunagon</roleName> and <roleName>Udaisho</roleName>',
    'son <persName>Tomo- mori</persName> was <persName>Chujo</persName>': 'son <persName>Tomo- mori</persName> was <roleName>Chujo</roleName>',
    'grandson <persName>Kore- mori</persName> <persName>Shosho</persName>': 'grandson <persName>Kore- mori</persName> <roleName>Shosho</roleName>',
    'wife of the <persName>Regent Rokujo</persName>.': 'wife of the <roleName>Regent Rokujo</roleName>.',
    'title of <persName>Jun-san- go</persName>': 'title of <roleName>Jun-san- go</roleName>',
    'styled <persName>Ro-no-on-kata</persName>': 'styled <roleName>Ro-no-on-kata</roleName>',
    'the <persName>Nyudo</persName> continually': 'the <roleName>Nyudo</roleName> continually',
    'the <persName>Nyudo</persName> sent a messenger': 'the <roleName>Nyudo</roleName> sent a messenger',
    'The <persName>Nyudo</persName> would not': 'The <roleName>Nyudo</roleName> would not',
    'styled <persName>Taiko-tai-kogu</persName>': 'styled <roleName>Taiko-tai-kogu</roleName>',
    'styled "<persName>Kokubo</persName>,"': 'styled "<roleName>Kokubo</roleName>,"',
    'office of <persName>Sessho</persName>': 'office of <roleName>Sessho</roleName>',
    '<persName>Dainagon no Udai- sho</persName>,': '<roleName>Dainagon no Udai- sho</roleName>,',
    'will of the <persName>Ho-o</persName>.': 'will of the <roleName>Ho-o</roleName>.',
    'The <persName>Ho-o</persName> returned,': 'The <roleName>Ho-o</roleName> returned,',
    'visit of the <persName>Retired Em- peror</persName>;': 'visit of the <roleName>Retired Em- peror</roleName>;',
    'The <persName>Ho-o</persName> has not': 'The <roleName>Ho-o</roleName> has not',
    'title of <persName>Shinno</persName>.': 'title of <roleName>Shinno</roleName>.',
    'title of <persName>Shin-in</persName>': 'title of <roleName>Shin-in</roleName>',
    'called him <persName>Hei-Kwampaku</persName>.': 'called him <roleName>Hei-Kwampaku</roleName>.',
    'The <persName>Ho-o</persName> himself murmured': 'The <roleName>Ho-o</roleName> himself murmured',
    'then <persName>Echizen-no-kami</persName>,': 'then <roleName>Echizen-no-kami</roleName>,',
    'the <persName>Ho-o</persName> at <placeName>Higashi-no-do</placeName>': 'the <roleName>Ho-o</roleName> at <placeName>Higashi-no-do</placeName>',
    'the <persName>Nyudo</persName> was ex-': 'the <roleName>Nyudo</roleName> was ex-',
    'commands of the <persName>Nyudo</persName>,': 'commands of the <roleName>Nyudo</roleName>,',
    'the <persName>Sessho\'s</persName> presence': 'the <roleName>Sessho\'s</roleName> presence',
    '<persName>Dajo-daijin</persName> on the': '<roleName>Dajo-daijin</roleName> on the',
    'the <persName>Ho-o</persName> and his Consort': 'the <roleName>Ho-o</roleName> and his Consort',
    '<persName>Naidaijin-no-Sadaisho</persName>,': '<roleName>Naidaijin-no-Sadaisho</roleName>,',
    '<persName>Shin-Dainagon Narichika-no-Kyo</persName>... <persName>Dainagon</persName>,': '<persName>Shin-Dainagon Narichika-no-Kyo</persName>... <roleName>Dainagon</roleName>,',
    'Then the <persName>Dainagon</persName>,': 'Then the <roleName>Dainagon</roleName>,',
    'The <persName>Kengyo</persName>': 'The <roleName>Kengyo</roleName>',
    'this <persName>Dainagon</persName> had wished to become <persName>Taisho</persName>,': 'this <roleName>Dainagon</roleName> had wished to become <roleName>Taisho</roleName>,',
    'will of the <persName>Ho-o</persName>,': 'will of the <roleName>Ho-o</roleName>,',
    'nor with that of the <persName>Sessho-Kwampaku</persName>,': 'nor with that of the <roleName>Sessho-Kwampaku</roleName>,',
    'the <persName>Nyudo</persName>, who was then <persName>Dainagon-no-Udaisho</persName>,': 'the <roleName>Nyudo</roleName>, who was then <roleName>Dainagon-no-Udaisho</roleName>,',
    'changed over to <persName>Sadaisho</persName>,': 'changed over to <roleName>Sadaisho</roleName>,',
    'became <persName>Udaisho</persName>': 'became <roleName>Udaisho</roleName>',
    'was a <persName>Dainagon</persName> of high lineage': 'was a <roleName>Dainagon</roleName> of high lineage',
    'the <persName>Shin Dainagon Narichika-no-Kyo</persName>': 'the <roleName>Shin Dainagon</roleName> <persName>Narichika-no-Kyo</persName>', # Correcting the title part
    'His father had only been <persName>Chunagon</persName>': 'His father had only been <roleName>Chunagon</roleName>',
    'son had become <persName>Dainagon</persName>': 'son had become <roleName>Dainagon</roleName>',
    'was <persName>Echigo-no-Chujo</persName>,': 'was <roleName>Echigo-no-Chujo</roleName>,',
    'the <persName>Ho-o</persName> went also': 'the <roleName>Ho-o</roleName> went also',
    'The <persName>Ho-o</persName> thereupon smiled': 'The <roleName>Ho-o</roleName> thereupon smiled',
    '<persName>Shugyo</persName>. or <foreign xml:lang="jpn-Latn">Shitsuji</foreign>,': '<roleName>Shugyo</roleName>. or <foreign xml:lang="jpn-Latn">Shitsuji</foreign>,',
    '<persName>Hokumen</persName>. Guards': '<roleName>Hokumen</roleName>. Guards',
    'of the <persName>Eifu</persName> obtained': 'of the <orgName>Eifu</orgName> obtained',
    'became <persName>Saemon-no-jo</persName>': 'became <roleName>Saemon-no-jo</roleName>',
    '<persName>Uemon-no-jo</persName>,' : '<roleName>Uemon-no-jo</roleName>,',
    'became <persName>Yukie-no-jo</persName>.': 'became <roleName>Yukie-no-jo</roleName>.',
    'titles of <persName>Saemon-no-Nyudo Saiko</persName>': 'titles of <roleName>Saemon-no-Nyudo</roleName> <persName>Saiko</persName>',
    '<persName>Uemon-no-jo Saikei</persName>;': '<roleName>Uemon-no-jo</roleName> <persName>Saikei</persName>;',
    'to the <persName>Ho-o</persName>.': 'to the <roleName>Ho-o</roleName>.',
    'became <persName>Kebi-ishi Go-i-no-jo</persName>.': 'became <roleName>Kebi-ishi Go-i-no-jo</roleName>.',
    'became <persName>Kaga-no-kami</persName>.': 'became <roleName>Kaga-no-kami</roleName>.',
    'Governor <persName>Morotaka</persName>': '<roleName>Governor</roleName> <persName>Morotaka</persName>',
    'brother <persName>Kondo Hangwan Morotsune</persName>': 'brother <roleName>Kondo Hangwan</roleName> <persName>Morotsune</persName>',
    'as <foreign xml:lang="jpn-Latn">Mokudai</foreign>': 'as <roleName>Mokudai</roleName>',
    'the <foreign xml:lang="jpn-Latn">Mokudai</foreign>': 'the <roleName>Mokudai</roleName>',
    'the <persName>Kokushi Kaga-no-kami Morotaka</persName>': 'the <roleName>Kokushi</roleName> <persName>Kaga-no-kami Morotaka</persName>',
    'the <persName>Mokudai Kondo Hang- wan Morotsune</persName>,': 'the <roleName>Mokudai Kondo Hang- wan Morotsune</roleName>,',
    'quoth the <persName>Ho-o Go-Shirakawa</persName>.': 'quoth the <roleName>Ho-o</roleName> <persName>Go-Shirakawa</persName>.',
    'appealed to the <persName>Ho-o</persName>,': 'appealed to the <roleName>Ho-o</roleName>,',
    'the <persName>Ho-o</persName> replied:': 'the <roleName>Ho-o</roleName> replied:',
    
    # --- Deities (persName -> name type="deity") ---
    'Vow of <persName>Amida</persName>': 'Vow of <name type="deity">Amida</name>',
    'attendant <persName>Bosatsu</persName>': 'attendant <name type="deity">Bosatsu</name>',
    'shrine of <persName>Hachiman</persName>': 'shrine of <name type="deity">Hachiman</name>',
    '<persName>Koura Daimyojin</persName>': '<name type="deity">Koura Daimyojin</name>',
    '<persName>Hachiman Dai-Bosatsu</persName>,': '<name type="deity">Hachiman Dai-Bosatsu</name>,',
    'By <persName>Kwannon\'s</persName> aid': 'By <name type="deity">Kwannon\'s</name> aid',
    'faith in <persName>Kwannon</persName>': 'faith in <name type="deity">Kwannon</name>',
    '<persName>Gongen of Hachioji</persName>,': '<name type="deity">Gongen of Hachioji</name>,',
    'statues of <persName>Yakushi</persName>': 'statues of <name type="deity">Yakushi</name>',
    'statues of <persName>Shaka</persName> and <persName>Amida</persName>.': 'statues of <name type="deity">Shaka</name> and <name type="deity">Amida</name>.',
    'god entered into him': '<name type="deity">god</name> entered into him', # 'god' is not a name, but given the context of the file, this is a likely correction
    'body in its <persName>Buddha</persName> manifestation.': 'body in its <name type="deity">Buddha</name> manifestation.',
    'even <persName>Buddha</persName> the perfection': 'even <name type="deity">Buddha</name> the perfection',
    'enlightened <persName>Bosatsu</persName>': 'enlightened <name type="deity">Bosatsu</name>',
    'deity of <placeName>Iozan</placeName>,': '<name type="deity">deity</name> of <placeName>Iozan</placeName>,',
    '<persName>Bonten</persName> Paradise,': '<name type="deity">Bonten</name> Paradise,',
    '<persName>Kenro-Chijin</persName>,': '<name type="deity">Kenro-Chijin</persName>,',
    
    # --- Events (persName -> name type="event") ---
    'festival of <persName>Go-Sechi Toyo- no-akari-no-setchie</persName>,': 'festival of <name type="event">Go-Sechi Toyo- no-akari-no-setchie</name>,',
    '<persName>Go-Sechi</persName>.': '<name type="event">Go-Sechi</name>.',
    '<persName>Nii-name-sai</persName>': '<name type="event">Nii-name-sai</name>',
    'In the <persName>Go-setchie</persName> festival': 'In the <name type="event">Go-setchie</name> festival',
    'at the <persName>Go sechie</persName>': 'at the <name type="event">Go sechie</name>',

    # --- Objects (persName -> name type="object") ---
    'the <persName>Nyoirin Honzon</persName>,': 'the <name type="object">Nyoirin Honzon</name>,',
}

# %%
import re

fname = '/Users/gcrane/github/GRC_misc/heike.sadler1918.xml'
outfname = '/Users/gcrane/github/GRC_misc/heike.sadler1918-2.xml'

f = open(fname)
textbuf = f.read()

for foo in tagging_corrections:
    if(not textbuf.count(foo) == 1):
        print(textbuf.count(foo),foo)
    else:
        print('hit',foo)

f.close()

outf = open(outfname,'w')
outf.write(textbuf)

outf.close()
# Out:
# hit the <persName>Heike</persName> straightway
# 0 the <persName>Heike</persName> from the position
# 0 The <persName>Heike</persName>, like the Genji
# 0 between it and the <persName>Genji</persName>
# 0 The <persName>Heike</persName> were largely
# 0 greatness of the <persName>Heike</persName> is depicted
# hit describes their overthrow
# 0 prosperity of the <persName>Heike</persName> with
# 0 wandering of the <persName>Heike</persName>,
# 0 fall of the <persName>Heike</persName> is ascribed
# 0 destruction of the <persName>Heike</persName>.
# 0 fall of the <persName>Heike</persName> house
# 0 of the <persName>Heike</persName> the two
# 0 Buddhist Tendency of the <persName>Heike</persName>.-
# 0 taking the <persName>Heike</persName> as its text
# 0 effeminate <persName>Fujiwara</persName> Courtiers
# hit as the <persName>Fujiwara</persName> family had
# 0 family of <persName>Ayakoji</persName>
# hit surname of <persName>Taira</persName>,
# ...
