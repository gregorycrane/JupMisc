# %%
import re

section_break_map_dead = [
    # Dialogue 1: Diogenes and Polydeukes
    {'text_pat': 'And to the rich, my dearest pet', 'dialogue_number': '1', 'section_number': '2'},
    {'text_pat': 'And to the poor, Mr. Laconian', 'dialogue_number': '1', 'section_number': '3'},

    # Dialogue 2: Kroesus, Pluto, etc.
    {'text_pat': 'None the less, basest of', 'dialogue_number': '2', 'section_number': '2'},

    # Dialogue 3: Menippus, Amphilochus, Trophonius
    {'text_pat': 'Menippus, Amphilochus himself must know', 'dialogue_number': '3', 'section_number': '2'},
    {'text_pat': 'What do you say? Unless I had gone', 'dialogue_number': '3', 'section_number': '3'},

    # Dialogue 4: Hermes and Charon
    {'text_pat': 'Just now, my dear Hermes, it is quite impossible', 'dialogue_number': '4', 'section_number': '2'},
    {'text_pat': 'Better so, even though payment', 'dialogue_number': '4', 'section_number': '3'},

    # Dialogue 5: Pluto and Hermes
    {'text_pat': 'They will suffer a ridiculous fate', 'dialogue_number': '5', 'section_number': '2'},

    # Dialogue 6: Terpsion and Pluto
    {'text_pat': 'These things, Terpsion, are much more reasonable', 'dialogue_number': '6', 'section_number': '2'},

    # Dialogue 7: Zenophantes and Kallidemides
    {'text_pat': 'What happened then ? For you seem', 'dialogue_number': '7', 'section_number': '2'},

    # Dialogue 8: Knemon and Damnippus
    {'text_pat': 'I was in the habit of courting and flattering', 'dialogue_number': '8', 'section_number': '2'},

    # Dialogue 9: Simylus and Polystratus
    {'text_pat': 'In the first place, I enjoyed universal power', 'dialogue_number': '9', 'section_number': '2'},

    # Dialogue 10: Charon, Hermes, etc.
    {'text_pat': 'You say well, and so let us do', 'dialogue_number': '10', 'section_number': '2'},
    {'text_pat': 'So, then, pray, off with your good looks', 'dialogue_number': '10', 'section_number': '3'},
    {'text_pat': 'Not stripped and bare, my fine Sir', 'dialogue_number': '10', 'section_number': '4'},
    {'text_pat': 'Bless me! And you gentleman armed', 'dialogue_number': '10', 'section_number': '5'},
    {'text_pat': 'It’s well. So loose the cables', 'dialogue_number': '10', 'section_number': '6'},

    # Dialogue 11: Krates and Diogenes
    {'text_pat': 'What, pray, was the end of it', 'dialogue_number': '11', 'section_number': '2'},
    {'text_pat': 'No, for I had no need of them', 'dialogue_number': '11', 'section_number': '3'},

    # Dialogue 12: Alexander, Hannibal, etc.
    {'text_pat': 'In respect to this one circumstance, Minos', 'dialogue_number': '12', 'section_number': '2'},
    {'text_pat': 'He has delivered no ignoble plea', 'dialogue_number': '12', 'section_number': '3'},
    {'text_pat': 'Not before you have heard me, too.', 'dialogue_number': '12', 'section_number': '4'},

    # Dialogue 13: Diogenes and Alexander
    {'text_pat': 'But their lie was not unserviceable', 'dialogue_number': '13', 'section_number': '2'},
    {'text_pat': 'May I not, pray, be excused for laughing', 'dialogue_number': '13', 'section_number': '3'},

    # Dialogue 14: Philip and Alexander
    {'text_pat': 'And what people worth fighting with', 'dialogue_number': '14', 'section_number': '2'},
    {'text_pat': 'I know all this ; for Kleitus brought me', 'dialogue_number': '14', 'section_number': '3'},

    # Dialogue 15: Antilochus and Achilleus
    {'text_pat': 'But, O son of Nestor, at that time', 'dialogue_number': '15', 'section_number': '2'},
    {'text_pat': 'Yet what can one do, Achilleus ?', 'dialogue_number': '15', 'section_number': '3'},

    # Dialogue 16: Diogenes and Herakles
    {'text_pat': 'And you did perfectly right', 'dialogue_number': '16', 'section_number': '2'},
    {'text_pat': 'I understand. He handed you over', 'dialogue_number': '16', 'section_number': '3'},
    {'text_pat': 'Now I clearly understand. For Alkmene', 'dialogue_number': '16', 'section_number': '4'},

    # Dialogue 17: Menippus and Tantalus
    {'text_pat': 'Your experience is somewhat of the miraculous', 'dialogue_number': '17', 'section_number': '2'},
    {'text_pat': 'You talk nonsense, Tantalus', 'dialogue_number': '17', 'section_number': '3'},

    # Dialogue 18: Menippus, Hermes, etc.
    {'text_pat': 'However, point me out Helene', 'dialogue_number': '18', 'section_number': '2'},

    # Dialogue 19: Aeakus, Protesilaus, etc.
    {'text_pat': 'Better so. Never, therefore, I assure you', 'dialogue_number': '19', 'section_number': '2'},

    # Dialogue 20: Menippus and Aeakus
    {'text_pat': 'Would you like me to show you the philosophers', 'dialogue_number': '20', 'section_number': '2'},
    {'text_pat': 'Is it me you are inquiring for, Menippus ?', 'dialogue_number': '20', 'section_number': '3'},

    # Dialogue 21: Menippus and Kerberus - (No section breaks)
    # Dialogue 22: Charon, Menippus, etc. - (No section breaks)
    # Dialogue 23: Protesilaus, Pluto, etc. - (No section breaks)

    # Dialogue 24: Diogenes and Mausolus
    {'text_pat': 'Will all those things, then, be of no advantage', 'dialogue_number': '24', 'section_number': '2'},

    # Dialogue 25: Nireus, Thersites, Menippus
    {'text_pat': 'You, by no means, however, came below', 'dialogue_number': '25', 'section_number': '2'},

    # Dialogue 26: Menippus and Cheiron
    {'text_pat': 'You are right, Cheiron; but how do you', 'dialogue_number': '26', 'section_number': '2'},
    {'text_pat': 'Take care, Cheiron, that you are not caught', 'dialogue_number': '26', 'section_number': '3'},

    # Dialogue 27: Diogenes, Antisthenes, Krates
    {'text_pat': 'I, also, will relate to you what I saw', 'dialogue_number': '27', 'section_number': '2'},
    {'text_pat': 'Very easily, Antisthenes', 'dialogue_number': '27', 'section_number': '3'},
    {'text_pat': 'You, Krates, and you, Antisthenes', 'dialogue_number': '27', 'section_number': '4'},
    {'text_pat': 'Then, though you were in such a condition', 'dialogue_number': '27', 'section_number': '5'},

    # Dialogue 28: Menippus and Teiresias
    {'text_pat': 'Have you not heard, Teiresias, the Medeia', 'dialogue_number': '28', 'section_number': '2'},
    {'text_pat': 'Do you not, pray, believe other things', 'dialogue_number': '28', 'section_number': '3'},

    # Dialogue 29: Aias and Agamemnon
    {'text_pat': 'Blame Thetis, then, my admirable Sir', 'dialogue_number': '29', 'section_number': '2'},

    # Dialogue 30: Minos and Sostratus
    {'text_pat': 'Whatsoever actions I performed in my life', 'dialogue_number': '30', 'section_number': '2'},
    {'text_pat': 'Do you see, then, how unjustly you act', 'dialogue_number': '30', 'section_number': '3'},
]

section_break_map_sea = [
    # Dialogue 1: Doris and Galateia
    {'text_pat': 'You seem, Galateia, to consider your Polyphemus', 'dialogue_number': '1', 'section_number': '2'},
    {'text_pat': 'If you appear beautiful to the eyes of a keeper', 'dialogue_number': '1', 'section_number': '3'},
    {'text_pat': 'Hold your tongue, Galateia; we heard his singing', 'dialogue_number': '1', 'section_number': '4'},
    # Note: Greek section 5 begins mid-paragraph in the English Doris-5.
    # This pattern targets the next full paragraph.
    {'text_pat': 'Do you then, my dear Doris, show us your own', 'dialogue_number': '1', 'section_number': '5'},

    # Dialogue 2: Cyclops and Poseidon
    {'text_pat': 'Returning from my accustomed tending of my', 'dialogue_number': '2', 'section_number': '2'},
    {'text_pat': 'How soundly you slept, my son, that you did', 'dialogue_number': '2', 'section_number': '3'},
    {'text_pat': 'I understand, they slipped away under them', 'dialogue_number': '2', 'section_number': '4'},

    # Dialogue 3: Poseidon and Alpheius
    {'text_pat': 'I am aware, Alpheius, she is no ugly creature', 'dialogue_number': '3', 'section_number': '2'},

    # Dialogue 4: Menelaus and Proteus
    {'text_pat': 'And what deception could there be in a case so', 'dialogue_number': '4', 'section_number': '2'},
    {'text_pat': 'Whatever rock it approaches and fastens its', 'dialogue_number': '4', 'section_number': '3'},

    # Dialogue 5: Panope and Galene
    # Note: Greek section 2 begins mid-paragraph in the English Panope-2.
    # This pattern targets the next full paragraph.
    {'text_pat': 'What, pray, did the Goddesses do, Panope ?', 'dialogue_number': '5', 'section_number': '2'},

    # Dialogue 6: Triton, Amymone, and Poseidon
    {'text_pat': 'But does she travel all alone so long a journey', 'dialogue_number': '6', 'section_number': '2'},
    {'text_pat': 'A lovely and blooming girl, Triton.', 'dialogue_number': '6', 'section_number': '3'},

    # Dialogue 7: Notus and Zephyrus
    {'text_pat': 'The heifer a divinity !', 'dialogue_number': '7', 'section_number': '2'},

    # Dialogue 8: Poseidon and Dolphins
    {'text_pat': 'Periander, I believe, was pleased with him', 'dialogue_number': '8', 'section_number': '2'},

    # Dialogue 9: Poseidon and Nereids
    # Note: The first speech of Greek section 2 is missing in the English translation.
    # This pattern targets the next available speech.
    {'text_pat': 'No, we ought not to save her, since she is so', 'dialogue_number': '9', 'section_number': '2'},

    # Dialogue 10: Iris and Poseidon
    {'text_pat': 'I perceive. Stand still, Island, and rise again', 'dialogue_number': '10', 'section_number': '2'},

    # Dialogue 11: Xanthus and Thalassa
    # Note: Greek section 2 begins mid-paragraph in the English Xanthus-3.
    # This pattern targets the next full paragraph.
    {'text_pat': 'You are turbid, and feverish and hot', 'dialogue_number': '11', 'section_number': '2'},

    # Dialogue 12: Doris and Thetis
    {'text_pat': 'And she—what did she do, when she was dropped', 'dialogue_number': '12', 'section_number': '2'},

    # Dialogue 13: Enipeus and Poseidon
    {'text_pat': 'What then? Ought you, on that account', 'dialogue_number': '13', 'section_number': '2'},

    # Dialogue 14: Triton and Nereids
    {'text_pat': 'I will explain to you the whole matter as it', 'dialogue_number': '14', 'section_number': '2'},
    # Note: Greek section 3 begins mid-paragraph in the English Triton-6.
    # This pattern targets the next full paragraph, which is section 4.
    {'text_pat': 'Well, for my part, I am not excessively', 'dialogue_number': '14', 'section_number': '4'},

    # Dialogue 15: Zephyrus and Notus
    # Note: Greek section 2 begins mid-paragraph in the English Zephyrus-5.
    # This pattern targets the next full paragraph.
    {'text_pat': 'That was a charming spectacle, Zephyrus', 'dialogue_number': '15', 'section_number': '3'},
    # Note: Greek section 4 begins mid-paragraph in the English Zephyrus-6.
    # This pattern targets the next full paragraph.
    {'text_pat': 'O fortunate Zephyrus, to have seen', 'dialogue_number': '15', 'section_number': '4'}
]

sectiontabs = {}

sectiontabs['068'] = [
    # Dialogue 1: Prometheus and Zeus
    {'text_pat': 'You are for outwitting me, Prometheus.', 'dialogue_number': '1', 'section_number': '2'},
    # Dialogue 2: Eros and Zeus
    {'text_pat': 'Naturally enough, Zeus, for, being mortal women', 'dialogue_number': '2', 'section_number': '2'},
    # Dialogue 3: Zeus and Hermes - (No section breaks)
    # Dialogue 4: Zeus and Ganymedes
    {'text_pat': 'Tell me, have you never heard the name of Zeus', 'dialogue_number': '4', 'section_number': '2'},
    {'text_pat': 'How simple and innocent is the child', 'dialogue_number': '4', 'section_number': '3'},
    {'text_pat': 'In what way, please, can I be of use to you ?', 'dialogue_number': '4', 'section_number': '4'},
    {'text_pat': 'Why, how will handsome looks give you', 'dialogue_number': '4', 'section_number': '5'},
    # Dialogue 5: Hera and Zeus
    {'text_pat': 'Your conduct not even in those matters is proper', 'dialogue_number': '5', 'section_number': '2'},
    {'text_pat': 'And what dreadful crime is it, Hera', 'dialogue_number': '5', 'section_number': '3'},
    {'text_pat': 'Would that you would even marry him', 'dialogue_number': '5', 'section_number': '4'},
    {'text_pat': 'Yes. Hephaestus is lame now', 'dialogue_number': '5', 'section_number': '5'},
    # Dialogue 6: Hera and Zeus (Ixion)
    {'text_pat': 'On mine, and no one else', 'dialogue_number': '6', 'section_number': '2'},
    {'text_pat': 'Is this the fine return the cursed villain makes', 'dialogue_number': '6', 'section_number': '3'},
    {'text_pat': 'What! Must you be for ever bringing up to mind', 'dialogue_number': '6', 'section_number': '4'},
    {'text_pat': 'Yes, but I shall be supposed to be the cloud', 'dialogue_number': '6', 'section_number': '5'},
    # Dialogue 7: Hephaestus and Apollo
    {'text_pat': 'The new-born brat did this, who hardly keeps', 'dialogue_number': '7', 'section_number': '2'},
    {'text_pat': 'No wonder you ask, for you have not heard', 'dialogue_number': '7', 'section_number': '3'},
    {'text_pat': 'Somewhere or other he found a dead tortoise', 'dialogue_number': '7', 'section_number': '4'},
    # Dialogue 8: Hephaestus and Zeus - (No section breaks)
    # Dialogue 9: Poseidon and Hermes
    {'text_pat': 'A lady of Thebes, one of the daughters of', 'dialogue_number': '9', 'section_number': '2'},
    # Dialogue 10: Hermes and Helios
    {'text_pat': 'Well, may he turn him out to perfection', 'dialogue_number': '10', 'section_number': '2'},
    # Dialogue 11: Aphrodite and Selene
    {'text_pat': 'To me he seems to be excessively handsome', 'dialogue_number': '11', 'section_number': '2'},
    # Dialogue 12: Aphrodite and Eros
    {'text_pat': 'Never fear, mother, for I have been a long time', 'dialogue_number': '12', 'section_number': '2'},
    # Dialogue 13: Zeus, Asklepius, and Herakles
    {'text_pat': 'You say well, seeing I healed your burns', 'dialogue_number': '13', 'section_number': '2'},
    # Dialogue 14: Hermes and Apollo
    {'text_pat': 'He was learning to play with the quoit', 'dialogue_number': '14', 'section_number': '2'},
    # Dialogue 15: Hermes and Apollo
    {'text_pat': 'Besides, too, as far as I am concerned', 'dialogue_number': '15', 'section_number': '2'},
    {'text_pat': 'Because, my dear Apollo, the former lives with', 'dialogue_number': '15', 'section_number': '3'},
    # Dialogue 16: Hera and Leto
    {'text_pat': 'These same children, however-the murderer of', 'dialogue_number': '16', 'section_number': '2'},
    # Dialogue 17: Apollo and Hermes
    {'text_pat': 'What then ? Did Hephaestus release them ?', 'dialogue_number': '17', 'section_number': '2'},
    # Dialogue 18: Hera and Zeus
    {'text_pat': 'You appear to me to be going to commend also', 'dialogue_number': '18', 'section_number': '2'},
    # Dialogue 19: Aphrodite and Eros
    {'text_pat': 'But you fear Athena, as you say', 'dialogue_number': '19', 'section_number': '2'},
    # Dialogue 20: The Judgment of Paris - (No section breaks in the English text)
    # Dialogue 21: Ares and Hermes
    {'text_pat': 'Fair speech, my dear Ares', 'dialogue_number': '21', 'section_number': '2'},
    # Dialogue 22: Pan and Hermes
    {'text_pat': 'I will give you her very own story', 'dialogue_number': '22', 'section_number': '2'},
    {'text_pat': 'Yet I shall not disgrace you, father', 'dialogue_number': '22', 'section_number': '3'},
    {'text_pat': 'But tell me, have you already married, Pan ?', 'dialogue_number': '22', 'section_number': '4'},
    # Dialogue 23: Apollo and Dionysus
    {'text_pat': 'And she does well to do so. As for Priapus', 'dialogue_number': '23', 'section_number': '2'},
    # Dialogue 24: Hermes and Maia
    # This break occurs in the MIDDLE of a <p> tag in the English text
    {'text_pat': 'And yet the sons of Leda', 'dialogue_number': '24', 'section_number': '2'},
    # Dialogue 25: Zeus and Helios
    {'text_pat': 'All this, indeed, I knew, and for that reason I', 'dialogue_number': '25', 'section_number': '2'},
    {'text_pat': 'Enough punishment, do you say', 'dialogue_number': '25', 'section_number': '3'},
    # Dialogue 26: Apollo and Hermes
    {'text_pat': 'They act so out of brotherly affection', 'dialogue_number': '26', 'section_number': '2'}
]
speaktab = {}
def addentry(curdict,curentry):
    if(curentry in curdict):
        curdict[curentry] = curdict[curentry] + 1
    else:
        curdict[curentry] = 1
        
def countspeaks(fname,speaktab):

    f = open(fname)

    for l in f:
        m = re.search('<speaker>([^<]+)',l)
        if(m):
            addentry(speaktab,m[1])
        m = re.search('gr32:([0-9]+)" n="([0-9]+)"',l)
        if(m):
            curcit = m[1] + '.' + m[2]
    f.close()


countspeaks('/Users/gcrane/github/canonical-greekLit/data/tlg0062/tlg068/tlg0062.tlg068.perseus-grc3.xml',speaktab)

# %%
for foo in sectiontabs['068']:
    print(foo['text_pat'])
# Out:
# You are for outwitting me, Prometheus.
# Naturally enough, Zeus, for, being mortal women
# Tell me, have you never heard the name of Zeus
# How simple and innocent is the child
# In what way, please, can I be of use to you ?
# Why, how will handsome looks give you
# Your conduct not even in those matters is proper
# And what dreadful crime is it, Hera
# Would that you would even marry him
# Yes. Hephaestus is lame now
# On mine, and no one else
# Is this the fine return the cursed villain makes
# What! Must you be for ever bringing up to mind
# Yes, but I shall be supposed to be the cloud
# The new-born brat did this, who hardly keeps
# No wonder you ask, for you have not heard
# Somewhere or other he found a dead tortoise
# A lady of Thebes, one of the daughters of
# Well, may he turn him out to perfection
# To me he seems to be excessively handsome
# Never fear, mother, for I have been a long time
# You say well, seeing I healed your burns
# He was learning to play with the quoit
# ...

# %%
for item in section_break_map_dead:
    # This accesses the value for the key 'text_pat' in each dictionary
    pattern = item['text_pat']
    curbook = item['dialogue_number']
    cursection = item['section_number']
    print(pattern,curbook + '.' + cursection)
# Out:
# And to the rich, my dearest pet 1.2
# And to the poor, Mr. Laconian 1.3
# None the less, basest of 2.2
# Menippus, Amphilochus himself must know 3.2
# What do you say? Unless I had gone 3.3
# Just now, my dear Hermes, it is quite impossible 4.2
# Better so, even though payment 4.3
# They will suffer a ridiculous fate 5.2
# These things, Terpsion, are much more reasonable 6.2
# What happened then ? For you seem 7.2
# I was in the habit of courting and flattering 8.2
# In the first place, I enjoyed universal power 9.2
# You say well, and so let us do 10.2
# So, then, pray, off with your good looks 10.3
# Not stripped and bare, my fine Sir 10.4
# Bless me! And you gentleman armed 10.5
# It’s well. So loose the cables 10.6
# What, pray, was the end of it 11.2
# No, for I had no need of them 11.3
# In respect to this one circumstance, Minos 12.2
# He has delivered no ignoble plea 12.3
# Not before you have heard me, too. 12.4
# But their lie was not unserviceable 13.2
# ...
